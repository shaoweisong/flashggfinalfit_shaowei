# %%
import pandas as pd
import os
import subprocess
import glob
import uproot
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import awkward as ak
import mplhep as hep

# %%
M250_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2/higgsCombineMX1000_MH125.AsymptoticLimits.mH125.root")
M250_run2 = M250_events_run2["limit"].arrays(['limit']).limit*100
M250_run2[2]
# Out:
# 235.15625

# %%
M250_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M250.AsymptoticLimits.mH125.root")
M250_run2 = M250_events_run2["limit"].arrays(['limit']).limit*100
M350_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M350.AsymptoticLimits.mH125.root")
M350_run2 = M350_events_run2["limit"].arrays(['limit']).limit*100
M450_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M450.AsymptoticLimits.mH125.root")
M450_run2 = M450_events_run2["limit"].arrays(['limit']).limit*100
M550_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M550.AsymptoticLimits.mH125.root")
M550_run2 = M550_events_run2["limit"].arrays(['limit']).limit*100
M600_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M600.AsymptoticLimits.mH125.root")
M600_run2 = M600_events_run2["limit"].arrays(['limit']).limit*100
M700_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M700.AsymptoticLimits.mH125.root")
M700_run2 = M700_events_run2["limit"].arrays(['limit']).limit*100
M850_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M850.AsymptoticLimits.mH125.root")
M850_run2 = M850_events_run2["limit"].arrays(['limit']).limit*100
M1000_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M1000.AsymptoticLimits.mH125.root")
M1000_run2 = M1000_events_run2["limit"].arrays(['limit']).limit*100
M1200_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M1200.AsymptoticLimits.mH125.root")
M1200_run2 = M1200_events_run2["limit"].arrays(['limit']).limit
M1400_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M1400.AsymptoticLimits.mH125.root")
M1400_run2 = M1400_events_run2["limit"].arrays(['limit']).limit
M1600_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M1600.AsymptoticLimits.mH125.root")
M1600_run2 = M1600_events_run2["limit"].arrays(['limit']).limit
M1800_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M1800.AsymptoticLimits.mH125.root")
M1800_run2 = M1800_events_run2["limit"].arrays(['limit']).limit
M2000_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M2000.AsymptoticLimits.mH125.root")
M2000_run2 = M2000_events_run2["limit"].arrays(['limit']).limit
M2200_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M2200.AsymptoticLimits.mH125.root")
M2200_run2 = M2200_events_run2["limit"].arrays(['limit']).limit
M2400_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M2400.AsymptoticLimits.mH125.root")
M2400_run2 = M2400_events_run2["limit"].arrays(['limit']).limit
M2600_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M2600.AsymptoticLimits.mH125.root")
M2600_run2 = M2600_events_run2["limit"].arrays(['limit']).limit
M3000_events_run2 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M3000.AsymptoticLimits.mH125.root")
M3000_run2 = M3000_events_run2["limit"].arrays(['limit']).limit

M250_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M250wwgg.AsymptoticLimits.mH125.root")
M250_wwgg = M250_events_wwgg["limit"].arrays(['limit']).limit*100
M350_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M350wwgg.AsymptoticLimits.mH125.root")
M350_wwgg = M350_events_wwgg["limit"].arrays(['limit']).limit*100
M450_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M450wwgg.AsymptoticLimits.mH125.root")
M450_wwgg = M450_events_wwgg["limit"].arrays(['limit']).limit*100
M550_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M550wwgg.AsymptoticLimits.mH125.root")
M550_wwgg = M550_events_wwgg["limit"].arrays(['limit']).limit*100
M600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M600wwgg.AsymptoticLimits.mH125.root")
M600_wwgg = M600_events_wwgg["limit"].arrays(['limit']).limit*100
M700_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M700wwgg.AsymptoticLimits.mH125.root")
M700_wwgg = M700_events_wwgg["limit"].arrays(['limit']).limit*100
M850_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M850wwgg.AsymptoticLimits.mH125.root")
M850_wwgg = M850_events_wwgg["limit"].arrays(['limit']).limit*100
M1000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M1000wwgg.AsymptoticLimits.mH125.root")
M1000_wwgg = M1000_events_wwgg["limit"].arrays(['limit']).limit*100
M1200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M1200wwgg.AsymptoticLimits.mH125.root")
M1200_wwgg = M1200_events_wwgg["limit"].arrays(['limit']).limit
M1400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M1400wwgg.AsymptoticLimits.mH125.root")
M1400_wwgg = M1400_events_wwgg["limit"].arrays(['limit']).limit
M1600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M1600wwgg.AsymptoticLimits.mH125.root")
M1600_wwgg = M1600_events_wwgg["limit"].arrays(['limit']).limit
M1800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M1800wwgg.AsymptoticLimits.mH125.root")
M1800_wwgg = M1800_events_wwgg["limit"].arrays(['limit']).limit
M2000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M2000wwgg.AsymptoticLimits.mH125.root")
M2000_wwgg = M2000_events_wwgg["limit"].arrays(['limit']).limit
M2200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M2200wwgg.AsymptoticLimits.mH125.root")
M2200_wwgg = M2200_events_wwgg["limit"].arrays(['limit']).limit
M2400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M2400wwgg.AsymptoticLimits.mH125.root")
M2400_wwgg = M2400_events_wwgg["limit"].arrays(['limit']).limit
M2600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M2600wwgg.AsymptoticLimits.mH125.root")
M2600_wwgg = M2600_events_wwgg["limit"].arrays(['limit']).limit
M3000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinedatacard_M3000wwgg.AsymptoticLimits.mH125.root")
M3000_wwgg = M3000_events_wwgg["limit"].arrays(['limit']).limit

hep.style.use(hep.style.CMS)
hep.cms.label("preliminary", data=True, lumi=138)   
# set figure size
plt.rcParams["figure.figsize"] = (20,20)
allcat_values = [250,350,450,550,600,700,850,1000,1200,1400,1600,1800,2000,2200,2400,2600,3000]
plt.plot(allcat_values, [M250_run2[2],M350_run2[2],M450_run2[2],M550_run2[2],M600_run2[2],M700_run2[2],M850_run2[2],M1000_run2[2],M1200_run2[2],M1400_run2[2],M1600_run2[2],M1800_run2[2],M2000_run2[2],M2200_run2[2],M2400_run2[2],M2600_run2[2],M3000_run2[2]],color='black', linewidth=2,linestyle='-', label='WWgg + ZZgg + bbgg Signal')#'Asymptotic Limits CLs expected'
plt.plot(allcat_values, [M250_wwgg[2],M350_wwgg[2],M450_wwgg[2],M550_wwgg[2],M600_wwgg[2],M700_wwgg[2],M850_wwgg[2],M1000_wwgg[2],M1200_wwgg[2],M1400_wwgg[2],M1600_wwgg[2],M1800_wwgg[2],M2000_wwgg[2],M2200_wwgg[2],M2400_wwgg[2],M2600_wwgg[2],M3000_wwgg[2]],color='blue', linewidth=2,linestyle='--', label='WWgg Signal')#'Asymptotic Limits CLs expected'
# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M250_run2[1],M350_run2[1],M450_run2[1],M550_run2[1],M600_run2[1],M700_run2[1],M850_run2[1],M1000_run2[1],M1200_run2[1],M1400_run2[1],M1600_run2[1],M1800_run2[1],M2000_run2[1],M2200_run2[1],M2400_run2[1],M2600_run2[1],M3000_run2[1]], [M250_run2[3],M350_run2[3],M450_run2[3],M550_run2[3],M600_run2[3],M700_run2[3],M850_run2[3],M1000_run2[3],M1200_run2[3],M1400_run2[3],M1600_run2[3],M1800_run2[3],M2000_run2[3],M2200_run2[3],M2400_run2[3],M2600_run2[3],M3000_run2[3]], color='#04cb02', alpha=1, label= r'68% expected')#label= r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M250_run2[0],M350_run2[0],M450_run2[0],M550_run2[0],M600_run2[0],M700_run2[0],M850_run2[0],M1000_run2[0],M1200_run2[0],M1400_run2[0],M1600_run2[0],M1800_run2[0],M2000_run2[0],M2200_run2[0],M2400_run2[0],M2600_run2[0],M3000_run2[0]],[M250_run2[1],M350_run2[1],M450_run2[1],M550_run2[1],M600_run2[1],M700_run2[1],M850_run2[1],M1000_run2[1],M1200_run2[1],M1400_run2[1],M1600_run2[1],M1800_run2[1],M2000_run2[1],M2200_run2[1],M2400_run2[1],M2600_run2[1],M3000_run2[1]], color='gold', alpha=1, label=r'95%expected')#label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_run2[3],M350_run2[3],M450_run2[3],M550_run2[3],M600_run2[3],M700_run2[3],M850_run2[3],M1000_run2[3],M1200_run2[3],M1400_run2[3],M1600_run2[3],M1800_run2[3],M2000_run2[3],M2200_run2[3],M2400_run2[3],M2600_run2[3],M3000_run2[3]],  [M250_run2[4],M350_run2[4],M450_run2[4],M550_run2[4],M600_run2[4],M700_run2[4],M850_run2[4],M1000_run2[4],M1200_run2[4],M1400_run2[4],M1600_run2[4],M1800_run2[4],M2000_run2[4],M2200_run2[4],M2400_run2[4],M2600_run2[4],M3000_run2[4]], color='gold', alpha=1)

plt.xlabel(r'Radion Mass (GeV)')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,3000)

# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,10000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(1., 0.95))

# %%
M250_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX250_MH125/higgsCombinecombineFHSL_2017_M250.AsymptoticLimits.mH125.root")
M250_2017 = M250_events_2017["limit"].arrays(['limit']).limit*100
M350_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX350_MH125/higgsCombinecombineFHSL_2017_M350.AsymptoticLimits.mH125.root")
M350_2017 = M350_events_2017["limit"].arrays(['limit']).limit*100
M450_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX450_MH125/higgsCombinecombineFHSL_2017_M450.AsymptoticLimits.mH125.root")
M450_2017 = M450_events_2017["limit"].arrays(['limit']).limit*100
M550_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX550_MH125/higgsCombinecombineFHSL_2017_M550.AsymptoticLimits.mH125.root")
M550_2017 = M550_events_2017["limit"].arrays(['limit']).limit*100
M600_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX600_MH125/higgsCombinecombineFHSL_2017_M600.AsymptoticLimits.mH125.root")
M600_2017 = M600_events_2017["limit"].arrays(['limit']).limit*100
M700_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX700_MH125/higgsCombinecombineFHSL_2017_M700.AsymptoticLimits.mH125.root")
M700_2017 = M700_events_2017["limit"].arrays(['limit']).limit*100
M850_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX850_MH125/higgsCombinecombineFHSL_2017_M850.AsymptoticLimits.mH125.root")
M850_2017 = M850_events_2017["limit"].arrays(['limit']).limit*100
M1000_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1000_MH125/higgsCombinecombineFHSL_2017_M1000.AsymptoticLimits.mH125.root")
M1000_2017 = M1000_events_2017["limit"].arrays(['limit']).limit*100
M1200_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1200_MH125/higgsCombinecombineFHSL_2017_M1200.AsymptoticLimits.mH125.root")
M1200_2017 = M1200_events_2017["limit"].arrays(['limit']).limit
M1400_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1400_MH125/higgsCombinecombineFHSL_2017_M1400.AsymptoticLimits.mH125.root")
M1400_2017 = M1400_events_2017["limit"].arrays(['limit']).limit
M1600_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1600_MH125/higgsCombinecombineFHSL_2017_M1600.AsymptoticLimits.mH125.root")
M1600_2017 = M1600_events_2017["limit"].arrays(['limit']).limit
M1800_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1800_MH125/higgsCombinecombineFHSL_2017_M1800.AsymptoticLimits.mH125.root")
M1800_2017 = M1800_events_2017["limit"].arrays(['limit']).limit
M2000_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2000_MH125/higgsCombinecombineFHSL_2017_M2000.AsymptoticLimits.mH125.root")
M2000_2017 = M2000_events_2017["limit"].arrays(['limit']).limit
M2200_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2200_MH125/higgsCombinecombineFHSL_2017_M2200.AsymptoticLimits.mH125.root")
M2200_2017 = M2200_events_2017["limit"].arrays(['limit']).limit
M2400_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2400_MH125/higgsCombinecombineFHSL_2017_M2400.AsymptoticLimits.mH125.root")
M2400_2017 = M2400_events_2017["limit"].arrays(['limit']).limit
M2600_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2600_MH125/higgsCombinecombineFHSL_2017_M2600.AsymptoticLimits.mH125.root")
M2600_2017 = M2600_events_2017["limit"].arrays(['limit']).limit
M3000_events_2017 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX3000_MH125/higgsCombinecombineFHSL_2017_M3000.AsymptoticLimits.mH125.root")
M3000_2017 = M3000_events_2017["limit"].arrays(['limit']).limit


M250_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX250_MH125/higgsCombineDatacard_M250_2017wwgg.AsymptoticLimits.mH125.root")
M250_wwgg = M250_events_wwgg["limit"].arrays(['limit']).limit*100
M350_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX350_MH125/higgsCombineDatacard_M350_2017wwgg.AsymptoticLimits.mH125.root")
M350_wwgg = M350_events_wwgg["limit"].arrays(['limit']).limit*100
M450_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX450_MH125/higgsCombineDatacard_M450_2017wwgg.AsymptoticLimits.mH125.root")
M450_wwgg = M450_events_wwgg["limit"].arrays(['limit']).limit*100
M550_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX550_MH125/higgsCombineDatacard_M550_2017wwgg.AsymptoticLimits.mH125.root")
M550_wwgg = M550_events_wwgg["limit"].arrays(['limit']).limit*100
M600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX600_MH125/higgsCombineDatacard_M600_2017wwgg.AsymptoticLimits.mH125.root")
M600_wwgg = M600_events_wwgg["limit"].arrays(['limit']).limit*100
M700_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX700_MH125/higgsCombineDatacard_M700_2017wwgg.AsymptoticLimits.mH125.root")
M700_wwgg = M700_events_wwgg["limit"].arrays(['limit']).limit*100
M850_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX850_MH125/higgsCombineDatacard_M850_2017wwgg.AsymptoticLimits.mH125.root")
M850_wwgg = M850_events_wwgg["limit"].arrays(['limit']).limit*100
M1000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1000_MH125/higgsCombineDatacard_M1000_2017wwgg.AsymptoticLimits.mH125.root")
M1000_wwgg = M1000_events_wwgg["limit"].arrays(['limit']).limit*100
M1200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1200_MH125/higgsCombineDatacard_M1200_2017wwgg.AsymptoticLimits.mH125.root")
M1200_wwgg = M1200_events_wwgg["limit"].arrays(['limit']).limit
M1400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1400_MH125/higgsCombineDatacard_M1400_2017wwgg.AsymptoticLimits.mH125.root")
M1400_wwgg = M1400_events_wwgg["limit"].arrays(['limit']).limit
M1600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1600_MH125/higgsCombineDatacard_M1600_2017wwgg.AsymptoticLimits.mH125.root")
M1600_wwgg = M1600_events_wwgg["limit"].arrays(['limit']).limit
M1800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1800_MH125/higgsCombineDatacard_M1800_2017wwgg.AsymptoticLimits.mH125.root")
M1800_wwgg = M1800_events_wwgg["limit"].arrays(['limit']).limit
M2000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2000_MH125/higgsCombineDatacard_M2000_2017wwgg.AsymptoticLimits.mH125.root")
M2000_wwgg = M2000_events_wwgg["limit"].arrays(['limit']).limit
M2200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2200_MH125/higgsCombineDatacard_M2200_2017wwgg.AsymptoticLimits.mH125.root")
M2200_wwgg = M2200_events_wwgg["limit"].arrays(['limit']).limit
M2400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2400_MH125/higgsCombineDatacard_M2400_2017wwgg.AsymptoticLimits.mH125.root")
M2400_wwgg = M2400_events_wwgg["limit"].arrays(['limit']).limit
M2600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2600_MH125/higgsCombineDatacard_M2600_2017wwgg.AsymptoticLimits.mH125.root")
M2600_wwgg = M2600_events_wwgg["limit"].arrays(['limit']).limit
M3000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX3000_MH125/higgsCombineDatacard_M3000_2017wwgg.AsymptoticLimits.mH125.root")
M3000_wwgg = M3000_events_wwgg["limit"].arrays(['limit']).limit

hep.style.use(hep.style.CMS)
hep.cms.label("preliminary", data=True, lumi=41.5)   
# set figure size
plt.rcParams["figure.figsize"] = (20,20)
allcat_values = [250,350,450,550,600,700,850,1000,1200,1400,1600,1800,2000,2200,2400,2600,3000]
plt.plot(allcat_values, [M250_2017[2],M350_2017[2],M450_2017[2],M550_2017[2],M600_2017[2],M700_2017[2],M850_2017[2],M1000_2017[2],M1200_2017[2],M1400_2017[2],M1600_2017[2],M1800_2017[2],M2000_2017[2],M2200_2017[2],M2400_2017[2],M2600_2017[2],M3000_2017[2]],color='black', linewidth=2,linestyle='-', label='WWgg + ZZgg + bbgg Signal')#'Asymptotic Limits CLs expected'
plt.plot(allcat_values, [M250_wwgg[2],M350_wwgg[2],M450_wwgg[2],M550_wwgg[2],M600_wwgg[2],M700_wwgg[2],M850_wwgg[2],M1000_wwgg[2],M1200_wwgg[2],M1400_wwgg[2],M1600_wwgg[2],M1800_wwgg[2],M2000_wwgg[2],M2200_wwgg[2],M2400_wwgg[2],M2600_wwgg[2],M3000_wwgg[2]],color='blue', linewidth=2,linestyle='--', label='WWgg Signal')#'Asymptotic Limits CLs expected'
# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M250_2017[1],M350_2017[1],M450_2017[1],M550_2017[1],M600_2017[1],M700_2017[1],M850_2017[1],M1000_2017[1],M1200_2017[1],M1400_2017[1],M1600_2017[1],M1800_2017[1],M2000_2017[1],M2200_2017[1],M2400_2017[1],M2600_2017[1],M3000_2017[1]], [M250_2017[3],M350_2017[3],M450_2017[3],M550_2017[3],M600_2017[3],M700_2017[3],M850_2017[3],M1000_2017[3],M1200_2017[3],M1400_2017[3],M1600_2017[3],M1800_2017[3],M2000_2017[3],M2200_2017[3],M2400_2017[3],M2600_2017[3],M3000_2017[3]], color='#04cb02', alpha=1, label= r'68% expected')#label= r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M250_2017[0],M350_2017[0],M450_2017[0],M550_2017[0],M600_2017[0],M700_2017[0],M850_2017[0],M1000_2017[0],M1200_2017[0],M1400_2017[0],M1600_2017[0],M1800_2017[0],M2000_2017[0],M2200_2017[0],M2400_2017[0],M2600_2017[0],M3000_2017[0]],[M250_2017[1],M350_2017[1],M450_2017[1],M550_2017[1],M600_2017[1],M700_2017[1],M850_2017[1],M1000_2017[1],M1200_2017[1],M1400_2017[1],M1600_2017[1],M1800_2017[1],M2000_2017[1],M2200_2017[1],M2400_2017[1],M2600_2017[1],M3000_2017[1]], color='gold', alpha=1, label=r'95%expected')#label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_2017[3],M350_2017[3],M450_2017[3],M550_2017[3],M600_2017[3],M700_2017[3],M850_2017[3],M1000_2017[3],M1200_2017[3],M1400_2017[3],M1600_2017[3],M1800_2017[3],M2000_2017[3],M2200_2017[3],M2400_2017[3],M2600_2017[3],M3000_2017[3]],  [M250_2017[4],M350_2017[4],M450_2017[4],M550_2017[4],M600_2017[4],M700_2017[4],M850_2017[4],M1000_2017[4],M1200_2017[4],M1400_2017[4],M1600_2017[4],M1800_2017[4],M2000_2017[4],M2200_2017[4],M2400_2017[4],M2600_2017[4],M3000_2017[4]], color='gold', alpha=1)

plt.xlabel(r'Radion Mass (GeV)')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,3000)

# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,100000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(1., 0.95))

# %%
M250_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX250_MH125/higgsCombinecombineFHSL_2018_M250.AsymptoticLimits.mH125.root")
M250_2018 = M250_events_2018["limit"].arrays(['limit']).limit*100
M350_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX350_MH125/higgsCombinecombineFHSL_2018_M350.AsymptoticLimits.mH125.root")
M350_2018 = M350_events_2018["limit"].arrays(['limit']).limit*100
M450_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX450_MH125/higgsCombinecombineFHSL_2018_M450.AsymptoticLimits.mH125.root")
M450_2018 = M450_events_2018["limit"].arrays(['limit']).limit*100
M550_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX550_MH125/higgsCombinecombineFHSL_2018_M550.AsymptoticLimits.mH125.root")
M550_2018 = M550_events_2018["limit"].arrays(['limit']).limit*100
M600_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX600_MH125/higgsCombinecombineFHSL_2018_M600.AsymptoticLimits.mH125.root")
M600_2018 = M600_events_2018["limit"].arrays(['limit']).limit*100
M700_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX700_MH125/higgsCombinecombineFHSL_2018_M700.AsymptoticLimits.mH125.root")
M700_2018 = M700_events_2018["limit"].arrays(['limit']).limit*100
M850_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX850_MH125/higgsCombinecombineFHSL_2018_M850.AsymptoticLimits.mH125.root")
M850_2018 = M850_events_2018["limit"].arrays(['limit']).limit*100
M1000_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1000_MH125/higgsCombinecombineFHSL_2018_M1000.AsymptoticLimits.mH125.root")
M1000_2018 = M1000_events_2018["limit"].arrays(['limit']).limit*100
M1200_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1200_MH125/higgsCombinecombineFHSL_2018_M1200.AsymptoticLimits.mH125.root")
M1200_2018 = M1200_events_2018["limit"].arrays(['limit']).limit
M1400_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1400_MH125/higgsCombinecombineFHSL_2018_M1400.AsymptoticLimits.mH125.root")
M1400_2018 = M1400_events_2018["limit"].arrays(['limit']).limit
M1600_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1600_MH125/higgsCombinecombineFHSL_2018_M1600.AsymptoticLimits.mH125.root")
M1600_2018 = M1600_events_2018["limit"].arrays(['limit']).limit
M1800_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1800_MH125/higgsCombinecombineFHSL_2018_M1800.AsymptoticLimits.mH125.root")
M1800_2018 = M1800_events_2018["limit"].arrays(['limit']).limit
M2000_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2000_MH125/higgsCombinecombineFHSL_2018_M2000.AsymptoticLimits.mH125.root")
M2000_2018 = M2000_events_2018["limit"].arrays(['limit']).limit
M2200_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2200_MH125/higgsCombinecombineFHSL_2018_M2200.AsymptoticLimits.mH125.root")
M2200_2018 = M2200_events_2018["limit"].arrays(['limit']).limit
M2400_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2400_MH125/higgsCombinecombineFHSL_2018_M2400.AsymptoticLimits.mH125.root")
M2400_2018 = M2400_events_2018["limit"].arrays(['limit']).limit
M2600_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2600_MH125/higgsCombinecombineFHSL_2018_M2600.AsymptoticLimits.mH125.root")
M2600_2018 = M2600_events_2018["limit"].arrays(['limit']).limit
M3000_events_2018 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX3000_MH125/higgsCombinecombineFHSL_2018_M3000.AsymptoticLimits.mH125.root")
M3000_2018 = M3000_events_2018["limit"].arrays(['limit']).limit


M250_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX250_MH125/higgsCombineDatacard_M250_2018wwgg.AsymptoticLimits.mH125.root")
M250_wwgg = M250_events_wwgg["limit"].arrays(['limit']).limit*100
M350_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX350_MH125/higgsCombineDatacard_M350_2018wwgg.AsymptoticLimits.mH125.root")
M350_wwgg = M350_events_wwgg["limit"].arrays(['limit']).limit*100
M450_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX450_MH125/higgsCombineDatacard_M450_2018wwgg.AsymptoticLimits.mH125.root")
M450_wwgg = M450_events_wwgg["limit"].arrays(['limit']).limit*100
M550_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX550_MH125/higgsCombineDatacard_M550_2018wwgg.AsymptoticLimits.mH125.root")
M550_wwgg = M550_events_wwgg["limit"].arrays(['limit']).limit*100
M600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX600_MH125/higgsCombineDatacard_M600_2018wwgg.AsymptoticLimits.mH125.root")
M600_wwgg = M600_events_wwgg["limit"].arrays(['limit']).limit*100
M700_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX700_MH125/higgsCombineDatacard_M700_2018wwgg.AsymptoticLimits.mH125.root")
M700_wwgg = M700_events_wwgg["limit"].arrays(['limit']).limit*100
M850_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX850_MH125/higgsCombineDatacard_M850_2018wwgg.AsymptoticLimits.mH125.root")
M850_wwgg = M850_events_wwgg["limit"].arrays(['limit']).limit*100
M1000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1000_MH125/higgsCombineDatacard_M1000_2018wwgg.AsymptoticLimits.mH125.root")
M1000_wwgg = M1000_events_wwgg["limit"].arrays(['limit']).limit*100
M1200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1200_MH125/higgsCombineDatacard_M1200_2018wwgg.AsymptoticLimits.mH125.root")
M1200_wwgg = M1200_events_wwgg["limit"].arrays(['limit']).limit
M1400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1400_MH125/higgsCombineDatacard_M1400_2018wwgg.AsymptoticLimits.mH125.root")
M1400_wwgg = M1400_events_wwgg["limit"].arrays(['limit']).limit
M1600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1600_MH125/higgsCombineDatacard_M1600_2018wwgg.AsymptoticLimits.mH125.root")
M1600_wwgg = M1600_events_wwgg["limit"].arrays(['limit']).limit
M1800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1800_MH125/higgsCombineDatacard_M1800_2018wwgg.AsymptoticLimits.mH125.root")
M1800_wwgg = M1800_events_wwgg["limit"].arrays(['limit']).limit
M2000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2000_MH125/higgsCombineDatacard_M2000_2018wwgg.AsymptoticLimits.mH125.root")
M2000_wwgg = M2000_events_wwgg["limit"].arrays(['limit']).limit
M2200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2200_MH125/higgsCombineDatacard_M2200_2018wwgg.AsymptoticLimits.mH125.root")
M2200_wwgg = M2200_events_wwgg["limit"].arrays(['limit']).limit
M2400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2400_MH125/higgsCombineDatacard_M2400_2018wwgg.AsymptoticLimits.mH125.root")
M2400_wwgg = M2400_events_wwgg["limit"].arrays(['limit']).limit
M2600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2600_MH125/higgsCombineDatacard_M2600_2018wwgg.AsymptoticLimits.mH125.root")
M2600_wwgg = M2600_events_wwgg["limit"].arrays(['limit']).limit
M3000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX3000_MH125/higgsCombineDatacard_M3000_2018wwgg.AsymptoticLimits.mH125.root")
M3000_wwgg = M3000_events_wwgg["limit"].arrays(['limit']).limit

hep.style.use(hep.style.CMS)
hep.cms.label("preliminary", data=True, lumi=59.83)   
# set figure size
plt.rcParams["figure.figsize"] = (20,20)
allcat_values = [250,350,450,550,600,700,850,1000,1200,1400,1600,1800,2000,2200,2400,2600,3000]
plt.plot(allcat_values, [M250_2018[2],M350_2018[2],M450_2018[2],M550_2018[2],M600_2018[2],M700_2018[2],M850_2018[2],M1000_2018[2],M1200_2018[2],M1400_2018[2],M1600_2018[2],M1800_2018[2],M2000_2018[2],M2200_2018[2],M2400_2018[2],M2600_2018[2],M3000_2018[2]],color='black', linewidth=2,linestyle='-', label='WWgg + ZZgg + bbgg Signal')#'Asymptotic Limits CLs expected'
plt.plot(allcat_values, [M250_wwgg[2],M350_wwgg[2],M450_wwgg[2],M550_wwgg[2],M600_wwgg[2],M700_wwgg[2],M850_wwgg[2],M1000_wwgg[2],M1200_wwgg[2],M1400_wwgg[2],M1600_wwgg[2],M1800_wwgg[2],M2000_wwgg[2],M2200_wwgg[2],M2400_wwgg[2],M2600_wwgg[2],M3000_wwgg[2]],color='blue', linewidth=2,linestyle='--', label='WWgg Signal')#'Asymptotic Limits CLs expected'
# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M250_2018[1],M350_2018[1],M450_2018[1],M550_2018[1],M600_2018[1],M700_2018[1],M850_2018[1],M1000_2018[1],M1200_2018[1],M1400_2018[1],M1600_2018[1],M1800_2018[1],M2000_2018[1],M2200_2018[1],M2400_2018[1],M2600_2018[1],M3000_2018[1]], [M250_2018[3],M350_2018[3],M450_2018[3],M550_2018[3],M600_2018[3],M700_2018[3],M850_2018[3],M1000_2018[3],M1200_2018[3],M1400_2018[3],M1600_2018[3],M1800_2018[3],M2000_2018[3],M2200_2018[3],M2400_2018[3],M2600_2018[3],M3000_2018[3]], color='#04cb02', alpha=1, label= r'68% expected')#label= r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M250_2018[0],M350_2018[0],M450_2018[0],M550_2018[0],M600_2018[0],M700_2018[0],M850_2018[0],M1000_2018[0],M1200_2018[0],M1400_2018[0],M1600_2018[0],M1800_2018[0],M2000_2018[0],M2200_2018[0],M2400_2018[0],M2600_2018[0],M3000_2018[0]],[M250_2018[1],M350_2018[1],M450_2018[1],M550_2018[1],M600_2018[1],M700_2018[1],M850_2018[1],M1000_2018[1],M1200_2018[1],M1400_2018[1],M1600_2018[1],M1800_2018[1],M2000_2018[1],M2200_2018[1],M2400_2018[1],M2600_2018[1],M3000_2018[1]], color='gold', alpha=1, label=r'95%expected')#label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_2018[3],M350_2018[3],M450_2018[3],M550_2018[3],M600_2018[3],M700_2018[3],M850_2018[3],M1000_2018[3],M1200_2018[3],M1400_2018[3],M1600_2018[3],M1800_2018[3],M2000_2018[3],M2200_2018[3],M2400_2018[3],M2600_2018[3],M3000_2018[3]],  [M250_2018[4],M350_2018[4],M450_2018[4],M550_2018[4],M600_2018[4],M700_2018[4],M850_2018[4],M1000_2018[4],M1200_2018[4],M1400_2018[4],M1600_2018[4],M1800_2018[4],M2000_2018[4],M2200_2018[4],M2400_2018[4],M2600_2018[4],M3000_2018[4]], color='gold', alpha=1)

plt.xlabel(r'Radion Mass (GeV)')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,3000)

# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,100000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(1., 0.95))

# %%
M250_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX250_MH125/higgsCombinecombineFHSL_2016pre_M250.AsymptoticLimits.mH125.root")
M250_2016pre = M250_events_2016pre["limit"].arrays(['limit']).limit*100
M350_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX350_MH125/higgsCombinecombineFHSL_2016pre_M350.AsymptoticLimits.mH125.root")
M350_2016pre = M350_events_2016pre["limit"].arrays(['limit']).limit*100
M450_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX450_MH125/higgsCombinecombineFHSL_2016pre_M450.AsymptoticLimits.mH125.root")
M450_2016pre = M450_events_2016pre["limit"].arrays(['limit']).limit*100
M550_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX550_MH125/higgsCombinecombineFHSL_2016pre_M550.AsymptoticLimits.mH125.root")
M550_2016pre = M550_events_2016pre["limit"].arrays(['limit']).limit*100
M600_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX600_MH125/higgsCombinecombineFHSL_2016pre_M600.AsymptoticLimits.mH125.root")
M600_2016pre = M600_events_2016pre["limit"].arrays(['limit']).limit*100
M700_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX700_MH125/higgsCombinecombineFHSL_2016pre_M700.AsymptoticLimits.mH125.root")
M700_2016pre = M700_events_2016pre["limit"].arrays(['limit']).limit*100
M850_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX850_MH125/higgsCombinecombineFHSL_2016pre_M850.AsymptoticLimits.mH125.root")
M850_2016pre = M850_events_2016pre["limit"].arrays(['limit']).limit*100
M1000_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1000_MH125/higgsCombinecombineFHSL_2016pre_M1000.AsymptoticLimits.mH125.root")
M1000_2016pre = M1000_events_2016pre["limit"].arrays(['limit']).limit*100
M1200_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1200_MH125/higgsCombinecombineFHSL_2016pre_M1200.AsymptoticLimits.mH125.root")
M1200_2016pre = M1200_events_2016pre["limit"].arrays(['limit']).limit
M1400_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1400_MH125/higgsCombinecombineFHSL_2016pre_M1400.AsymptoticLimits.mH125.root")
M1400_2016pre = M1400_events_2016pre["limit"].arrays(['limit']).limit
M1600_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1600_MH125/higgsCombinecombineFHSL_2016pre_M1600.AsymptoticLimits.mH125.root")
M1600_2016pre = M1600_events_2016pre["limit"].arrays(['limit']).limit
M1800_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1800_MH125/higgsCombinecombineFHSL_2016pre_M1800.AsymptoticLimits.mH125.root")
M1800_2016pre = M1800_events_2016pre["limit"].arrays(['limit']).limit
M2000_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2000_MH125/higgsCombinecombineFHSL_2016pre_M2000.AsymptoticLimits.mH125.root")
M2000_2016pre = M2000_events_2016pre["limit"].arrays(['limit']).limit
M2200_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2200_MH125/higgsCombinecombineFHSL_2016pre_M2200.AsymptoticLimits.mH125.root")
M2200_2016pre = M2200_events_2016pre["limit"].arrays(['limit']).limit
M2400_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2400_MH125/higgsCombinecombineFHSL_2016pre_M2400.AsymptoticLimits.mH125.root")
M2400_2016pre = M2400_events_2016pre["limit"].arrays(['limit']).limit
M2600_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2600_MH125/higgsCombinecombineFHSL_2016pre_M2600.AsymptoticLimits.mH125.root")
M2600_2016pre = M2600_events_2016pre["limit"].arrays(['limit']).limit
M3000_events_2016pre = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX3000_MH125/higgsCombinecombineFHSL_2016pre_M3000.AsymptoticLimits.mH125.root")
M3000_2016pre = M3000_events_2016pre["limit"].arrays(['limit']).limit


M250_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX250_MH125/higgsCombineDatacard_M250_2016prewwgg.AsymptoticLimits.mH125.root")
M250_wwgg = M250_events_wwgg["limit"].arrays(['limit']).limit*100
M350_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX350_MH125/higgsCombineDatacard_M350_2016prewwgg.AsymptoticLimits.mH125.root")
M350_wwgg = M350_events_wwgg["limit"].arrays(['limit']).limit*100
M450_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX450_MH125/higgsCombineDatacard_M450_2016prewwgg.AsymptoticLimits.mH125.root")
M450_wwgg = M450_events_wwgg["limit"].arrays(['limit']).limit*100
M550_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX550_MH125/higgsCombineDatacard_M550_2016prewwgg.AsymptoticLimits.mH125.root")
M550_wwgg = M550_events_wwgg["limit"].arrays(['limit']).limit*100
M600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX600_MH125/higgsCombineDatacard_M600_2016prewwgg.AsymptoticLimits.mH125.root")
M600_wwgg = M600_events_wwgg["limit"].arrays(['limit']).limit*100
M700_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX700_MH125/higgsCombineDatacard_M700_2016prewwgg.AsymptoticLimits.mH125.root")
M700_wwgg = M700_events_wwgg["limit"].arrays(['limit']).limit*100
M850_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX850_MH125/higgsCombineDatacard_M850_2016prewwgg.AsymptoticLimits.mH125.root")
M850_wwgg = M850_events_wwgg["limit"].arrays(['limit']).limit*100
M1000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1000_MH125/higgsCombineDatacard_M1000_2016prewwgg.AsymptoticLimits.mH125.root")
M1000_wwgg = M1000_events_wwgg["limit"].arrays(['limit']).limit*100
M1200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1200_MH125/higgsCombineDatacard_M1200_2016prewwgg.AsymptoticLimits.mH125.root")
M1200_wwgg = M1200_events_wwgg["limit"].arrays(['limit']).limit
M1400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1400_MH125/higgsCombineDatacard_M1400_2016prewwgg.AsymptoticLimits.mH125.root")
M1400_wwgg = M1400_events_wwgg["limit"].arrays(['limit']).limit
M1600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1600_MH125/higgsCombineDatacard_M1600_2016prewwgg.AsymptoticLimits.mH125.root")
M1600_wwgg = M1600_events_wwgg["limit"].arrays(['limit']).limit
M1800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1800_MH125/higgsCombineDatacard_M1800_2016prewwgg.AsymptoticLimits.mH125.root")
M1800_wwgg = M1800_events_wwgg["limit"].arrays(['limit']).limit
M2000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2000_MH125/higgsCombineDatacard_M2000_2016prewwgg.AsymptoticLimits.mH125.root")
M2000_wwgg = M2000_events_wwgg["limit"].arrays(['limit']).limit
M2200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2200_MH125/higgsCombineDatacard_M2200_2016prewwgg.AsymptoticLimits.mH125.root")
M2200_wwgg = M2200_events_wwgg["limit"].arrays(['limit']).limit
M2400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2400_MH125/higgsCombineDatacard_M2400_2016prewwgg.AsymptoticLimits.mH125.root")
M2400_wwgg = M2400_events_wwgg["limit"].arrays(['limit']).limit
M2600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2600_MH125/higgsCombineDatacard_M2600_2016prewwgg.AsymptoticLimits.mH125.root")
M2600_wwgg = M2600_events_wwgg["limit"].arrays(['limit']).limit
M3000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX3000_MH125/higgsCombineDatacard_M3000_2016prewwgg.AsymptoticLimits.mH125.root")
M3000_wwgg = M3000_events_wwgg["limit"].arrays(['limit']).limit

hep.style.use(hep.style.CMS)
hep.cms.label("preliminary", data=True, lumi=19.48)   
# set figure size
plt.rcParams["figure.figsize"] = (20,20)
allcat_values = [250,350,450,550,600,700,850,1000,1200,1400,1600,1800,2000,2200,2400,2600,3000]
plt.plot(allcat_values, [M250_2016pre[2],M350_2016pre[2],M450_2016pre[2],M550_2016pre[2],M600_2016pre[2],M700_2016pre[2],M850_2016pre[2],M1000_2016pre[2],M1200_2016pre[2],M1400_2016pre[2],M1600_2016pre[2],M1800_2016pre[2],M2000_2016pre[2],M2200_2016pre[2],M2400_2016pre[2],M2600_2016pre[2],M3000_2016pre[2]],color='black', linewidth=2,linestyle='-', label='WWgg + ZZgg + bbgg Signal')#'Asymptotic Limits CLs expected'
plt.plot(allcat_values, [M250_wwgg[2],M350_wwgg[2],M450_wwgg[2],M550_wwgg[2],M600_wwgg[2],M700_wwgg[2],M850_wwgg[2],M1000_wwgg[2],M1200_wwgg[2],M1400_wwgg[2],M1600_wwgg[2],M1800_wwgg[2],M2000_wwgg[2],M2200_wwgg[2],M2400_wwgg[2],M2600_wwgg[2],M3000_wwgg[2]],color='blue', linewidth=2,linestyle='--', label='WWgg Signal')#'Asymptotic Limits CLs expected'
# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M250_2016pre[1],M350_2016pre[1],M450_2016pre[1],M550_2016pre[1],M600_2016pre[1],M700_2016pre[1],M850_2016pre[1],M1000_2016pre[1],M1200_2016pre[1],M1400_2016pre[1],M1600_2016pre[1],M1800_2016pre[1],M2000_2016pre[1],M2200_2016pre[1],M2400_2016pre[1],M2600_2016pre[1],M3000_2016pre[1]], [M250_2016pre[3],M350_2016pre[3],M450_2016pre[3],M550_2016pre[3],M600_2016pre[3],M700_2016pre[3],M850_2016pre[3],M1000_2016pre[3],M1200_2016pre[3],M1400_2016pre[3],M1600_2016pre[3],M1800_2016pre[3],M2000_2016pre[3],M2200_2016pre[3],M2400_2016pre[3],M2600_2016pre[3],M3000_2016pre[3]], color='#04cb02', alpha=1, label= r'68% expected')#label= r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M250_2016pre[0],M350_2016pre[0],M450_2016pre[0],M550_2016pre[0],M600_2016pre[0],M700_2016pre[0],M850_2016pre[0],M1000_2016pre[0],M1200_2016pre[0],M1400_2016pre[0],M1600_2016pre[0],M1800_2016pre[0],M2000_2016pre[0],M2200_2016pre[0],M2400_2016pre[0],M2600_2016pre[0],M3000_2016pre[0]],[M250_2016pre[1],M350_2016pre[1],M450_2016pre[1],M550_2016pre[1],M600_2016pre[1],M700_2016pre[1],M850_2016pre[1],M1000_2016pre[1],M1200_2016pre[1],M1400_2016pre[1],M1600_2016pre[1],M1800_2016pre[1],M2000_2016pre[1],M2200_2016pre[1],M2400_2016pre[1],M2600_2016pre[1],M3000_2016pre[1]], color='gold', alpha=1, label=r'95%expected')#label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_2016pre[3],M350_2016pre[3],M450_2016pre[3],M550_2016pre[3],M600_2016pre[3],M700_2016pre[3],M850_2016pre[3],M1000_2016pre[3],M1200_2016pre[3],M1400_2016pre[3],M1600_2016pre[3],M1800_2016pre[3],M2000_2016pre[3],M2200_2016pre[3],M2400_2016pre[3],M2600_2016pre[3],M3000_2016pre[3]],  [M250_2016pre[4],M350_2016pre[4],M450_2016pre[4],M550_2016pre[4],M600_2016pre[4],M700_2016pre[4],M850_2016pre[4],M1000_2016pre[4],M1200_2016pre[4],M1400_2016pre[4],M1600_2016pre[4],M1800_2016pre[4],M2000_2016pre[4],M2200_2016pre[4],M2400_2016pre[4],M2600_2016pre[4],M3000_2016pre[4]], color='gold', alpha=1)

plt.xlabel(r'Radion Mass (GeV)')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,3000)

# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,100000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(1., 0.95))

# %%
M250_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX250_MH125/higgsCombinecombineFHSL_2016post_M250.AsymptoticLimits.mH125.root")
M250_2016post = M250_events_2016post["limit"].arrays(['limit']).limit*100
M350_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX350_MH125/higgsCombinecombineFHSL_2016post_M350.AsymptoticLimits.mH125.root")
M350_2016post = M350_events_2016post["limit"].arrays(['limit']).limit*100
M450_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX450_MH125/higgsCombinecombineFHSL_2016post_M450.AsymptoticLimits.mH125.root")
M450_2016post = M450_events_2016post["limit"].arrays(['limit']).limit*100
M550_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX550_MH125/higgsCombinecombineFHSL_2016post_M550.AsymptoticLimits.mH125.root")
M550_2016post = M550_events_2016post["limit"].arrays(['limit']).limit*100
M600_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX600_MH125/higgsCombinecombineFHSL_2016post_M600.AsymptoticLimits.mH125.root")
M600_2016post = M600_events_2016post["limit"].arrays(['limit']).limit*100
M700_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX700_MH125/higgsCombinecombineFHSL_2016post_M700.AsymptoticLimits.mH125.root")
M700_2016post = M700_events_2016post["limit"].arrays(['limit']).limit*100
M850_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX850_MH125/higgsCombinecombineFHSL_2016post_M850.AsymptoticLimits.mH125.root")
M850_2016post = M850_events_2016post["limit"].arrays(['limit']).limit*100
M1000_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1000_MH125/higgsCombinecombineFHSL_2016post_M1000.AsymptoticLimits.mH125.root")
M1000_2016post = M1000_events_2016post["limit"].arrays(['limit']).limit*100
M1200_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1200_MH125/higgsCombinecombineFHSL_2016post_M1200.AsymptoticLimits.mH125.root")
M1200_2016post = M1200_events_2016post["limit"].arrays(['limit']).limit
M1400_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1400_MH125/higgsCombinecombineFHSL_2016post_M1400.AsymptoticLimits.mH125.root")
M1400_2016post = M1400_events_2016post["limit"].arrays(['limit']).limit
M1600_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1600_MH125/higgsCombinecombineFHSL_2016post_M1600.AsymptoticLimits.mH125.root")
M1600_2016post = M1600_events_2016post["limit"].arrays(['limit']).limit
M1800_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1800_MH125/higgsCombinecombineFHSL_2016post_M1800.AsymptoticLimits.mH125.root")
M1800_2016post = M1800_events_2016post["limit"].arrays(['limit']).limit
M2000_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2000_MH125/higgsCombinecombineFHSL_2016post_M2000.AsymptoticLimits.mH125.root")
M2000_2016post = M2000_events_2016post["limit"].arrays(['limit']).limit
M2200_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2200_MH125/higgsCombinecombineFHSL_2016post_M2200.AsymptoticLimits.mH125.root")
M2200_2016post = M2200_events_2016post["limit"].arrays(['limit']).limit
M2400_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2400_MH125/higgsCombinecombineFHSL_2016post_M2400.AsymptoticLimits.mH125.root")
M2400_2016post = M2400_events_2016post["limit"].arrays(['limit']).limit
M2600_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2600_MH125/higgsCombinecombineFHSL_2016post_M2600.AsymptoticLimits.mH125.root")
M2600_2016post = M2600_events_2016post["limit"].arrays(['limit']).limit
M3000_events_2016post = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX3000_MH125/higgsCombinecombineFHSL_2016post_M3000.AsymptoticLimits.mH125.root")
M3000_2016post = M3000_events_2016post["limit"].arrays(['limit']).limit


M250_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX250_MH125/higgsCombineDatacard_M250_2016postwwgg.AsymptoticLimits.mH125.root")
M250_wwgg = M250_events_wwgg["limit"].arrays(['limit']).limit*100
M350_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX350_MH125/higgsCombineDatacard_M350_2016postwwgg.AsymptoticLimits.mH125.root")
M350_wwgg = M350_events_wwgg["limit"].arrays(['limit']).limit*100
M450_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX450_MH125/higgsCombineDatacard_M450_2016postwwgg.AsymptoticLimits.mH125.root")
M450_wwgg = M450_events_wwgg["limit"].arrays(['limit']).limit*100
M550_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX550_MH125/higgsCombineDatacard_M550_2016postwwgg.AsymptoticLimits.mH125.root")
M550_wwgg = M550_events_wwgg["limit"].arrays(['limit']).limit*100
M600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX600_MH125/higgsCombineDatacard_M600_2016postwwgg.AsymptoticLimits.mH125.root")
M600_wwgg = M600_events_wwgg["limit"].arrays(['limit']).limit*100
M700_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX700_MH125/higgsCombineDatacard_M700_2016postwwgg.AsymptoticLimits.mH125.root")
M700_wwgg = M700_events_wwgg["limit"].arrays(['limit']).limit*100
M850_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX850_MH125/higgsCombineDatacard_M850_2016postwwgg.AsymptoticLimits.mH125.root")
M850_wwgg = M850_events_wwgg["limit"].arrays(['limit']).limit*100
M1000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1000_MH125/higgsCombineDatacard_M1000_2016postwwgg.AsymptoticLimits.mH125.root")
M1000_wwgg = M1000_events_wwgg["limit"].arrays(['limit']).limit*100
M1200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1200_MH125/higgsCombineDatacard_M1200_2016postwwgg.AsymptoticLimits.mH125.root")
M1200_wwgg = M1200_events_wwgg["limit"].arrays(['limit']).limit
M1400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1400_MH125/higgsCombineDatacard_M1400_2016postwwgg.AsymptoticLimits.mH125.root")
M1400_wwgg = M1400_events_wwgg["limit"].arrays(['limit']).limit
M1600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1600_MH125/higgsCombineDatacard_M1600_2016postwwgg.AsymptoticLimits.mH125.root")
M1600_wwgg = M1600_events_wwgg["limit"].arrays(['limit']).limit
M1800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1800_MH125/higgsCombineDatacard_M1800_2016postwwgg.AsymptoticLimits.mH125.root")
M1800_wwgg = M1800_events_wwgg["limit"].arrays(['limit']).limit
M2000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2000_MH125/higgsCombineDatacard_M2000_2016postwwgg.AsymptoticLimits.mH125.root")
M2000_wwgg = M2000_events_wwgg["limit"].arrays(['limit']).limit
M2200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2200_MH125/higgsCombineDatacard_M2200_2016postwwgg.AsymptoticLimits.mH125.root")
M2200_wwgg = M2200_events_wwgg["limit"].arrays(['limit']).limit
M2400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2400_MH125/higgsCombineDatacard_M2400_2016postwwgg.AsymptoticLimits.mH125.root")
M2400_wwgg = M2400_events_wwgg["limit"].arrays(['limit']).limit
M2600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2600_MH125/higgsCombineDatacard_M2600_2016postwwgg.AsymptoticLimits.mH125.root")
M2600_wwgg = M2600_events_wwgg["limit"].arrays(['limit']).limit
M3000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX3000_MH125/higgsCombineDatacard_M3000_2016postwwgg.AsymptoticLimits.mH125.root")
M3000_wwgg = M3000_events_wwgg["limit"].arrays(['limit']).limit

hep.style.use(hep.style.CMS)
hep.cms.label("preliminary", data=True, lumi=16.76)   
# set figure size
plt.rcParams["figure.figsize"] = (20,20)
allcat_values = [250,350,450,550,600,700,850,1000,1200,1400,1600,1800,2000,2200,2400,2600,3000]
plt.plot(allcat_values, [M250_2016post[2],M350_2016post[2],M450_2016post[2],M550_2016post[2],M600_2016post[2],M700_2016post[2],M850_2016post[2],M1000_2016post[2],M1200_2016post[2],M1400_2016post[2],M1600_2016post[2],M1800_2016post[2],M2000_2016post[2],M2200_2016post[2],M2400_2016post[2],M2600_2016post[2],M3000_2016post[2]],color='black', linewidth=2,linestyle='-', label='WWgg + ZZgg + bbgg Signal')#'Asymptotic Limits CLs expected'
plt.plot(allcat_values, [M250_wwgg[2],M350_wwgg[2],M450_wwgg[2],M550_wwgg[2],M600_wwgg[2],M700_wwgg[2],M850_wwgg[2],M1000_wwgg[2],M1200_wwgg[2],M1400_wwgg[2],M1600_wwgg[2],M1800_wwgg[2],M2000_wwgg[2],M2200_wwgg[2],M2400_wwgg[2],M2600_wwgg[2],M3000_wwgg[2]],color='blue', linewidth=2,linestyle='--', label='WWgg Signal')#'Asymptotic Limits CLs expected'
# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M250_2016post[1],M350_2016post[1],M450_2016post[1],M550_2016post[1],M600_2016post[1],M700_2016post[1],M850_2016post[1],M1000_2016post[1],M1200_2016post[1],M1400_2016post[1],M1600_2016post[1],M1800_2016post[1],M2000_2016post[1],M2200_2016post[1],M2400_2016post[1],M2600_2016post[1],M3000_2016post[1]], [M250_2016post[3],M350_2016post[3],M450_2016post[3],M550_2016post[3],M600_2016post[3],M700_2016post[3],M850_2016post[3],M1000_2016post[3],M1200_2016post[3],M1400_2016post[3],M1600_2016post[3],M1800_2016post[3],M2000_2016post[3],M2200_2016post[3],M2400_2016post[3],M2600_2016post[3],M3000_2016post[3]], color='#04cb02', alpha=1, label= r'68% expected')#label= r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M250_2016post[0],M350_2016post[0],M450_2016post[0],M550_2016post[0],M600_2016post[0],M700_2016post[0],M850_2016post[0],M1000_2016post[0],M1200_2016post[0],M1400_2016post[0],M1600_2016post[0],M1800_2016post[0],M2000_2016post[0],M2200_2016post[0],M2400_2016post[0],M2600_2016post[0],M3000_2016post[0]],[M250_2016post[1],M350_2016post[1],M450_2016post[1],M550_2016post[1],M600_2016post[1],M700_2016post[1],M850_2016post[1],M1000_2016post[1],M1200_2016post[1],M1400_2016post[1],M1600_2016post[1],M1800_2016post[1],M2000_2016post[1],M2200_2016post[1],M2400_2016post[1],M2600_2016post[1],M3000_2016post[1]], color='gold', alpha=1, label=r'95%expected')#label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_2016post[3],M350_2016post[3],M450_2016post[3],M550_2016post[3],M600_2016post[3],M700_2016post[3],M850_2016post[3],M1000_2016post[3],M1200_2016post[3],M1400_2016post[3],M1600_2016post[3],M1800_2016post[3],M2000_2016post[3],M2200_2016post[3],M2400_2016post[3],M2600_2016post[3],M3000_2016post[3]],  [M250_2016post[4],M350_2016post[4],M450_2016post[4],M550_2016post[4],M600_2016post[4],M700_2016post[4],M850_2016post[4],M1000_2016post[4],M1200_2016post[4],M1400_2016post[4],M1600_2016post[4],M1800_2016post[4],M2000_2016post[4],M2200_2016post[4],M2400_2016post[4],M2600_2016post[4],M3000_2016post[4]], color='gold', alpha=1)

plt.xlabel(r'Radion Mass (GeV)')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,3000)

# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,100000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(1., 0.95))
