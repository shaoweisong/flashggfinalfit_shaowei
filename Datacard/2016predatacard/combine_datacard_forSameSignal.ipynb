# %%
import pandas as pd
import os
import subprocess
import glob
import uproot
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import awkward as ak
import mplhep as hep

# %%
def add_all_line(df, line):
    all_strings = ''
    for strings in df.iloc[line]:
        if type(strings) is str:
            all_strings += strings + '     '
    return all_strings

# %% [markdown]
# # resolved

# %%
cat_name = ['cat34FHlowpurity', 'cat34FHhighpurity','cat34SLhighpurity','cat34SLlowpurity']
mass_name=['MX250_MH125', 'MX260_MH125','MX270_MH125','MX280_MH125', 'MX300_MH125', 'MX320_MH125', 'MX350_MH125', 'MX400_MH125', 'MX450_MH125', 'MX500_MH125', 'MX550_MH125', 'MX600_MH125', 'MX650_MH125', 'MX700_MH125', 'MX750_MH125', 'MX800_MH125', 'MX850_MH125','MX1000_MH125']
# mass_name=['MX500_MH125']
#combine command
getlimit=[]
Combinecommand=[]
txttoroot=[]
cd = []
for cat in cat_name:
    for mass in mass_name: 
        print(mass,cat)
        mass_dir = "datacard_" + mass
        FHSLcat_path="/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/"+mass_dir+"/Datacard_"+mass+"_2016pre_combineFHSL_"+cat+".txt"
        bbggcat_path="/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/"+mass_dir+"/Datacard_"+mass+"_2016pre_bbgg_"+cat+".txt"
        zzggcat_path="/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/"+mass_dir+"/Datacard_"+mass+"_2016pre_zzgg_"+cat+".txt"
        FHSLws_path="/eos/cms/store/group/phys_b2g/shsong/flashggws/cat34/2016pre/"+mass+"/ws_gghh_"+mass+"_2016pre_combineFHSL_"+cat
        bbggws_path="/eos/cms/store/group/phys_b2g/shsong/flashggws/cat34/2016pre/"+mass+"/ws_gghh_"+mass+"_2016pre_bbgg_"+cat
        zzggws_path="/eos/cms/store/group/phys_b2g/shsong/flashggws/cat34/2016pre/"+mass+"/ws_gghh_"+mass+"_2016pre_zzgg_"+cat
        FHSLsignalmodel= glob.glob(os.path.join(FHSLws_path, 'CMS-HGG_sigfit_packaged_*.root')) 
        bbggsignalmodel= glob.glob(os.path.join(bbggws_path, 'CMS-HGG_sigfit_packaged_*.root'))
        zzggsignalmodel= glob.glob(os.path.join(zzggws_path, 'CMS-HGG_sigfit_packaged_*.root'))
        FHSLsignaltxt = os.path.getsize(FHSLcat_path) > 1000
        bbggsignaltxt = os.path.getsize(bbggcat_path) > 1000
        zzggsignaltxt = os.path.getsize(zzggcat_path) > 1000
        if len(FHSLsignalmodel)>0:
            if FHSLsignaltxt:
                FHSLsignalmodel = True
            else:
                FHSLsignalmodel = False
        else:
            FHSLsignalmodel = False
        if len(bbggsignalmodel)>0:
            if bbggsignaltxt:
                bbggsignalmodel = True
            else:
                bbggsignalmodel = False
        else:
            bbggsignalmodel = False
        if len(zzggsignalmodel)>0:
            if zzggsignaltxt:
                zzggsignalmodel = True
            else:
                zzggsignalmodel = False
        else:
            zzggsignalmodel = False
        if not os.path.exists(mass_dir):
            os.makedirs(mass_dir)
        destination_text_path = "/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/" + mass_dir + "/Datacard_" + mass + "_" + cat + ".txt"
        if os.path.exists(destination_text_path):
            os.remove(destination_text_path) 
        print(destination_text_path)
        # print(FHSLsignalmodel)
        # print(bbggsignalmodel)
        # print(zzggsignalmodel)
        if FHSLsignalmodel and not bbggsignalmodel and not zzggsignalmodel:
            print("FHSL",mass,cat)
            with open(FHSLcat_path, 'r') as source_file:
                        content = source_file.read()
            with open(destination_text_path, 'w') as destination_file:
                destination_file.write(content.replace("gghh_2016pre_hgg", "gghhWWgg_2016pre_hgg"))
        if FHSLsignalmodel and bbggsignalmodel and not zzggsignalmodel:
            print("FHSL and bbgg",mass,cat)
            with open(FHSLcat_path, 'r') as source_file:
                        content = source_file.read()
            with open(destination_text_path, 'w') as destination_file:
                destination_file.write(content.replace("gghh_2016pre_hgg", "gghhWWgg_2016pre_hgg"))
            separator = r'(?<!\*)\s+'

            df_FHSL = pd.read_table(FHSLcat_path, sep=separator, header=None, engine='python')
            df_FHSL = df_FHSL.replace('gghh_2016pre_hgg', 'gghhWWgg_2016pre_hgg')
            df_bbgg = pd.read_table(bbggcat_path, sep=separator, header=None, engine='python')
            df_bbgg = df_bbgg.replace('gghh_2016pre_hgg', 'gghhbbgg_2016pre_hgg')
            # df_zzgg = pd.read_table(zzggcat_path, sep=separator, header=None, engine='python')
            # df_zzgg = df_zzgg.replace('gghh_2016pre_hgg', 'gghhzzgg_2016pre_hgg')
            with open(destination_text_path, 'r') as file:
                lines = file.readlines()
                lines.insert(10, add_all_line(df_bbgg, 8).replace(" bbgg_"+cat+"_2016pre "," combineFHSL_"+cat+"_2016pre ") + "\n")
                lines[18]=(add_all_line(df_FHSL,15) + df_bbgg.iloc[15][1].replace("bbgg_"+cat+"_2016pre","combineFHSL_"+cat+"_2016pre")+ "\n")
                lines[19]=(add_all_line(df_FHSL,16) + df_bbgg.iloc[16][1]+ "\n")
                lines[20]=(add_all_line(df_FHSL,17) + str(int(df_bbgg.iloc[17][1])-1)+ "\n")
                lines[21]=(add_all_line(df_FHSL,18) + df_bbgg.iloc[18][1]+ "\n")
                lines[24]=(add_all_line(df_FHSL,20) + df_bbgg.iloc[20][2]+ "\n")
                lines[25]=(add_all_line(df_FHSL,21) + df_bbgg.iloc[21][2]+ "\n")
                lines[26]=(add_all_line(df_FHSL,22) + df_bbgg.iloc[22][2]+ "\n")
                lines[27]=(add_all_line(df_FHSL,23) + df_bbgg.iloc[23][2]+ "\n")
                lines[28]=(add_all_line(df_FHSL,24) + df_bbgg.iloc[24][2]+ "\n")
                lines[29]=(add_all_line(df_FHSL,25) + df_bbgg.iloc[25][2]+ "\n")
                lines[30]=(add_all_line(df_FHSL,26) + df_bbgg.iloc[26][2]+ "\n")
                lines[31]=(add_all_line(df_FHSL,27) + df_bbgg.iloc[27][2]+ "\n")
                lines[32]=(add_all_line(df_FHSL,28) + df_bbgg.iloc[28][2]+ "\n")
                lines[33]=(add_all_line(df_FHSL,29) + df_bbgg.iloc[29][2]+ "\n")
                lines[34]=(add_all_line(df_FHSL,30) + df_bbgg.iloc[30][2]+ "\n")
                lines[35]=(add_all_line(df_FHSL,31) + df_bbgg.iloc[31][2]+ "\n")
                lines[36]=(add_all_line(df_FHSL,32) + df_bbgg.iloc[32][2]+ "\n")
                lines[37]=(add_all_line(df_FHSL,33) + df_bbgg.iloc[33][2]+ "\n")
                lines[38]=(add_all_line(df_FHSL,34) + df_bbgg.iloc[34][2]+ "\n")
                lines[39]=(add_all_line(df_FHSL,35) + df_bbgg.iloc[35][2]+ "\n")
                lines[40]=(add_all_line(df_FHSL,36) + df_bbgg.iloc[36][2]+ "\n")
                lines[41]=(add_all_line(df_FHSL,37) + df_bbgg.iloc[37][2]+ "\n")
                lines[42]=(add_all_line(df_FHSL,38) + df_bbgg.iloc[38][2]+ "\n")
                lines[43]=(add_all_line(df_FHSL,39) + df_bbgg.iloc[39][2]+ "\n")
                lines[44]=(add_all_line(df_FHSL,40) + df_bbgg.iloc[40][2]+ "\n")
                lines[45]=(add_all_line(df_FHSL,41) + df_bbgg.iloc[41][2]+ "\n")
                # lines[46]=(add_all_line(df_FHSL,42) + df_bbgg.iloc[42][2]+ "\n")
                lines[47]=(add_all_line(df_FHSL,43) + df_bbgg.iloc[43][2]+ "\n")
                lines[48]=(add_all_line(df_FHSL,44) + df_bbgg.iloc[44][2]+ "\n")
                # lines[49]=(add_all_line(df_FHSL,45) + df_bbgg.iloc[45][2]+ "\n")
                
                with open(destination_text_path, 'w') as file:
                    file.writelines(lines)
        if FHSLsignalmodel and bbggsignalmodel and zzggsignalmodel:
            print("FHSL, bbgg, zzgg ",mass,cat)
            with open(FHSLcat_path, 'r') as source_file:
                        content = source_file.read()
            with open(destination_text_path, 'w') as destination_file:
                destination_file.write(content.replace("gghh_2016pre_hgg", "gghhWWgg_2016pre_hgg"))
            separator = r'(?<!\*)\s+'

            df_FHSL = pd.read_table(FHSLcat_path, sep=separator, header=None, engine='python')
            df_FHSL = df_FHSL.replace('gghh_2016pre_hgg', 'gghhWWgg_2016pre_hgg')
            df_bbgg = pd.read_table(bbggcat_path, sep=separator, header=None, engine='python')
            df_bbgg = df_bbgg.replace('gghh_2016pre_hgg', 'gghhbbgg_2016pre_hgg')
            df_zzgg = pd.read_table(zzggcat_path, sep=separator, header=None, engine='python')
            df_zzgg = df_zzgg.replace('gghh_2016pre_hgg', 'gghhzzgg_2016pre_hgg')
            with open(destination_text_path, 'r') as file:
                lines = file.readlines()
                lines.insert(10, add_all_line(df_bbgg, 8).replace(" bbgg_"+cat+"_2016pre "," combineFHSL_"+cat+"_2016pre ") + "\n")
                lines[18]=(add_all_line(df_FHSL,15) + df_bbgg.iloc[15][1].replace("bbgg_"+cat+"_2016pre","combineFHSL_"+cat+"_2016pre")+"     "+df_zzgg.iloc[15][1].replace("zzgg_"+cat+"_2016pre","combineFHSL_"+cat+"_2016pre")+ "\n")
                lines[19]=(add_all_line(df_FHSL,16) + df_bbgg.iloc[16][1]+"     "+df_zzgg.iloc[16][1]+ "\n")
                lines[20]=(add_all_line(df_FHSL,17) + str(int(df_bbgg.iloc[17][1])-1)+"     " +str(int(df_bbgg.iloc[17][1])-2)+ "\n")
                lines[21]=(add_all_line(df_FHSL,18) + df_bbgg.iloc[18][1]+"     "+df_zzgg.iloc[18][1]+ "\n")
                lines[24]=(add_all_line(df_FHSL,20) + df_bbgg.iloc[20][2]+"     "+df_zzgg.iloc[20][2]+ "\n")
                lines[25]=(add_all_line(df_FHSL,21) + df_bbgg.iloc[21][2]+"     "+df_zzgg.iloc[21][2]+ "\n")
                lines[26]=(add_all_line(df_FHSL,22) + df_bbgg.iloc[22][2]+"     "+df_zzgg.iloc[22][2]+ "\n")
                lines[27]=(add_all_line(df_FHSL,23) + df_bbgg.iloc[23][2]+"     "+df_zzgg.iloc[23][2]+ "\n")
                lines[28]=(add_all_line(df_FHSL,24) + df_bbgg.iloc[24][2]+"     "+df_zzgg.iloc[24][2]+ "\n")
                lines[29]=(add_all_line(df_FHSL,25) + df_bbgg.iloc[25][2]+"     "+df_zzgg.iloc[25][2]+ "\n")
                lines[30]=(add_all_line(df_FHSL,26) + df_bbgg.iloc[26][2]+"     "+df_zzgg.iloc[26][2]+ "\n")
                lines[31]=(add_all_line(df_FHSL,27) + df_bbgg.iloc[27][2]+"     "+df_zzgg.iloc[27][2]+ "\n")
                lines[32]=(add_all_line(df_FHSL,28) + df_bbgg.iloc[28][2]+"     "+df_zzgg.iloc[28][2]+ "\n")
                lines[33]=(add_all_line(df_FHSL,29) + df_bbgg.iloc[29][2]+"     "+df_zzgg.iloc[29][2]+ "\n")
                lines[34]=(add_all_line(df_FHSL,30) + df_bbgg.iloc[30][2]+"     "+df_zzgg.iloc[30][2]+ "\n")
                lines[35]=(add_all_line(df_FHSL,31) + df_bbgg.iloc[31][2]+"     "+df_zzgg.iloc[31][2]+ "\n")
                lines[36]=(add_all_line(df_FHSL,32) + df_bbgg.iloc[32][2]+"     "+df_zzgg.iloc[32][2]+ "\n")
                lines[37]=(add_all_line(df_FHSL,33) + df_bbgg.iloc[33][2]+"     "+df_zzgg.iloc[33][2]+ "\n")
                lines[38]=(add_all_line(df_FHSL,34) + df_bbgg.iloc[34][2]+"     "+df_zzgg.iloc[34][2]+ "\n")
                lines[39]=(add_all_line(df_FHSL,35) + df_bbgg.iloc[35][2]+"     "+df_zzgg.iloc[35][2]+ "\n")
                lines[40]=(add_all_line(df_FHSL,36) + df_bbgg.iloc[36][2]+"     "+df_zzgg.iloc[36][2]+ "\n")
                lines[41]=(add_all_line(df_FHSL,37) + df_bbgg.iloc[37][2]+"     "+df_zzgg.iloc[37][2]+ "\n")
                lines[42]=(add_all_line(df_FHSL,38) + df_bbgg.iloc[38][2]+"     "+df_zzgg.iloc[38][2]+ "\n")
                lines[43]=(add_all_line(df_FHSL,39) + df_bbgg.iloc[39][2]+"     "+df_zzgg.iloc[39][2]+ "\n")
                lines[44]=(add_all_line(df_FHSL,40) + df_bbgg.iloc[40][2]+"     "+df_zzgg.iloc[40][2]+ "\n")
                lines[45]=(add_all_line(df_FHSL,41) + df_bbgg.iloc[41][2]+"     "+df_zzgg.iloc[41][2]+ "\n")
                # lines[46]=(add_all_line(df_FHSL,42) + df_bbgg.iloc[42][2]+"     "+df_zzgg.iloc[42][2]+ "\n")
                lines[47]=(add_all_line(df_FHSL,43) + df_bbgg.iloc[43][2]+"     "+df_zzgg.iloc[43][2]+ "\n")
                lines[48]=(add_all_line(df_FHSL,44) + df_bbgg.iloc[44][2]+"     "+df_zzgg.iloc[44][2]+ "\n")
                # lines[49]=(add_all_line(df_FHSL,45) + df_bbgg.iloc[45][2]+"     "+df_zzgg.iloc[45][2]+ "\n")
                lines.insert(10, add_all_line(df_zzgg, 8).replace(" zzgg_"+cat+"_2016pre "," combineFHSL_"+cat+"_2016pre ") + "\n")
                with open(destination_text_path, 'w') as file:
                    file.writelines(lines)
        if FHSLsignalmodel and zzggsignalmodel and not bbggsignalmodel:
            print("FHSL and zzgg",mass,cat)
            with open(FHSLcat_path, 'r') as source_file:
                        content = source_file.read()
            with open(destination_text_path, 'w') as destination_file:
                destination_file.write(content.replace("gghh_2016pre_hgg", "gghhWWgg_2016pre_hgg"))
            separator = r'(?<!\*)\s+'

            df_FHSL = pd.read_table(FHSLcat_path, sep=separator, header=None, engine='python')
            df_FHSL = df_FHSL.replace('gghh_2016pre_hgg', 'gghhWWgg_2016pre_hgg')
            # df_bbgg = pd.read_table(bbggcat_path, sep=separator, header=None, engine='python')
            # df_bbgg = df_bbgg.replace('gghh_2016pre_hgg', 'gghhbbgg_2016pre_hgg')
            df_zzgg = pd.read_table(zzggcat_path, sep=separator, header=None, engine='python')
            df_zzgg = df_zzgg.replace('gghh_2016pre_hgg', 'gghhzzgg_2016pre_hgg')
            with open(destination_text_path, 'r') as file:
                lines = file.readlines()
                lines.insert(10, add_all_line(df_zzgg, 8).replace(" zzgg_"+cat+"_2016pre "," combineFHSL_"+cat+"_2016pre ") + "\n")
                lines[18]=(add_all_line(df_FHSL,15) + df_zzgg.iloc[15][1].replace("zzgg_"+cat+"_2016pre","combineFHSL_"+cat+"_2016pre")+ "\n")
                lines[19]=(add_all_line(df_FHSL,16) + df_zzgg.iloc[16][1]+ "\n")
                lines[20]=(add_all_line(df_FHSL,17) + str(int(df_zzgg.iloc[17][1])-1)+ "\n")
                lines[21]=(add_all_line(df_FHSL,18) + df_zzgg.iloc[18][1]+ "\n")
                lines[24]=(add_all_line(df_FHSL,20) + df_zzgg.iloc[20][2]+ "\n")
                lines[25]=(add_all_line(df_FHSL,21) + df_zzgg.iloc[21][2]+ "\n")
                lines[26]=(add_all_line(df_FHSL,22) + df_zzgg.iloc[22][2]+ "\n")
                lines[27]=(add_all_line(df_FHSL,23) + df_zzgg.iloc[23][2]+ "\n")
                lines[28]=(add_all_line(df_FHSL,24) + df_zzgg.iloc[24][2]+ "\n")
                lines[29]=(add_all_line(df_FHSL,25) + df_zzgg.iloc[25][2]+ "\n")
                lines[30]=(add_all_line(df_FHSL,26) + df_zzgg.iloc[26][2]+ "\n")
                lines[31]=(add_all_line(df_FHSL,27) + df_zzgg.iloc[27][2]+ "\n")
                lines[32]=(add_all_line(df_FHSL,28) + df_zzgg.iloc[28][2]+ "\n")
                lines[33]=(add_all_line(df_FHSL,29) + df_zzgg.iloc[29][2]+ "\n")
                lines[34]=(add_all_line(df_FHSL,30) + df_zzgg.iloc[30][2]+ "\n")
                lines[35]=(add_all_line(df_FHSL,31) + df_zzgg.iloc[31][2]+ "\n")
                lines[36]=(add_all_line(df_FHSL,32) + df_zzgg.iloc[32][2]+ "\n")
                lines[37]=(add_all_line(df_FHSL,33) + df_zzgg.iloc[33][2]+ "\n")
                lines[38]=(add_all_line(df_FHSL,34) + df_zzgg.iloc[34][2]+ "\n")
                lines[39]=(add_all_line(df_FHSL,35) + df_zzgg.iloc[35][2]+ "\n")
                lines[40]=(add_all_line(df_FHSL,36) + df_zzgg.iloc[36][2]+ "\n")
                lines[41]=(add_all_line(df_FHSL,37) + df_zzgg.iloc[37][2]+ "\n")
                lines[42]=(add_all_line(df_FHSL,38) + df_zzgg.iloc[38][2]+ "\n")
                lines[43]=(add_all_line(df_FHSL,39) + df_zzgg.iloc[39][2]+ "\n")
                lines[44]=(add_all_line(df_FHSL,40) + df_zzgg.iloc[40][2]+ "\n")
                lines[45]=(add_all_line(df_FHSL,41) + df_zzgg.iloc[41][2]+ "\n")
                # lines[46]=(add_all_line(df_FHSL,42) + df_zzgg.iloc[42][2]+ "\n")
                lines[47]=(add_all_line(df_FHSL,43) + df_zzgg.iloc[43][2]+ "\n")
                lines[48]=(add_all_line(df_FHSL,44) + df_zzgg.iloc[44][2]+ "\n")
                # lines[49]=(add_all_line(df_FHSL,45) + df_zzgg.iloc[45][2]+ "\n")
                with open(destination_text_path, 'w') as file:
                    file.writelines(lines)
# Out:
# MX250_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX250_MH125/Datacard_MX250_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX250_MH125 cat34FHlowpurity
# MX260_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX260_MH125/Datacard_MX260_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX260_MH125 cat34FHlowpurity
# MX270_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX270_MH125/Datacard_MX270_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX270_MH125 cat34FHlowpurity
# MX280_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX280_MH125/Datacard_MX280_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX280_MH125 cat34FHlowpurity
# MX300_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX300_MH125/Datacard_MX300_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX300_MH125 cat34FHlowpurity
# MX320_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX320_MH125/Datacard_MX320_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX320_MH125 cat34FHlowpurity
# MX350_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX350_MH125/Datacard_MX350_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX350_MH125 cat34FHlowpurity
# MX400_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX400_MH125/Datacard_MX400_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX400_MH125 cat34FHlowpurity
# MX450_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX450_MH125/Datacard_MX450_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX450_MH125 cat34FHlowpurity
# MX500_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX500_MH125/Datacard_MX500_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX500_MH125 cat34FHlowpurity
# MX550_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX550_MH125/Datacard_MX550_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX550_MH125 cat34FHlowpurity
# MX600_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX600_MH125/Datacard_MX600_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX600_MH125 cat34FHlowpurity
# MX650_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX650_MH125/Datacard_MX650_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX650_MH125 cat34FHlowpurity
# MX700_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX700_MH125/Datacard_MX700_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX700_MH125 cat34FHlowpurity
# MX750_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX750_MH125/Datacard_MX750_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX750_MH125 cat34FHlowpurity
# MX800_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX800_MH125/Datacard_MX800_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX800_MH125 cat34FHlowpurity
# MX850_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX850_MH125/Datacard_MX850_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX850_MH125 cat34FHlowpurity
# MX1000_MH125 cat34FHlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1000_MH125/Datacard_MX1000_MH125_cat34FHlowpurity.txt
# FHSL, bbgg, zzgg  MX1000_MH125 cat34FHlowpurity
# MX250_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX250_MH125/Datacard_MX250_MH125_cat34FHhighpurity.txt
# FHSL MX250_MH125 cat34FHhighpurity
# MX260_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX260_MH125/Datacard_MX260_MH125_cat34FHhighpurity.txt
# FHSL MX260_MH125 cat34FHhighpurity
# MX270_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX270_MH125/Datacard_MX270_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX270_MH125 cat34FHhighpurity
# MX280_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX280_MH125/Datacard_MX280_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX280_MH125 cat34FHhighpurity
# MX300_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX300_MH125/Datacard_MX300_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX300_MH125 cat34FHhighpurity
# MX320_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX320_MH125/Datacard_MX320_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX320_MH125 cat34FHhighpurity
# MX350_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX350_MH125/Datacard_MX350_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX350_MH125 cat34FHhighpurity
# MX400_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX400_MH125/Datacard_MX400_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX400_MH125 cat34FHhighpurity
# MX450_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX450_MH125/Datacard_MX450_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX450_MH125 cat34FHhighpurity
# MX500_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX500_MH125/Datacard_MX500_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX500_MH125 cat34FHhighpurity
# MX550_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX550_MH125/Datacard_MX550_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX550_MH125 cat34FHhighpurity
# MX600_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX600_MH125/Datacard_MX600_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX600_MH125 cat34FHhighpurity
# MX650_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX650_MH125/Datacard_MX650_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX650_MH125 cat34FHhighpurity
# MX700_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX700_MH125/Datacard_MX700_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX700_MH125 cat34FHhighpurity
# MX750_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX750_MH125/Datacard_MX750_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX750_MH125 cat34FHhighpurity
# MX800_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX800_MH125/Datacard_MX800_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX800_MH125 cat34FHhighpurity
# MX850_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX850_MH125/Datacard_MX850_MH125_cat34FHhighpurity.txt
# FHSL and zzgg MX850_MH125 cat34FHhighpurity
# MX1000_MH125 cat34FHhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1000_MH125/Datacard_MX1000_MH125_cat34FHhighpurity.txt
# FHSL MX1000_MH125 cat34FHhighpurity
# MX250_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX250_MH125/Datacard_MX250_MH125_cat34SLhighpurity.txt
# FHSL MX250_MH125 cat34SLhighpurity
# MX260_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX260_MH125/Datacard_MX260_MH125_cat34SLhighpurity.txt
# FHSL MX260_MH125 cat34SLhighpurity
# MX270_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX270_MH125/Datacard_MX270_MH125_cat34SLhighpurity.txt
# FHSL MX270_MH125 cat34SLhighpurity
# MX280_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX280_MH125/Datacard_MX280_MH125_cat34SLhighpurity.txt
# FHSL MX280_MH125 cat34SLhighpurity
# MX300_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX300_MH125/Datacard_MX300_MH125_cat34SLhighpurity.txt
# FHSL MX300_MH125 cat34SLhighpurity
# MX320_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX320_MH125/Datacard_MX320_MH125_cat34SLhighpurity.txt
# FHSL MX320_MH125 cat34SLhighpurity
# MX350_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX350_MH125/Datacard_MX350_MH125_cat34SLhighpurity.txt
# FHSL MX350_MH125 cat34SLhighpurity
# MX400_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX400_MH125/Datacard_MX400_MH125_cat34SLhighpurity.txt
# FHSL MX400_MH125 cat34SLhighpurity
# MX450_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX450_MH125/Datacard_MX450_MH125_cat34SLhighpurity.txt
# FHSL MX450_MH125 cat34SLhighpurity
# MX500_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX500_MH125/Datacard_MX500_MH125_cat34SLhighpurity.txt
# FHSL MX500_MH125 cat34SLhighpurity
# MX550_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX550_MH125/Datacard_MX550_MH125_cat34SLhighpurity.txt
# FHSL MX550_MH125 cat34SLhighpurity
# MX600_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX600_MH125/Datacard_MX600_MH125_cat34SLhighpurity.txt
# FHSL MX600_MH125 cat34SLhighpurity
# MX650_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX650_MH125/Datacard_MX650_MH125_cat34SLhighpurity.txt
# FHSL MX650_MH125 cat34SLhighpurity
# MX700_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX700_MH125/Datacard_MX700_MH125_cat34SLhighpurity.txt
# FHSL MX700_MH125 cat34SLhighpurity
# MX750_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX750_MH125/Datacard_MX750_MH125_cat34SLhighpurity.txt
# MX800_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX800_MH125/Datacard_MX800_MH125_cat34SLhighpurity.txt
# FHSL MX800_MH125 cat34SLhighpurity
# MX850_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX850_MH125/Datacard_MX850_MH125_cat34SLhighpurity.txt
# FHSL MX850_MH125 cat34SLhighpurity
# MX1000_MH125 cat34SLhighpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1000_MH125/Datacard_MX1000_MH125_cat34SLhighpurity.txt
# FHSL MX1000_MH125 cat34SLhighpurity
# MX250_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX250_MH125/Datacard_MX250_MH125_cat34SLlowpurity.txt
# FHSL and zzgg MX250_MH125 cat34SLlowpurity
# MX260_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX260_MH125/Datacard_MX260_MH125_cat34SLlowpurity.txt
# FHSL and zzgg MX260_MH125 cat34SLlowpurity
# MX270_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX270_MH125/Datacard_MX270_MH125_cat34SLlowpurity.txt
# FHSL and zzgg MX270_MH125 cat34SLlowpurity
# MX280_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX280_MH125/Datacard_MX280_MH125_cat34SLlowpurity.txt
# FHSL and zzgg MX280_MH125 cat34SLlowpurity
# MX300_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX300_MH125/Datacard_MX300_MH125_cat34SLlowpurity.txt
# FHSL and zzgg MX300_MH125 cat34SLlowpurity
# MX320_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX320_MH125/Datacard_MX320_MH125_cat34SLlowpurity.txt
# FHSL and zzgg MX320_MH125 cat34SLlowpurity
# MX350_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX350_MH125/Datacard_MX350_MH125_cat34SLlowpurity.txt
# FHSL and zzgg MX350_MH125 cat34SLlowpurity
# MX400_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX400_MH125/Datacard_MX400_MH125_cat34SLlowpurity.txt
# FHSL, bbgg, zzgg  MX400_MH125 cat34SLlowpurity
# MX450_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX450_MH125/Datacard_MX450_MH125_cat34SLlowpurity.txt
# FHSL and zzgg MX450_MH125 cat34SLlowpurity
# MX500_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX500_MH125/Datacard_MX500_MH125_cat34SLlowpurity.txt
# FHSL and zzgg MX500_MH125 cat34SLlowpurity
# MX550_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX550_MH125/Datacard_MX550_MH125_cat34SLlowpurity.txt
# FHSL MX550_MH125 cat34SLlowpurity
# MX600_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX600_MH125/Datacard_MX600_MH125_cat34SLlowpurity.txt
# FHSL MX600_MH125 cat34SLlowpurity
# MX650_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX650_MH125/Datacard_MX650_MH125_cat34SLlowpurity.txt
# FHSL MX650_MH125 cat34SLlowpurity
# MX700_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX700_MH125/Datacard_MX700_MH125_cat34SLlowpurity.txt
# FHSL MX700_MH125 cat34SLlowpurity
# MX750_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX750_MH125/Datacard_MX750_MH125_cat34SLlowpurity.txt
# MX800_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX800_MH125/Datacard_MX800_MH125_cat34SLlowpurity.txt
# FHSL MX800_MH125 cat34SLlowpurity
# MX850_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX850_MH125/Datacard_MX850_MH125_cat34SLlowpurity.txt
# FHSL MX850_MH125 cat34SLlowpurity
# MX1000_MH125 cat34SLlowpurity
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1000_MH125/Datacard_MX1000_MH125_cat34SLlowpurity.txt
# FHSL MX1000_MH125 cat34SLlowpurity

# %%
cat_name = ['cat12highpurity','cat12lowpurity']
mass_name=['MX1000_MH125','MX500_MH125','MX550_MH125','MX600_MH125','MX650_MH125','MX700_MH125','MX750_MH125','MX800_MH125','MX850_MH125', 'MX1100_MH125', 'MX1200_MH125', 'MX1300_MH125','MX1400_MH125','MX1500_MH125', 'MX1600_MH125', 'MX1700_MH125','MX1800_MH125','MX1900_MH125', 'MX2000_MH125', 'MX2200_MH125', 'MX2600_MH125', 'MX2800_MH125','MX2400_MH125','MX3000_MH125']
# mass_name=['MX1200_MH125']
#combine command
getlimit=[]
Combinecommand=[]
txttoroot=[]
cd = []
for cat in cat_name:
    for mass in mass_name: 
        mass_dir = "datacard_" + mass
        FHSLcat_path="/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/"+mass_dir+"/Datacard_"+mass+"_2016pre_combineFHSL_"+cat+".txt"
        bbggcat_path="/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/"+mass_dir+"/Datacard_"+mass+"_2016pre_bbgg_"+cat+".txt"
        zzggcat_path="/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/"+mass_dir+"/Datacard_"+mass+"_2016pre_zzgg_"+cat+".txt"
        FHSLws_path="/eos/cms/store/group/phys_b2g/shsong/flashggws/cat12/2016pre/"+mass+"/ws_gghh_"+mass+"_2016pre_combineFHSL_"+cat
        bbggws_path="/eos/cms/store/group/phys_b2g/shsong/flashggws/cat12/2016pre/"+mass+"/ws_gghh_"+mass+"_2016pre_bbgg_"+cat
        zzggws_path="/eos/cms/store/group/phys_b2g/shsong/flashggws/cat12/2016pre/"+mass+"/ws_gghh_"+mass+"_2016pre_zzgg_"+cat
        FHSLsignalmodel= glob.glob(os.path.join(FHSLws_path, 'CMS-HGG_sigfit_packaged_*.root'))
        bbggsignalmodel= glob.glob(os.path.join(bbggws_path, 'CMS-HGG_sigfit_packaged_*.root'))
        zzggsignalmodel= glob.glob(os.path.join(zzggws_path, 'CMS-HGG_sigfit_packaged_*.root'))
        FHSLsignaltxt = os.path.getsize(FHSLcat_path) > 1000
        bbggsignaltxt = os.path.getsize(bbggcat_path) > 1000
        zzggsignaltxt = os.path.getsize(zzggcat_path) > 1000
        if len(FHSLsignalmodel)>0:
            if FHSLsignaltxt:
                FHSLsignalmodel = True
            else:
                FHSLsignalmodel = False
        else:
            FHSLsignalmodel = False
        if len(bbggsignalmodel)>0:
            if bbggsignaltxt:
                bbggsignalmodel = True
            else:
                bbggsignalmodel = False
        else:
            bbggsignalmodel = False
        if len(zzggsignalmodel)>0:
            if zzggsignaltxt:
                zzggsignalmodel = True
            else:
                zzggsignalmodel = False
        else:
            zzggsignalmodel = False

        if not os.path.exists(mass_dir):
            os.makedirs(mass_dir)
        destination_text_path = "/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/" + mass_dir + "/Datacard_" + mass + "_" + cat + ".txt"
        if os.path.exists(destination_text_path):
            os.remove(destination_text_path) 
        print(destination_text_path)
        print(FHSLsignalmodel)
        print(bbggsignalmodel)
        print(zzggsignalmodel)
        if FHSLsignalmodel and not bbggsignalmodel and not zzggsignalmodel:
            print("FHSL",mass,cat)
            os.system("cp "+FHSLcat_path+" "+destination_text_path)

        if FHSLsignalmodel and bbggsignalmodel and not zzggsignalmodel:
            print("FHSL and bbgg",mass,cat)
            with open(FHSLcat_path, 'r') as source_file:
                        content = source_file.read()
            print(destination_text_path)
            with open(destination_text_path, 'w') as destination_file:
                destination_file.write(content.replace("gghh_2016pre_hgg", "gghhWWgg_2016pre_hgg"))
            separator = r'(?<!\*)\s+'

            df_FHSL = pd.read_table(FHSLcat_path, sep=separator, header=None, engine='python')
            df_FHSL = df_FHSL.replace('gghh_2016pre_hgg', 'gghhWWgg_2016pre_hgg')
            df_bbgg = pd.read_table(bbggcat_path, sep=separator, header=None, engine='python')
            df_bbgg = df_bbgg.replace('gghh_2016pre_hgg', 'gghhbbgg_2016pre_hgg')
            df_zzgg = pd.read_table(zzggcat_path, sep=separator, header=None, engine='python')
            df_zzgg = df_zzgg.replace('gghh_2016pre_hgg', 'gghhzzgg_2016pre_hgg')
            with open(destination_text_path, 'r') as file:
                lines = file.readlines()
                lines.insert(10, add_all_line(df_bbgg, 8).replace(" bbgg_"+cat+"_2016pre "," combineFHSL_"+cat+"_2016pre ") + "\n")
                lines[18]=(add_all_line(df_FHSL,15) + df_bbgg.iloc[15][1].replace("bbgg_"+cat+"_2016pre","combineFHSL_"+cat+"_2016pre")+ "\n")
                lines[19]=(add_all_line(df_FHSL,16) + df_bbgg.iloc[16][1]+ "\n")
                lines[20]=(add_all_line(df_FHSL,17) + str(int(df_bbgg.iloc[17][1])-1)+ "\n")
                lines[21]=(add_all_line(df_FHSL,18) + df_bbgg.iloc[18][1]+ "\n")
                lines[24]=(add_all_line(df_FHSL,20) + df_bbgg.iloc[20][2]+ "\n")
                lines[25]=(add_all_line(df_FHSL,21) + df_bbgg.iloc[21][2]+ "\n")
                lines[26]=(add_all_line(df_FHSL,22) + df_bbgg.iloc[22][2]+ "\n")
                lines[27]=(add_all_line(df_FHSL,23) + df_bbgg.iloc[23][2]+ "\n")
                lines[28]=(add_all_line(df_FHSL,24) + df_bbgg.iloc[24][2]+ "\n")
                lines[29]=(add_all_line(df_FHSL,25) + df_bbgg.iloc[25][2]+ "\n")
                lines[30]=(add_all_line(df_FHSL,26) + df_bbgg.iloc[26][2]+ "\n")
                lines[31]=(add_all_line(df_FHSL,27) + df_bbgg.iloc[27][2]+ "\n")
                lines[32]=(add_all_line(df_FHSL,28) + df_bbgg.iloc[28][2]+ "\n")
                lines[33]=(add_all_line(df_FHSL,29) + df_bbgg.iloc[29][2]+ "\n")
                lines[34]=(add_all_line(df_FHSL,30) + df_bbgg.iloc[30][2]+ "\n")
                lines[35]=(add_all_line(df_FHSL,31) + df_bbgg.iloc[31][2]+ "\n")
                lines[36]=(add_all_line(df_FHSL,32) + df_bbgg.iloc[32][2]+ "\n")
                lines[37]=(add_all_line(df_FHSL,33) + df_bbgg.iloc[33][2]+ "\n")
                lines[38]=(add_all_line(df_FHSL,34) + df_bbgg.iloc[34][2]+ "\n")
                lines[39]=(add_all_line(df_FHSL,35) + df_bbgg.iloc[35][2]+ "\n")
                lines[40]=(add_all_line(df_FHSL,36) + df_bbgg.iloc[36][2]+ "\n")
                lines[41]=(add_all_line(df_FHSL,37) + df_bbgg.iloc[37][2]+ "\n")
                lines[42]=(add_all_line(df_FHSL,38) + df_bbgg.iloc[38][2]+ "\n")
                lines[43]=(add_all_line(df_FHSL,39) + df_bbgg.iloc[39][2]+ "\n")
                lines[44]=(add_all_line(df_FHSL,40) + df_bbgg.iloc[40][2]+ "\n")
                lines[45]=(add_all_line(df_FHSL,41) + df_bbgg.iloc[41][2]+ "\n")
                # lines[46]=(add_all_line(df_FHSL,42) + df_bbgg.iloc[42][2]+ "\n")
                lines[47]=(add_all_line(df_FHSL,43) + df_bbgg.iloc[43][2]+ "\n")
                lines[48]=(add_all_line(df_FHSL,44) + df_bbgg.iloc[44][2]+ "\n")
                # lines[49]=(add_all_line(df_FHSL,45) + df_bbgg.iloc[45][2]+ "\n")
                # lines[50]=(add_all_line(df_FHSL,46) + df_bbgg.iloc[46][2]+ "\n")
                # lines[51]=(add_all_line(df_FHSL,47) + df_bbgg.iloc[47][2]+ "\n")
                
                with open(destination_text_path, 'w') as file:
                    file.writelines(lines)
        if FHSLsignalmodel and bbggsignalmodel and zzggsignalmodel:
            with open(FHSLcat_path, 'r') as source_file:
                        content = source_file.read()
            with open(destination_text_path, 'w') as destination_file:
                destination_file.write(content.replace("gghh_2016pre_hgg", "gghhWWgg_2016pre_hgg"))
            separator = r'(?<!\*)\s+'
            print(FHSLcat_path)
            df_FHSL = pd.read_table(FHSLcat_path, sep=separator, header=None, engine='python')
            df_FHSL = df_FHSL.replace('gghh_2016pre_hgg', 'gghhWWgg_2016pre_hgg')
            df_bbgg = pd.read_table(bbggcat_path, sep=separator, header=None, engine='python')
            df_bbgg = df_bbgg.replace('gghh_2016pre_hgg', 'gghhbbgg_2016pre_hgg')
            df_zzgg = pd.read_table(zzggcat_path, sep=separator, header=None, engine='python')
            df_zzgg = df_zzgg.replace('gghh_2016pre_hgg', 'gghhzzgg_2016pre_hgg')
            with open(destination_text_path, 'r') as file:
                lines = file.readlines()
                lines.insert(10, add_all_line(df_bbgg, 8).replace(" bbgg_"+cat+"_2016pre "," combineFHSL_"+cat+"_2016pre ") + "\n")
                lines[18]=(add_all_line(df_FHSL,15) + df_bbgg.iloc[15][1].replace("bbgg_"+cat+"_2016pre","combineFHSL_"+cat+"_2016pre")+"     "+df_zzgg.iloc[15][1].replace("zzgg_"+cat+"_2016pre","combineFHSL_"+cat+"_2016pre")+ "\n")
                lines[19]=(add_all_line(df_FHSL,16) + df_bbgg.iloc[16][1]+"     "+df_zzgg.iloc[16][1]+ "\n")
                lines[20]=(add_all_line(df_FHSL,17) + str(int(df_bbgg.iloc[17][1])-1)+"     " +str(int(df_bbgg.iloc[17][1])-2)+ "\n")
                lines[21]=(add_all_line(df_FHSL,18) + df_bbgg.iloc[18][1]+"     "+df_zzgg.iloc[18][1]+ "\n")
                lines[24]=(add_all_line(df_FHSL,20) + df_bbgg.iloc[20][2]+"     "+df_zzgg.iloc[20][2]+ "\n")
                lines[25]=(add_all_line(df_FHSL,21) + df_bbgg.iloc[21][2]+"     "+df_zzgg.iloc[21][2]+ "\n")
                lines[26]=(add_all_line(df_FHSL,22) + df_bbgg.iloc[22][2]+"     "+df_zzgg.iloc[22][2]+ "\n")
                lines[27]=(add_all_line(df_FHSL,23) + df_bbgg.iloc[23][2]+"     "+df_zzgg.iloc[23][2]+ "\n")
                lines[28]=(add_all_line(df_FHSL,24) + df_bbgg.iloc[24][2]+"     "+df_zzgg.iloc[24][2]+ "\n")
                lines[29]=(add_all_line(df_FHSL,25) + df_bbgg.iloc[25][2]+"     "+df_zzgg.iloc[25][2]+ "\n")
                lines[30]=(add_all_line(df_FHSL,26) + df_bbgg.iloc[26][2]+"     "+df_zzgg.iloc[26][2]+ "\n")
                lines[31]=(add_all_line(df_FHSL,27) + df_bbgg.iloc[27][2]+"     "+df_zzgg.iloc[27][2]+ "\n")
                lines[32]=(add_all_line(df_FHSL,28) + df_bbgg.iloc[28][2]+"     "+df_zzgg.iloc[28][2]+ "\n")
                lines[33]=(add_all_line(df_FHSL,29) + df_bbgg.iloc[29][2]+"     "+df_zzgg.iloc[29][2]+ "\n")
                lines[34]=(add_all_line(df_FHSL,30) + df_bbgg.iloc[30][2]+"     "+df_zzgg.iloc[30][2]+ "\n")
                lines[35]=(add_all_line(df_FHSL,31) + df_bbgg.iloc[31][2]+"     "+df_zzgg.iloc[31][2]+ "\n")
                lines[36]=(add_all_line(df_FHSL,32) + df_bbgg.iloc[32][2]+"     "+df_zzgg.iloc[32][2]+ "\n")
                lines[37]=(add_all_line(df_FHSL,33) + df_bbgg.iloc[33][2]+"     "+df_zzgg.iloc[33][2]+ "\n")
                lines[38]=(add_all_line(df_FHSL,34) + df_bbgg.iloc[34][2]+"     "+df_zzgg.iloc[34][2]+ "\n")
                lines[39]=(add_all_line(df_FHSL,35) + df_bbgg.iloc[35][2]+"     "+df_zzgg.iloc[35][2]+ "\n")
                lines[40]=(add_all_line(df_FHSL,36) + df_bbgg.iloc[36][2]+"     "+df_zzgg.iloc[36][2]+ "\n")
                lines[41]=(add_all_line(df_FHSL,37) + df_bbgg.iloc[37][2]+"     "+df_zzgg.iloc[37][2]+ "\n")
                lines[42]=(add_all_line(df_FHSL,38) + df_bbgg.iloc[38][2]+"     "+df_zzgg.iloc[38][2]+ "\n")
                lines[43]=(add_all_line(df_FHSL,39) + df_bbgg.iloc[39][2]+"     "+df_zzgg.iloc[39][2]+ "\n")
                lines[44]=(add_all_line(df_FHSL,40) + df_bbgg.iloc[40][2]+"     "+df_zzgg.iloc[40][2]+ "\n")
                lines[45]=(add_all_line(df_FHSL,41) + df_bbgg.iloc[41][2]+"     "+df_zzgg.iloc[41][2]+ "\n")
                # lines[46]=(add_all_line(df_FHSL,42) + df_bbgg.iloc[42][2]+"     "+df_zzgg.iloc[42][2]+ "\n")
                lines[47]=(add_all_line(df_FHSL,43) + df_bbgg.iloc[43][2]+"     "+df_zzgg.iloc[43][2]+ "\n")
                lines[48]=(add_all_line(df_FHSL,44) + df_bbgg.iloc[44][2]+"     "+df_zzgg.iloc[44][2]+ "\n")
                # lines[49]=(add_all_line(df_FHSL,45) + df_bbgg.iloc[45][2]+"     "+df_zzgg.iloc[45][2]+ "\n")
                # lines[50]=(add_all_line(df_FHSL,46) + df_bbgg.iloc[46][2]+"     "+df_zzgg.iloc[46][2]+ "\n")
                # lines[51]=(add_all_line(df_FHSL,47) + df_bbgg.iloc[47][2]+"     "+df_zzgg.iloc[47][2]+ "\n")
                lines.insert(10, add_all_line(df_zzgg, 8).replace(" zzgg_"+cat+"_2016pre "," combineFHSL_"+cat+"_2016pre ") + "\n")
                with open(destination_text_path, 'w') as file:
                    file.writelines(lines)
        if FHSLsignalmodel and zzggsignalmodel and not bbggsignalmodel:
            print("FHSL and zzgg",mass,cat)
            with open(FHSLcat_path, 'r') as source_file:
                        content = source_file.read()
            with open(destination_text_path, 'w') as destination_file:
                destination_file.write(content.replace("gghh_2016pre_hgg", "gghhWWgg_2016pre_hgg"))
            separator = r'(?<!\*)\s+'

            df_FHSL = pd.read_table(FHSLcat_path, sep=separator, header=None, engine='python')
            df_FHSL = df_FHSL.replace('gghh_2016pre_hgg', 'gghhWWgg_2016pre_hgg')
            df_bbgg = pd.read_table(bbggcat_path, sep=separator, header=None, engine='python')
            df_bbgg = df_bbgg.replace('gghh_2016pre_hgg', 'gghhbbgg_2016pre_hgg')
            df_zzgg = pd.read_table(zzggcat_path, sep=separator, header=None, engine='python')
            df_zzgg = df_zzgg.replace('gghh_2016pre_hgg', 'gghhzzgg_2016pre_hgg')
            with open(destination_text_path, 'r') as file:
                lines = file.readlines()
                lines.insert(10, add_all_line(df_zzgg, 8).replace(" zzgg_"+cat+"_2016pre "," combineFHSL_"+cat+"_2016pre ") + "\n")
                lines[18]=(add_all_line(df_FHSL,15) + df_zzgg.iloc[15][1].replace("zzgg_"+cat+"_2016pre","combineFHSL_"+cat+"_2016pre")+ "\n")
                lines[19]=(add_all_line(df_FHSL,16) + df_zzgg.iloc[16][1]+ "\n")
                lines[20]=(add_all_line(df_FHSL,17) + str(int(df_zzgg.iloc[17][1])-1)+ "\n")
                lines[21]=(add_all_line(df_FHSL,18) + df_zzgg.iloc[18][1]+ "\n")
                lines[24]=(add_all_line(df_FHSL,20) + df_zzgg.iloc[20][2]+ "\n")
                lines[25]=(add_all_line(df_FHSL,21) + df_zzgg.iloc[21][2]+ "\n")
                lines[26]=(add_all_line(df_FHSL,22) + df_zzgg.iloc[22][2]+ "\n")
                lines[27]=(add_all_line(df_FHSL,23) + df_zzgg.iloc[23][2]+ "\n")
                lines[28]=(add_all_line(df_FHSL,24) + df_zzgg.iloc[24][2]+ "\n")
                lines[29]=(add_all_line(df_FHSL,25) + df_zzgg.iloc[25][2]+ "\n")
                lines[30]=(add_all_line(df_FHSL,26) + df_zzgg.iloc[26][2]+ "\n")
                lines[31]=(add_all_line(df_FHSL,27) + df_zzgg.iloc[27][2]+ "\n")
                lines[32]=(add_all_line(df_FHSL,28) + df_zzgg.iloc[28][2]+ "\n")
                lines[33]=(add_all_line(df_FHSL,29) + df_zzgg.iloc[29][2]+ "\n")
                lines[34]=(add_all_line(df_FHSL,30) + df_zzgg.iloc[30][2]+ "\n")
                lines[35]=(add_all_line(df_FHSL,31) + df_zzgg.iloc[31][2]+ "\n")
                lines[36]=(add_all_line(df_FHSL,32) + df_zzgg.iloc[32][2]+ "\n")
                lines[37]=(add_all_line(df_FHSL,33) + df_zzgg.iloc[33][2]+ "\n")
                lines[38]=(add_all_line(df_FHSL,34) + df_zzgg.iloc[34][2]+ "\n")
                lines[39]=(add_all_line(df_FHSL,35) + df_zzgg.iloc[35][2]+ "\n")
                lines[40]=(add_all_line(df_FHSL,36) + df_zzgg.iloc[36][2]+ "\n")
                lines[41]=(add_all_line(df_FHSL,37) + df_zzgg.iloc[37][2]+ "\n")
                lines[42]=(add_all_line(df_FHSL,38) + df_zzgg.iloc[38][2]+ "\n")
                lines[43]=(add_all_line(df_FHSL,39) + df_zzgg.iloc[39][2]+ "\n")
                lines[44]=(add_all_line(df_FHSL,40) + df_zzgg.iloc[40][2]+ "\n")
                lines[45]=(add_all_line(df_FHSL,41) + df_zzgg.iloc[41][2]+ "\n")
                # lines[46]=(add_all_line(df_FHSL,42) + df_zzgg.iloc[42][2]+ "\n")
                lines[47]=(add_all_line(df_FHSL,43) + df_zzgg.iloc[43][2]+ "\n")
                lines[48]=(add_all_line(df_FHSL,44) + df_zzgg.iloc[44][2]+ "\n")
                # lines[49]=(add_all_line(df_FHSL,45) + df_zzgg.iloc[45][2]+ "\n")
                # lines[50]=(add_all_line(df_FHSL,46) + df_zzgg.iloc[46][2]+ "\n")
                # lines[51]=(add_all_line(df_FHSL,47) + df_zzgg.iloc[47][2]+ "\n")
                with open(destination_text_path, 'w') as file:
                    file.writelines(lines)
# Out:
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1000_MH125/Datacard_MX1000_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1000_MH125/Datacard_MX1000_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX500_MH125/Datacard_MX500_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX500_MH125/Datacard_MX500_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX550_MH125/Datacard_MX550_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX550_MH125/Datacard_MX550_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX600_MH125/Datacard_MX600_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX600_MH125/Datacard_MX600_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX650_MH125/Datacard_MX650_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX650_MH125/Datacard_MX650_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX700_MH125/Datacard_MX700_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX700_MH125/Datacard_MX700_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX750_MH125/Datacard_MX750_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX750_MH125/Datacard_MX750_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX800_MH125/Datacard_MX800_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX800_MH125/Datacard_MX800_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX850_MH125/Datacard_MX850_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX850_MH125/Datacard_MX850_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1100_MH125/Datacard_MX1100_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1100_MH125/Datacard_MX1100_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1200_MH125/Datacard_MX1200_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1200_MH125/Datacard_MX1200_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1300_MH125/Datacard_MX1300_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1300_MH125/Datacard_MX1300_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1400_MH125/Datacard_MX1400_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1400_MH125/Datacard_MX1400_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1500_MH125/Datacard_MX1500_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1500_MH125/Datacard_MX1500_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1600_MH125/Datacard_MX1600_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1600_MH125/Datacard_MX1600_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1700_MH125/Datacard_MX1700_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1700_MH125/Datacard_MX1700_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1800_MH125/Datacard_MX1800_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1800_MH125/Datacard_MX1800_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1900_MH125/Datacard_MX1900_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1900_MH125/Datacard_MX1900_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2000_MH125/Datacard_MX2000_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2000_MH125/Datacard_MX2000_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2200_MH125/Datacard_MX2200_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2200_MH125/Datacard_MX2200_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2600_MH125/Datacard_MX2600_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2600_MH125/Datacard_MX2600_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2800_MH125/Datacard_MX2800_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2800_MH125/Datacard_MX2800_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2400_MH125/Datacard_MX2400_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2400_MH125/Datacard_MX2400_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX3000_MH125/Datacard_MX3000_MH125_cat12highpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX3000_MH125/Datacard_MX3000_MH125_2016pre_combineFHSL_cat12highpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1000_MH125/Datacard_MX1000_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1000_MH125/Datacard_MX1000_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX500_MH125/Datacard_MX500_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX500_MH125/Datacard_MX500_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX550_MH125/Datacard_MX550_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX550_MH125/Datacard_MX550_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX600_MH125/Datacard_MX600_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX600_MH125/Datacard_MX600_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX650_MH125/Datacard_MX650_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX650_MH125/Datacard_MX650_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX700_MH125/Datacard_MX700_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX700_MH125/Datacard_MX700_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX750_MH125/Datacard_MX750_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX750_MH125/Datacard_MX750_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX800_MH125/Datacard_MX800_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX800_MH125/Datacard_MX800_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX850_MH125/Datacard_MX850_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX850_MH125/Datacard_MX850_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1100_MH125/Datacard_MX1100_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1100_MH125/Datacard_MX1100_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1200_MH125/Datacard_MX1200_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1200_MH125/Datacard_MX1200_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1300_MH125/Datacard_MX1300_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1300_MH125/Datacard_MX1300_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1400_MH125/Datacard_MX1400_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1400_MH125/Datacard_MX1400_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1500_MH125/Datacard_MX1500_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1500_MH125/Datacard_MX1500_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1600_MH125/Datacard_MX1600_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1600_MH125/Datacard_MX1600_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1700_MH125/Datacard_MX1700_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1700_MH125/Datacard_MX1700_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1800_MH125/Datacard_MX1800_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1800_MH125/Datacard_MX1800_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1900_MH125/Datacard_MX1900_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1900_MH125/Datacard_MX1900_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2000_MH125/Datacard_MX2000_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2000_MH125/Datacard_MX2000_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2200_MH125/Datacard_MX2200_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2200_MH125/Datacard_MX2200_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2600_MH125/Datacard_MX2600_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2600_MH125/Datacard_MX2600_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2800_MH125/Datacard_MX2800_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2800_MH125/Datacard_MX2800_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2400_MH125/Datacard_MX2400_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2400_MH125/Datacard_MX2400_MH125_2016pre_combineFHSL_cat12lowpurity.txt
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX3000_MH125/Datacard_MX3000_MH125_cat12lowpurity.txt
# True
# True
# True
# /afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX3000_MH125/Datacard_MX3000_MH125_2016pre_combineFHSL_cat12lowpurity.txt
