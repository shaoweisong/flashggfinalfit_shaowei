# %%
import uproot
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import awkward as ak
import mplhep as hep

# %%
M500_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX500_MH125/higgsCombinecombineFHSL_2017allcat_M500.AsymptoticLimits.mH125.root")
M500_cat_cat12 = M500_events_cat12["limit"].arrays(['limit']).limit*100
M550_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX550_MH125/higgsCombinecombineFHSL_2017allcat_M550.AsymptoticLimits.mH125.root")
M550_cat_cat12 = M550_events_cat12["limit"].arrays(['limit']).limit*100
M600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX600_MH125/higgsCombinecombineFHSL_2017allcat_M600.AsymptoticLimits.mH125.root")
M600_cat_cat12 = M600_events_cat12["limit"].arrays(['limit']).limit*100
M650_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX650_MH125/higgsCombinecombineFHSL_2017allcat_M650.AsymptoticLimits.mH125.root")
M650_cat_cat12 = M650_events_cat12["limit"].arrays(['limit']).limit*100
M700_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX700_MH125/higgsCombinecombineFHSL_2017allcat_M700.AsymptoticLimits.mH125.root")
M700_cat_cat12 = M700_events_cat12["limit"].arrays(['limit']).limit*100
M750_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX750_MH125/higgsCombinecombineFHSL_2017allcat_M750.AsymptoticLimits.mH125.root")
M750_cat_cat12 = M750_events_cat12["limit"].arrays(['limit']).limit*100
M800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX800_MH125/higgsCombinecombineFHSL_2017allcat_M800.AsymptoticLimits.mH125.root")
M800_cat_cat12 = M800_events_cat12["limit"].arrays(['limit']).limit*100
M850_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX850_MH125/higgsCombinecombineFHSL_2017allcat_M850.AsymptoticLimits.mH125.root")
M850_cat_cat12 = M850_events_cat12["limit"].arrays(['limit']).limit*100
M1000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1000_MH125/higgsCombinecombineFHSL_2017allcat_M1000.AsymptoticLimits.mH125.root")
M1000_cat_cat12 = M1000_events_cat12["limit"].arrays(['limit']).limit
M1100_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1100_MH125/higgsCombinecombineFHSL_2017allcat_M1100.AsymptoticLimits.mH125.root")
M1100_cat_cat12 = M1100_events_cat12["limit"].arrays(['limit']).limit
M1200_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1200_MH125/higgsCombinecombineFHSL_2017allcat_M1200.AsymptoticLimits.mH125.root")
M1200_cat_cat12 = M1200_events_cat12["limit"].arrays(['limit']).limit
M1300_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1300_MH125/higgsCombinecombineFHSL_2017allcat_M1300.AsymptoticLimits.mH125.root")
M1300_cat_cat12 = M1300_events_cat12["limit"].arrays(['limit']).limit
M1400_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1400_MH125/higgsCombinecombineFHSL_2017allcat_M1400.AsymptoticLimits.mH125.root")
M1400_cat_cat12 = M1400_events_cat12["limit"].arrays(['limit']).limit
M1500_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1500_MH125/higgsCombinecombineFHSL_2017allcat_M1500.AsymptoticLimits.mH125.root")
M1500_cat_cat12 = M1500_events_cat12["limit"].arrays(['limit']).limit
M1600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1600_MH125/higgsCombinecombineFHSL_2017allcat_M1600.AsymptoticLimits.mH125.root")
M1600_cat_cat12 = M1600_events_cat12["limit"].arrays(['limit']).limit
M1700_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1700_MH125/higgsCombinecombineFHSL_2017allcat_M1700.AsymptoticLimits.mH125.root")
M1700_cat_cat12 = M1700_events_cat12["limit"].arrays(['limit']).limit
M1800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1800_MH125/higgsCombinecombineFHSL_2017allcat_M1800.AsymptoticLimits.mH125.root")
M1800_cat_cat12 = M1800_events_cat12["limit"].arrays(['limit']).limit
M1900_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1900_MH125/higgsCombinecombineFHSL_2017allcat_M1900.AsymptoticLimits.mH125.root")
M1900_cat_cat12 = M1900_events_cat12["limit"].arrays(['limit']).limit
# M2000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX2000_MH125/higgsCombinecombineFHSL_2017allcat_M2000.AsymptoticLimits.mH125.root")
# M2000_cat_cat12 = M2000_events_cat12["limit"].arrays(['limit']).limit
# M2200_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX2200_MH125/higgsCombinecombineFHSL_2017allcat_M2200.AsymptoticLimits.mH125.root")
# M2200_cat_cat12 = M2200_events_cat12["limit"].arrays(['limit']).limit
M2400_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX2400_MH125/higgsCombinecombineFHSL_2017allcat_M2400.AsymptoticLimits.mH125.root")
M2400_cat_cat12 = M2400_events_cat12["limit"].arrays(['limit']).limit
M2600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX2600_MH125/higgsCombinecombineFHSL_2017allcat_M2600.AsymptoticLimits.mH125.root")
M2600_cat_cat12 = M2600_events_cat12["limit"].arrays(['limit']).limit
M2800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX2800_MH125/higgsCombinecombineFHSL_2017allcat_M2800.AsymptoticLimits.mH125.root")
M2800_cat_cat12 = M2800_events_cat12["limit"].arrays(['limit']).limit
M3000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX3000_MH125/higgsCombinecombineFHSL_2017allcat_M3000.AsymptoticLimits.mH125.root")
M3000_cat_cat12 = M3000_events_cat12["limit"].arrays(['limit']).limit

M500_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX500_MH125/higgsCombineDatacard_M500_2017wwgg.AsymptoticLimits.mH125.root")
M500_wwgg = M500_events_wwgg["limit"].arrays(['limit']).limit*100
M550_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX550_MH125/higgsCombineDatacard_M550_2017wwgg.AsymptoticLimits.mH125.root")
M550_wwgg = M550_events_wwgg["limit"].arrays(['limit']).limit*100
M600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX600_MH125/higgsCombineDatacard_M600_2017wwgg.AsymptoticLimits.mH125.root")
M600_wwgg = M600_events_wwgg["limit"].arrays(['limit']).limit*100
M650_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX650_MH125/higgsCombineDatacard_M650_2017wwgg.AsymptoticLimits.mH125.root")
M650_wwgg = M650_events_wwgg["limit"].arrays(['limit']).limit*100
M700_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX700_MH125/higgsCombineDatacard_M700_2017wwgg.AsymptoticLimits.mH125.root")
M700_wwgg = M700_events_wwgg["limit"].arrays(['limit']).limit*100
M750_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX750_MH125/higgsCombineDatacard_M750_2017wwgg.AsymptoticLimits.mH125.root")
M750_wwgg = M750_events_wwgg["limit"].arrays(['limit']).limit*100
M800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX800_MH125/higgsCombineDatacard_M800_2017wwgg.AsymptoticLimits.mH125.root")
M800_wwgg = M800_events_wwgg["limit"].arrays(['limit']).limit*100
M850_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX850_MH125/higgsCombineDatacard_M850_2017wwgg.AsymptoticLimits.mH125.root")
M850_wwgg = M850_events_wwgg["limit"].arrays(['limit']).limit*100
M1000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1000_MH125/higgsCombineDatacard_M1000_2017wwgg.AsymptoticLimits.mH125.root")
M1000_wwgg = M1000_events_wwgg["limit"].arrays(['limit']).limit
M1100_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1100_MH125/higgsCombineDatacard_M1100_2017wwgg.AsymptoticLimits.mH125.root")
M1100_wwgg = M1100_events_wwgg["limit"].arrays(['limit']).limit
M1200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1200_MH125/higgsCombineDatacard_M1200_2017wwgg.AsymptoticLimits.mH125.root")
M1200_wwgg = M1200_events_wwgg["limit"].arrays(['limit']).limit
M1300_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1300_MH125/higgsCombineDatacard_M1300_2017wwgg.AsymptoticLimits.mH125.root")
M1300_wwgg = M1300_events_wwgg["limit"].arrays(['limit']).limit
M1400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1400_MH125/higgsCombineDatacard_M1400_2017wwgg.AsymptoticLimits.mH125.root")
M1400_wwgg = M1400_events_wwgg["limit"].arrays(['limit']).limit
M1500_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1500_MH125/higgsCombineDatacard_M1500_2017wwgg.AsymptoticLimits.mH125.root")
M1500_wwgg = M1500_events_wwgg["limit"].arrays(['limit']).limit
M1600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1600_MH125/higgsCombineDatacard_M1600_2017wwgg.AsymptoticLimits.mH125.root")
M1600_wwgg = M1600_events_wwgg["limit"].arrays(['limit']).limit
M1700_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1700_MH125/higgsCombineDatacard_M1700_2017wwgg.AsymptoticLimits.mH125.root")
M1700_wwgg = M1700_events_wwgg["limit"].arrays(['limit']).limit
M1800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1800_MH125/higgsCombineDatacard_M1800_2017wwgg.AsymptoticLimits.mH125.root")
M1800_wwgg = M1800_events_wwgg["limit"].arrays(['limit']).limit
M1900_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX1900_MH125/higgsCombineDatacard_M1900_2017wwgg.AsymptoticLimits.mH125.root")
M1900_wwgg = M1900_events_wwgg["limit"].arrays(['limit']).limit
# M2000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX2000_MH125/higgsCombineDatacard_M2000_2017wwgg.AsymptoticLimits.mH125.root")
# M2000_wwgg = M2000_events_wwgg["limit"].arrays(['limit']).limit
# M2200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX2200_MH125/higgsCombineDatacard_M2200_2017wwgg.AsymptoticLimits.mH125.root")
# M2200_wwgg = M2200_events_wwgg["limit"].arrays(['limit']).limit
M2400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX2400_MH125/higgsCombineDatacard_M2400_2017wwgg.AsymptoticLimits.mH125.root")
M2400_wwgg = M2400_events_wwgg["limit"].arrays(['limit']).limit
M2600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX2600_MH125/higgsCombineDatacard_M2600_2017wwgg.AsymptoticLimits.mH125.root")
M2600_wwgg = M2600_events_wwgg["limit"].arrays(['limit']).limit
M2800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX2800_MH125/higgsCombineDatacard_M2800_2017wwgg.AsymptoticLimits.mH125.root")
M2800_wwgg = M2800_events_wwgg["limit"].arrays(['limit']).limit
M3000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/checkboosted/2017datacard/MX3000_MH125/higgsCombineDatacard_M3000_2017wwgg.AsymptoticLimits.mH125.root")
M3000_wwgg = M3000_events_wwgg["limit"].arrays(['limit']).limit

# %%
hep.style.use(hep.style.CMS)

hep.cms.label("preliminary", data=True, year='2017', lumi=41.5)   
# set figure size
plt.rcParams["figure.figsize"] = (16, 10)

allcat_values = [500,550,600,650,700,750,800,850,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2400,2600,2800,3000]
plt.plot(allcat_values, [M500_cat_cat12[2],M550_cat_cat12[2],M600_cat_cat12[2],M650_cat_cat12[2],M700_cat_cat12[2],M750_cat_cat12[2],M800_cat_cat12[2],M850_cat_cat12[2],M1000_cat_cat12[2],M1100_cat_cat12[2],M1200_cat_cat12[2],M1300_cat_cat12[2],M1400_cat_cat12[2],M1500_cat_cat12[2],M1600_cat_cat12[2],M1700_cat_cat12[2],M1800_cat_cat12[2],M1900_cat_cat12[2],M2400_cat_cat12[2],M2600_cat_cat12[2],M2800_cat_cat12[2],M3000_cat_cat12[2]],color='black', linewidth=2,linestyle='-', label='Asymptotic Limits CLs expected')
plt.plot(allcat_values, [M500_wwgg[2],M550_wwgg[2],M600_wwgg[2],M650_wwgg[2],M700_wwgg[2],M750_wwgg[2],M800_wwgg[2],M850_wwgg[2],M1000_wwgg[2],M1100_wwgg[2],M1200_wwgg[2],M1300_wwgg[2],M1400_wwgg[2],M1500_wwgg[2],M1600_wwgg[2],M1700_wwgg[2],M1800_wwgg[2],M1900_wwgg[2],M2400_wwgg[2],M2600_wwgg[2],M2800_wwgg[2],M3000_wwgg[2]],color='blue', linewidth=2,linestyle='--', label='WWgg signal')

# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M500_cat_cat12[1],M550_cat_cat12[1],M600_cat_cat12[1],M650_cat_cat12[1],M700_cat_cat12[1],M750_cat_cat12[1],M800_cat_cat12[1],M850_cat_cat12[1],M1000_cat_cat12[1],M1100_cat_cat12[1],M1200_cat_cat12[1],M1300_cat_cat12[1],M1400_cat_cat12[1],M1500_cat_cat12[1],M1600_cat_cat12[1],M1700_cat_cat12[1],M1800_cat_cat12[1],M1900_cat_cat12[1],M2400_cat_cat12[1],M2600_cat_cat12[1],M2800_cat_cat12[1],M3000_cat_cat12[1]], [M500_cat_cat12[3],M550_cat_cat12[3],M600_cat_cat12[3],M650_cat_cat12[3],M700_cat_cat12[3],M750_cat_cat12[3],M800_cat_cat12[3],M850_cat_cat12[3],M1000_cat_cat12[3],M1100_cat_cat12[3],M1200_cat_cat12[3],M1300_cat_cat12[3],M1400_cat_cat12[3],M1500_cat_cat12[3],M1600_cat_cat12[3],M1700_cat_cat12[3],M1800_cat_cat12[3],M1900_cat_cat12[3],M2400_cat_cat12[3],M2600_cat_cat12[3],M2800_cat_cat12[3],M3000_cat_cat12[3]], color='#04cb02', alpha=1, label= r'68% expected')#r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M500_cat_cat12[0],M550_cat_cat12[0],M600_cat_cat12[0],M650_cat_cat12[0],M700_cat_cat12[0],M750_cat_cat12[0],M800_cat_cat12[0],M850_cat_cat12[0],M1000_cat_cat12[0],M1100_cat_cat12[0],M1200_cat_cat12[0],M1300_cat_cat12[0],M1400_cat_cat12[0],M1500_cat_cat12[0],M1600_cat_cat12[0],M1700_cat_cat12[0],M1800_cat_cat12[0],M1900_cat_cat12[0],M2400_cat_cat12[0],M2600_cat_cat12[0],M2800_cat_cat12[0],M3000_cat_cat12[0]],[M500_cat_cat12[1],M550_cat_cat12[1],M600_cat_cat12[1],M650_cat_cat12[1],M700_cat_cat12[1],M750_cat_cat12[1],M800_cat_cat12[1],M850_cat_cat12[1],M1000_cat_cat12[1],M1100_cat_cat12[1],M1200_cat_cat12[1],M1300_cat_cat12[1],M1400_cat_cat12[1],M1500_cat_cat12[1],M1600_cat_cat12[1],M1700_cat_cat12[1],M1800_cat_cat12[1],M1900_cat_cat12[1],M2400_cat_cat12[1],M2600_cat_cat12[1],M2800_cat_cat12[1],M3000_cat_cat12[1]], color='gold', alpha=1, label= r'95% expected')#r'±2 std. deviation')
plt.fill_between(allcat_values,  [M500_cat_cat12[3],M550_cat_cat12[3],M600_cat_cat12[3],M650_cat_cat12[3],M700_cat_cat12[3],M750_cat_cat12[3],M800_cat_cat12[3],M850_cat_cat12[3],M1000_cat_cat12[3],M1100_cat_cat12[3],M1200_cat_cat12[3],M1300_cat_cat12[3],M1400_cat_cat12[3],M1500_cat_cat12[3],M1600_cat_cat12[3],M1700_cat_cat12[3],M1800_cat_cat12[3],M1900_cat_cat12[3],M2400_cat_cat12[3],M2600_cat_cat12[3],M2800_cat_cat12[3],M3000_cat_cat12[3]],  [M500_cat_cat12[4],M550_cat_cat12[4],M600_cat_cat12[4],M650_cat_cat12[4],M700_cat_cat12[4],M750_cat_cat12[4],M800_cat_cat12[4],M850_cat_cat12[4],M1000_cat_cat12[4],M1100_cat_cat12[4],M1200_cat_cat12[4],M1300_cat_cat12[4],M1400_cat_cat12[4],M1500_cat_cat12[4],M1600_cat_cat12[4],M1700_cat_cat12[4],M1800_cat_cat12[4],M1900_cat_cat12[4],M2400_cat_cat12[4],M2600_cat_cat12[4],M2800_cat_cat12[4],M3000_cat_cat12[4]], color='gold', alpha=1)

# 添加标签和标题
plt.xlabel(r'Radion Mass (GeV)')
# plt.ylabel(r'95% CL limits on $\sigma(ggX)*Br(XHHWWgg)[fb]$')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(500,3000)
#每1000GeV一个刻度
# plt.xticks(np.arange(200, 3001, 500))
# set x ticks
# plt.xticks(np.arange(1000, 3001, 500))
# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,10000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(0.95, 0.95))
