# %%
import uproot
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import awkward as ak
import mplhep as hep

# %% [markdown]
# # cat12+cat34

# %%
M250_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX250_MH125/higgsCombinecat34_MX250_MH125_2017.AsymptoticLimits.mH125.root")
M250_cat34 = M250_events_cat34["limit"].arrays(['limit']).limit*100
M260_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX260_MH125/higgsCombinecat34_MX260_MH125_2017.AsymptoticLimits.mH125.root")
M260_cat34 = M260_events_cat34["limit"].arrays(['limit']).limit*100
M270_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX270_MH125/higgsCombinecat34_MX270_MH125_2017.AsymptoticLimits.mH125.root")
M270_cat34 = M270_events_cat34["limit"].arrays(['limit']).limit*100
M280_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX280_MH125/higgsCombinecat34_MX280_MH125_2017.AsymptoticLimits.mH125.root")
M280_cat34 = M280_events_cat34["limit"].arrays(['limit']).limit*100
M300_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX300_MH125/higgsCombinecat34_MX300_MH125_2017.AsymptoticLimits.mH125.root")
M300_cat34 = M300_events_cat34["limit"].arrays(['limit']).limit*100
M320_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX320_MH125/higgsCombinecat34_MX320_MH125_2017.AsymptoticLimits.mH125.root")
M320_cat34 = M320_events_cat34["limit"].arrays(['limit']).limit*100
# M350_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX350_MH125/higgsCombinecat34_MX350_MH125_2017.AsymptoticLimits.mH125.root")
# M350_cat34 = M350_events_cat34["limit"].arrays(['limit']).limit*100
M400_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX400_MH125/higgsCombinecat34_MX400_MH125_2017.AsymptoticLimits.mH125.root")
M400_cat34 = M400_events_cat34["limit"].arrays(['limit']).limit*100
M450_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX450_MH125/higgsCombinecat34_MX450_MH125_2017.AsymptoticLimits.mH125.root")
M450_cat34 = M450_events_cat34["limit"].arrays(['limit']).limit*100
M500_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX500_MH125/higgsCombinecat34_MX500_MH125_2017.AsymptoticLimits.mH125.root")
M500_cat34 = M500_events_cat34["limit"].arrays(['limit']).limit*100
M550_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX550_MH125/higgsCombinecat34_MX550_MH125_2017.AsymptoticLimits.mH125.root")
M550_cat34 = M550_events_cat34["limit"].arrays(['limit']).limit*100
M600_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX600_MH125/higgsCombinecat34_MX600_MH125_2017.AsymptoticLimits.mH125.root")
M600_cat34 = M600_events_cat34["limit"].arrays(['limit']).limit*100
M650_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX650_MH125/higgsCombinecat34_MX650_MH125_2017.AsymptoticLimits.mH125.root")
M650_cat34 = M650_events_cat34["limit"].arrays(['limit']).limit*100
M700_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX700_MH125/higgsCombinecat34_MX700_MH125_2017.AsymptoticLimits.mH125.root")
M700_cat34 = M700_events_cat34["limit"].arrays(['limit']).limit*100
M750_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX750_MH125/higgsCombinecat34_MX750_MH125_2017.AsymptoticLimits.mH125.root")
M750_cat34 = M750_events_cat34["limit"].arrays(['limit']).limit*100
M800_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX800_MH125/higgsCombinecat34_MX800_MH125_2017.AsymptoticLimits.mH125.root")
M800_cat34 = M800_events_cat34["limit"].arrays(['limit']).limit*100
M850_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX850_MH125/higgsCombinecat34_MX850_MH125_2017.AsymptoticLimits.mH125.root")
M850_cat34 = M850_events_cat34["limit"].arrays(['limit']).limit*100
M1000_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1000_MH125/higgsCombinecat34_MX1000_MH125_2017.AsymptoticLimits.mH125.root")
M1000_cat34 = M1000_events_cat34["limit"].arrays(['limit']).limit*100
M250_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX250_MH125/higgsCombineWWggcat34_MX250_MH125_2017.AsymptoticLimits.mH125.root")
M250_wwggcat34 = M250_events_wwggcat34["limit"].arrays(['limit']).limit*100
M260_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX260_MH125/higgsCombineWWggcat34_MX260_MH125_2017.AsymptoticLimits.mH125.root")
M260_wwggcat34 = M260_events_wwggcat34["limit"].arrays(['limit']).limit*100
M270_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX270_MH125/higgsCombineWWggcat34_MX270_MH125_2017.AsymptoticLimits.mH125.root")
M270_wwggcat34 = M270_events_wwggcat34["limit"].arrays(['limit']).limit*100
M280_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX280_MH125/higgsCombineWWggcat34_MX280_MH125_2017.AsymptoticLimits.mH125.root")
M280_wwggcat34 = M280_events_wwggcat34["limit"].arrays(['limit']).limit*100
M300_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX300_MH125/higgsCombineWWggcat34_MX300_MH125_2017.AsymptoticLimits.mH125.root")
M300_wwggcat34 = M300_events_wwggcat34["limit"].arrays(['limit']).limit*100
M320_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX320_MH125/higgsCombineWWggcat34_MX320_MH125_2017.AsymptoticLimits.mH125.root")
M320_wwggcat34 = M320_events_wwggcat34["limit"].arrays(['limit']).limit*100
# M350_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX350_MH125/higgsCombineWWggcat34_MX350_MH125_2017.AsymptoticLimits.mH125.root")
# M350_wwggcat34 = M350_events_wwggcat34["limit"].arrays(['limit']).limit*100
M400_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX400_MH125/higgsCombineWWggcat34_MX400_MH125_2017.AsymptoticLimits.mH125.root")
M400_wwggcat34 = M400_events_wwggcat34["limit"].arrays(['limit']).limit*100
M450_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX450_MH125/higgsCombineWWggcat34_MX450_MH125_2017.AsymptoticLimits.mH125.root")
M450_wwggcat34 = M450_events_wwggcat34["limit"].arrays(['limit']).limit*100
M500_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX500_MH125/higgsCombineWWggcat34_MX500_MH125_2017.AsymptoticLimits.mH125.root")
M500_wwggcat34 = M500_events_wwggcat34["limit"].arrays(['limit']).limit*100
M550_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX550_MH125/higgsCombineWWggcat34_MX550_MH125_2017.AsymptoticLimits.mH125.root")
M550_wwggcat34 = M550_events_wwggcat34["limit"].arrays(['limit']).limit*100
M600_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX600_MH125/higgsCombineWWggcat34_MX600_MH125_2017.AsymptoticLimits.mH125.root")
M600_wwggcat34 = M600_events_wwggcat34["limit"].arrays(['limit']).limit*100
M650_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX650_MH125/higgsCombineWWggcat34_MX650_MH125_2017.AsymptoticLimits.mH125.root")
M650_wwggcat34 = M650_events_wwggcat34["limit"].arrays(['limit']).limit*100
M700_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX700_MH125/higgsCombineWWggcat34_MX700_MH125_2017.AsymptoticLimits.mH125.root")
M700_wwggcat34 = M700_events_wwggcat34["limit"].arrays(['limit']).limit*100
M750_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX750_MH125/higgsCombineWWggcat34_MX750_MH125_2017.AsymptoticLimits.mH125.root")
M750_wwggcat34 = M750_events_wwggcat34["limit"].arrays(['limit']).limit*100
M800_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX800_MH125/higgsCombineWWggcat34_MX800_MH125_2017.AsymptoticLimits.mH125.root")
M800_wwggcat34 = M800_events_wwggcat34["limit"].arrays(['limit']).limit*100
M850_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX850_MH125/higgsCombineWWggcat34_MX850_MH125_2017.AsymptoticLimits.mH125.root")
M850_wwggcat34 = M850_events_wwggcat34["limit"].arrays(['limit']).limit*100
M1000_events_wwggcat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1000_MH125/higgsCombineWWggcat34_MX1000_MH125_2017.AsymptoticLimits.mH125.root")
M1000_wwggcat34 = M1000_events_wwggcat34["limit"].arrays(['limit']).limit*100

# %%
hep.style.use(hep.style.CMS)
hep.cms.label("preliminary", data=True, year='UL2017', lumi=41.5)   
# set figure size
plt.rcParams["figure.figsize"] = (20,20)
allcat_values = [250,260,270,280,300,320,400,450,500,550,600,650,700,750,800,850,1000]
plt.plot(allcat_values, [M250_cat34[2],M260_cat34[2],M270_cat34[2],M280_cat34[2],M300_cat34[2],M320_cat34[2],M400_cat34[2],M450_cat34[2],M500_cat34[2],M550_cat34[2],M600_cat34[2],M650_cat34[2],M700_cat34[2],M750_cat34[2],M800_cat34[2],M850_cat34[2],M1000_cat34[2]],color='black', linewidth=2,linestyle='-', label='WWgg + ZZgg + bbgg Signal')#'Asymptotic Limits CLs expected'
plt.plot(allcat_values, [M250_wwggcat34[2],M260_wwggcat34[2],M270_wwggcat34[2],M280_wwggcat34[2],M300_wwggcat34[2],M320_wwggcat34[2],M400_wwggcat34[2],M450_wwggcat34[2],M500_wwggcat34[2],M550_wwggcat34[2],M600_wwggcat34[2],M650_wwggcat34[2],M700_wwggcat34[2],M750_wwggcat34[2],M800_wwggcat34[2],M850_wwggcat34[2],M1000_wwggcat34[2]],color='blue', linewidth=2,linestyle='--', label='WWgg Signal')#'Asymptotic Limits CLs expected'

# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M250_cat34[1],M260_cat34[1],M270_cat34[1],M280_cat34[1],M300_cat34[1],M320_cat34[1],M400_cat34[1],M450_cat34[1],M500_cat34[1],M550_cat34[1],M600_cat34[1],M650_cat34[1],M700_cat34[1],M750_cat34[1],M800_cat34[1],M850_cat34[1],M1000_cat34[1]], [M250_cat34[3],M260_cat34[3],M270_cat34[3],M280_cat34[3],M300_cat34[3],M320_cat34[3],M400_cat34[3],M450_cat34[3],M500_cat34[3],M550_cat34[3],M600_cat34[3],M650_cat34[3],M700_cat34[3],M750_cat34[3],M800_cat34[3],M850_cat34[3],M1000_cat34[3]], color='#04cb02', alpha=1, label= r'68% expected')#label= r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M250_cat34[0],M260_cat34[0],M270_cat34[0],M280_cat34[0],M300_cat34[0],M320_cat34[0],M400_cat34[0],M450_cat34[0],M500_cat34[0],M550_cat34[0],M600_cat34[0],M650_cat34[0],M700_cat34[0],M750_cat34[0],M800_cat34[0],M850_cat34[0],M1000_cat34[0]],[M250_cat34[1],M260_cat34[1],M270_cat34[1],M280_cat34[1],M300_cat34[1],M320_cat34[1],M400_cat34[1],M450_cat34[1],M500_cat34[1],M550_cat34[1],M600_cat34[1],M650_cat34[1],M700_cat34[1],M750_cat34[1],M800_cat34[1],M850_cat34[1],M1000_cat34[1]], color='gold', alpha=1, label=r'95%expected')#label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_cat34[3],M260_cat34[3],M270_cat34[3],M280_cat34[3],M300_cat34[3],M320_cat34[3],M400_cat34[3],M450_cat34[3],M500_cat34[3],M550_cat34[3],M600_cat34[3],M650_cat34[3],M700_cat34[3],M750_cat34[3],M800_cat34[3],M850_cat34[3],M1000_cat34[3]],  [M250_cat34[4],M260_cat34[4],M270_cat34[4],M280_cat34[4],M300_cat34[4],M320_cat34[4],M400_cat34[4],M450_cat34[4],M500_cat34[4],M550_cat34[4],M600_cat34[4],M650_cat34[4],M700_cat34[4],M750_cat34[4],M800_cat34[4],M850_cat34[4],M1000_cat34[4]], color='gold', alpha=1)

plt.xlabel(r'Radion Mass (GeV)')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,1000)

# set log scale
plt.yscale('log')
# set y limit
plt.ylim(100,100000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(1., 0.95))

# %%
M500_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX500_MH125/higgsCombinecat12_MX500_MH125_2017.AsymptoticLimits.mH125.root")
M500_cat_cat12 = M500_events_cat12["limit"].arrays(['limit']).limit*100
M550_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX550_MH125/higgsCombinecat12_MX550_MH125_2017.AsymptoticLimits.mH125.root")
M550_cat_cat12 = M550_events_cat12["limit"].arrays(['limit']).limit*100
M600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX600_MH125/higgsCombinecat12_MX600_MH125_2017.AsymptoticLimits.mH125.root")
M600_cat_cat12 = M600_events_cat12["limit"].arrays(['limit']).limit*100
M650_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX650_MH125/higgsCombinecat12_MX650_MH125_2017.AsymptoticLimits.mH125.root")
M650_cat_cat12 = M650_events_cat12["limit"].arrays(['limit']).limit*100
M700_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX700_MH125/higgsCombinecat12_MX700_MH125_2017.AsymptoticLimits.mH125.root")
M700_cat_cat12 = M700_events_cat12["limit"].arrays(['limit']).limit*100
M750_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX750_MH125/higgsCombinecat12_MX750_MH125_2017.AsymptoticLimits.mH125.root")
M750_cat_cat12 = M750_events_cat12["limit"].arrays(['limit']).limit*100
M800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX800_MH125/higgsCombinecat12_MX800_MH125_2017.AsymptoticLimits.mH125.root")
M800_cat_cat12 = M800_events_cat12["limit"].arrays(['limit']).limit*100
M850_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX850_MH125/higgsCombinecat12_MX850_MH125_2017.AsymptoticLimits.mH125.root")
M850_cat_cat12 = M850_events_cat12["limit"].arrays(['limit']).limit*100
M1000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1000_MH125/higgsCombinecat12_MX1000_MH125_2017.AsymptoticLimits.mH125.root")
M1000_cat_cat12 = M1000_events_cat12["limit"].arrays(['limit']).limit
M1100_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1100_MH125/higgsCombinecat12_MX1100_MH125_2017.AsymptoticLimits.mH125.root")
M1100_cat_cat12 = M1100_events_cat12["limit"].arrays(['limit']).limit
M1200_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1200_MH125/higgsCombinecat12_MX1200_MH125_2017.AsymptoticLimits.mH125.root")
M1200_cat_cat12 = M1200_events_cat12["limit"].arrays(['limit']).limit
M1300_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1300_MH125/higgsCombinecat12_MX1300_MH125_2017.AsymptoticLimits.mH125.root")
M1300_cat_cat12 = M1300_events_cat12["limit"].arrays(['limit']).limit
M1400_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1400_MH125/higgsCombinecat12_MX1400_MH125_2017.AsymptoticLimits.mH125.root")
M1400_cat_cat12 = M1400_events_cat12["limit"].arrays(['limit']).limit
M1500_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1500_MH125/higgsCombinecat12_MX1500_MH125_2017.AsymptoticLimits.mH125.root")
M1500_cat_cat12 = M1500_events_cat12["limit"].arrays(['limit']).limit
M1600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1600_MH125/higgsCombinecat12_MX1600_MH125_2017.AsymptoticLimits.mH125.root")
M1600_cat_cat12 = M1600_events_cat12["limit"].arrays(['limit']).limit
M1700_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1700_MH125/higgsCombinecat12_MX1700_MH125_2017.AsymptoticLimits.mH125.root")
M1700_cat_cat12 = M1700_events_cat12["limit"].arrays(['limit']).limit
M1800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1800_MH125/higgsCombinecat12_MX1800_MH125_2017.AsymptoticLimits.mH125.root")
M1800_cat_cat12 = M1800_events_cat12["limit"].arrays(['limit']).limit
M1900_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1900_MH125/higgsCombinecat12_MX1900_MH125_2017.AsymptoticLimits.mH125.root")
M1900_cat_cat12 = M1900_events_cat12["limit"].arrays(['limit']).limit
M2000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2000_MH125/higgsCombinecat12_MX2000_MH125_2017.AsymptoticLimits.mH125.root")
M2000_cat_cat12 = M2000_events_cat12["limit"].arrays(['limit']).limit
M2200_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2200_MH125/higgsCombinecat12_MX2200_MH125_2017.AsymptoticLimits.mH125.root")
M2200_cat_cat12 = M2200_events_cat12["limit"].arrays(['limit']).limit
M2400_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2400_MH125/higgsCombinecat12_MX2400_MH125_2017.AsymptoticLimits.mH125.root")
M2400_cat_cat12 = M2400_events_cat12["limit"].arrays(['limit']).limit
M2600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2600_MH125/higgsCombinecat12_MX2600_MH125_2017.AsymptoticLimits.mH125.root")
M2600_cat_cat12 = M2600_events_cat12["limit"].arrays(['limit']).limit
M2800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2800_MH125/higgsCombinecat12_MX2800_MH125_2017.AsymptoticLimits.mH125.root")
M2800_cat_cat12 = M2800_events_cat12["limit"].arrays(['limit']).limit
M3000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX3000_MH125/higgsCombinecat12_MX3000_MH125_2017.AsymptoticLimits.mH125.root")
M3000_cat_cat12 = M3000_events_cat12["limit"].arrays(['limit']).limit

M500_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX500_MH125/higgsCombineWWggcat12_MX500_MH125_2017.AsymptoticLimits.mH125.root")
M500_wwgg = M500_events_wwgg["limit"].arrays(['limit']).limit*100
M550_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX550_MH125/higgsCombineWWggcat12_MX550_MH125_2017.AsymptoticLimits.mH125.root")
M550_wwgg = M550_events_wwgg["limit"].arrays(['limit']).limit*100
M600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX600_MH125/higgsCombineWWggcat12_MX600_MH125_2017.AsymptoticLimits.mH125.root")
M600_wwgg = M600_events_wwgg["limit"].arrays(['limit']).limit*100
M650_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX650_MH125/higgsCombineWWggcat12_MX650_MH125_2017.AsymptoticLimits.mH125.root")
M650_wwgg = M650_events_wwgg["limit"].arrays(['limit']).limit*100
M700_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX700_MH125/higgsCombineWWggcat12_MX700_MH125_2017.AsymptoticLimits.mH125.root")
M700_wwgg = M700_events_wwgg["limit"].arrays(['limit']).limit*100
M750_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX750_MH125/higgsCombineWWggcat12_MX750_MH125_2017.AsymptoticLimits.mH125.root")
M750_wwgg = M750_events_wwgg["limit"].arrays(['limit']).limit*100
M800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX800_MH125/higgsCombineWWggcat12_MX800_MH125_2017.AsymptoticLimits.mH125.root")
M800_wwgg = M800_events_wwgg["limit"].arrays(['limit']).limit*100
M850_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX850_MH125/higgsCombineWWggcat12_MX850_MH125_2017.AsymptoticLimits.mH125.root")
M850_wwgg = M850_events_wwgg["limit"].arrays(['limit']).limit*100
M1000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1000_MH125/higgsCombineWWggcat12_MX1000_MH125_2017.AsymptoticLimits.mH125.root")
M1000_wwgg = M1000_events_wwgg["limit"].arrays(['limit']).limit
M1100_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1100_MH125/higgsCombineWWggcat12_MX1100_MH125_2017.AsymptoticLimits.mH125.root")
M1100_wwgg = M1100_events_wwgg["limit"].arrays(['limit']).limit
M1200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1200_MH125/higgsCombineWWggcat12_MX1200_MH125_2017.AsymptoticLimits.mH125.root")
M1200_wwgg = M1200_events_wwgg["limit"].arrays(['limit']).limit
M1300_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1300_MH125/higgsCombineWWggcat12_MX1300_MH125_2017.AsymptoticLimits.mH125.root")
M1300_wwgg = M1300_events_wwgg["limit"].arrays(['limit']).limit
M1400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1400_MH125/higgsCombineWWggcat12_MX1400_MH125_2017.AsymptoticLimits.mH125.root")
M1400_wwgg = M1400_events_wwgg["limit"].arrays(['limit']).limit
M1500_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1500_MH125/higgsCombineWWggcat12_MX1500_MH125_2017.AsymptoticLimits.mH125.root")
M1500_wwgg = M1500_events_wwgg["limit"].arrays(['limit']).limit
M1600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1600_MH125/higgsCombineWWggcat12_MX1600_MH125_2017.AsymptoticLimits.mH125.root")
M1600_wwgg = M1600_events_wwgg["limit"].arrays(['limit']).limit
M1700_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1700_MH125/higgsCombineWWggcat12_MX1700_MH125_2017.AsymptoticLimits.mH125.root")
M1700_wwgg = M1700_events_wwgg["limit"].arrays(['limit']).limit
M1800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1800_MH125/higgsCombineWWggcat12_MX1800_MH125_2017.AsymptoticLimits.mH125.root")
M1800_wwgg = M1800_events_wwgg["limit"].arrays(['limit']).limit
M1900_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1900_MH125/higgsCombineWWggcat12_MX1900_MH125_2017.AsymptoticLimits.mH125.root")
M1900_wwgg = M1900_events_wwgg["limit"].arrays(['limit']).limit
M2000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2000_MH125/higgsCombineWWggcat12_MX2000_MH125_2017.AsymptoticLimits.mH125.root")
M2000_wwgg = M2000_events_wwgg["limit"].arrays(['limit']).limit
M2200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2200_MH125/higgsCombineWWggcat12_MX2200_MH125_2017.AsymptoticLimits.mH125.root")
M2200_wwgg = M2200_events_wwgg["limit"].arrays(['limit']).limit
M2400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2400_MH125/higgsCombineWWggcat12_MX2400_MH125_2017.AsymptoticLimits.mH125.root")
M2400_wwgg = M2400_events_wwgg["limit"].arrays(['limit']).limit
M2600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2600_MH125/higgsCombineWWggcat12_MX2600_MH125_2017.AsymptoticLimits.mH125.root")
M2600_wwgg = M2600_events_wwgg["limit"].arrays(['limit']).limit
M2800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2800_MH125/higgsCombineWWggcat12_MX2800_MH125_2017.AsymptoticLimits.mH125.root")
M2800_wwgg = M2800_events_wwgg["limit"].arrays(['limit']).limit
M3000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX3000_MH125/higgsCombineWWggcat12_MX3000_MH125_2017.AsymptoticLimits.mH125.root")
M3000_wwgg = M3000_events_wwgg["limit"].arrays(['limit']).limit

# %%
hep.style.use(hep.style.CMS)

hep.cms.label("preliminary", data=True, year='2017', lumi=41.5)   
# set figure size
plt.rcParams["figure.figsize"] = (16, 10)

allcat_values = [500,550,600,650,700,750,800,850,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
plt.plot(allcat_values, [M500_cat_cat12[2],M550_cat_cat12[2],M600_cat_cat12[2],M650_cat_cat12[2],M700_cat_cat12[2],M750_cat_cat12[2],M800_cat_cat12[2],M850_cat_cat12[2],M1000_cat_cat12[2],M1100_cat_cat12[2],M1200_cat_cat12[2],M1300_cat_cat12[2],M1400_cat_cat12[2],M1500_cat_cat12[2],M1600_cat_cat12[2],M1700_cat_cat12[2],M1800_cat_cat12[2],M1900_cat_cat12[2],M2000_cat_cat12[2],M2200_cat_cat12[2],M2400_cat_cat12[2],M2600_cat_cat12[2],M2800_cat_cat12[2],M3000_cat_cat12[2]],color='black', linewidth=2,linestyle='-', label='Asymptotic Limits CLs expected')
plt.plot(allcat_values, [M500_wwgg[2],M550_wwgg[2],M600_wwgg[2],M650_wwgg[2],M700_wwgg[2],M750_wwgg[2],M800_wwgg[2],M850_wwgg[2],M1000_wwgg[2],M1100_wwgg[2],M1200_wwgg[2],M1300_wwgg[2],M1400_wwgg[2],M1500_wwgg[2],M1600_wwgg[2],M1700_wwgg[2],M1800_wwgg[2],M1900_wwgg[2],M2000_wwgg[2],M2200_wwgg[2],M2400_wwgg[2],M2600_wwgg[2],M2800_wwgg[2],M3000_wwgg[2]],color='blue', linewidth=2,linestyle='--', label='WWgg signal')

# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M500_cat_cat12[1],M550_cat_cat12[1],M600_cat_cat12[1],M650_cat_cat12[1],M700_cat_cat12[1],M750_cat_cat12[1],M800_cat_cat12[1],M850_cat_cat12[1],M1000_cat_cat12[1],M1100_cat_cat12[1],M1200_cat_cat12[1],M1300_cat_cat12[1],M1400_cat_cat12[1],M1500_cat_cat12[1],M1600_cat_cat12[1],M1700_cat_cat12[1],M1800_cat_cat12[1],M1900_cat_cat12[1],M2000_cat_cat12[1],M2200_cat_cat12[1],M2400_cat_cat12[1],M2600_cat_cat12[1],M2800_cat_cat12[1],M3000_cat_cat12[1]], [M500_cat_cat12[3],M550_cat_cat12[3],M600_cat_cat12[3],M650_cat_cat12[3],M700_cat_cat12[3],M750_cat_cat12[3],M800_cat_cat12[3],M850_cat_cat12[3],M1000_cat_cat12[3],M1100_cat_cat12[3],M1200_cat_cat12[3],M1300_cat_cat12[3],M1400_cat_cat12[3],M1500_cat_cat12[3],M1600_cat_cat12[3],M1700_cat_cat12[3],M1800_cat_cat12[3],M1900_cat_cat12[3],M2000_cat_cat12[3],M2200_cat_cat12[3],M2400_cat_cat12[3],M2600_cat_cat12[3],M2800_cat_cat12[3],M3000_cat_cat12[3]], color='#04cb02', alpha=1, label= r'68% expected')#r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M500_cat_cat12[0],M550_cat_cat12[0],M600_cat_cat12[0],M650_cat_cat12[0],M700_cat_cat12[0],M750_cat_cat12[0],M800_cat_cat12[0],M850_cat_cat12[0],M1000_cat_cat12[0],M1100_cat_cat12[0],M1200_cat_cat12[0],M1300_cat_cat12[0],M1400_cat_cat12[0],M1500_cat_cat12[0],M1600_cat_cat12[0],M1700_cat_cat12[0],M1800_cat_cat12[0],M1900_cat_cat12[0],M2000_cat_cat12[0],M2200_cat_cat12[0],M2400_cat_cat12[0],M2600_cat_cat12[0],M2800_cat_cat12[0],M3000_cat_cat12[0]],[M500_cat_cat12[1],M550_cat_cat12[1],M600_cat_cat12[1],M650_cat_cat12[1],M700_cat_cat12[1],M750_cat_cat12[1],M800_cat_cat12[1],M850_cat_cat12[1],M1000_cat_cat12[1],M1100_cat_cat12[1],M1200_cat_cat12[1],M1300_cat_cat12[1],M1400_cat_cat12[1],M1500_cat_cat12[1],M1600_cat_cat12[1],M1700_cat_cat12[1],M1800_cat_cat12[1],M1900_cat_cat12[1],M2000_cat_cat12[1],M2200_cat_cat12[1],M2400_cat_cat12[1],M2600_cat_cat12[1],M2800_cat_cat12[1],M3000_cat_cat12[1]], color='gold', alpha=1, label= r'95% expected')#r'±2 std. deviation')
plt.fill_between(allcat_values,  [M500_cat_cat12[3],M550_cat_cat12[3],M600_cat_cat12[3],M650_cat_cat12[3],M700_cat_cat12[3],M750_cat_cat12[3],M800_cat_cat12[3],M850_cat_cat12[3],M1000_cat_cat12[3],M1100_cat_cat12[3],M1200_cat_cat12[3],M1300_cat_cat12[3],M1400_cat_cat12[3],M1500_cat_cat12[3],M1600_cat_cat12[3],M1700_cat_cat12[3],M1800_cat_cat12[3],M1900_cat_cat12[3],M2000_cat_cat12[3],M2200_cat_cat12[3],M2400_cat_cat12[3],M2600_cat_cat12[3],M2800_cat_cat12[3],M3000_cat_cat12[3]],  [M500_cat_cat12[4],M550_cat_cat12[4],M600_cat_cat12[4],M650_cat_cat12[4],M700_cat_cat12[4],M750_cat_cat12[4],M800_cat_cat12[4],M850_cat_cat12[4],M1000_cat_cat12[4],M1100_cat_cat12[4],M1200_cat_cat12[4],M1300_cat_cat12[4],M1400_cat_cat12[4],M1500_cat_cat12[4],M1600_cat_cat12[4],M1700_cat_cat12[4],M1800_cat_cat12[4],M1900_cat_cat12[4],M2000_cat_cat12[4],M2200_cat_cat12[4],M2400_cat_cat12[4],M2600_cat_cat12[4],M2800_cat_cat12[4],M3000_cat_cat12[4]], color='gold', alpha=1)

# 添加标签和标题
plt.xlabel(r'Radion Mass (GeV)')
# plt.ylabel(r'95% CL limits on $\sigma(ggX)*Br(XHHWWgg)[fb]$')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(500,3000)
#每1000GeV一个刻度
# plt.xticks(np.arange(200, 3001, 500))
# set x ticks
# plt.xticks(np.arange(1000, 3001, 500))
# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,10000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(0.95, 0.95))

# %% [markdown]
# # cat1234

# %%
M250_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX250_MH125/higgsCombinecat34_MX250_MH125_2017.AsymptoticLimits.mH125.root")
M250_cat1234 = M250_events_cat1234["limit"].arrays(['limit']).limit*100
M260_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX260_MH125/higgsCombinecat34_MX260_MH125_2017.AsymptoticLimits.mH125.root")
M260_cat1234 = M260_events_cat1234["limit"].arrays(['limit']).limit*100
M270_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX270_MH125/higgsCombinecat34_MX270_MH125_2017.AsymptoticLimits.mH125.root")
M270_cat1234 = M270_events_cat1234["limit"].arrays(['limit']).limit*100
M280_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX280_MH125/higgsCombinecat34_MX280_MH125_2017.AsymptoticLimits.mH125.root")
M280_cat1234 = M280_events_cat1234["limit"].arrays(['limit']).limit*100
M300_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX300_MH125/higgsCombinecat34_MX300_MH125_2017.AsymptoticLimits.mH125.root")
M300_cat1234 = M300_events_cat1234["limit"].arrays(['limit']).limit*100
M320_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX320_MH125/higgsCombinecat34_MX320_MH125_2017.AsymptoticLimits.mH125.root")
M320_cat1234 = M320_events_cat1234["limit"].arrays(['limit']).limit*100
# M350_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX350_MH125/higgsCombinecat34_MX350_MH125_2017.AsymptoticLimits.mH125.root")
# M350_cat1234 = M350_events_cat1234["limit"].arrays(['limit']).limit*100
M400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX400_MH125/higgsCombinecat34_MX400_MH125_2017.AsymptoticLimits.mH125.root")
M400_cat1234 = M400_events_cat1234["limit"].arrays(['limit']).limit*100
M450_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX450_MH125/higgsCombinecat34_MX450_MH125_2017.AsymptoticLimits.mH125.root")
M450_cat1234 = M450_events_cat1234["limit"].arrays(['limit']).limit*100
M500_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX500_MH125/higgsCombinecat1234_MX500_MH125_2017.AsymptoticLimits.mH125.root")
M500_cat1234 = M500_events_cat1234["limit"].arrays(['limit']).limit*100
M550_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX550_MH125/higgsCombinecat1234_MX550_MH125_2017.AsymptoticLimits.mH125.root")
M550_cat1234 = M550_events_cat1234["limit"].arrays(['limit']).limit*100
M600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX600_MH125/higgsCombinecat1234_MX600_MH125_2017.AsymptoticLimits.mH125.root")
M600_cat1234 = M600_events_cat1234["limit"].arrays(['limit']).limit*100
M650_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX650_MH125/higgsCombinecat1234_MX650_MH125_2017.AsymptoticLimits.mH125.root")
M650_cat1234 = M650_events_cat1234["limit"].arrays(['limit']).limit*100
M700_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX700_MH125/higgsCombinecat1234_MX700_MH125_2017.AsymptoticLimits.mH125.root")
M700_cat1234 = M700_events_cat1234["limit"].arrays(['limit']).limit*100
M750_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX750_MH125/higgsCombinecat1234_MX750_MH125_2017.AsymptoticLimits.mH125.root")
M750_cat1234 = M750_events_cat1234["limit"].arrays(['limit']).limit*100
M800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX800_MH125/higgsCombinecat1234_MX800_MH125_2017.AsymptoticLimits.mH125.root")
M800_cat1234 = M800_events_cat1234["limit"].arrays(['limit']).limit*100
M850_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX850_MH125/higgsCombinecat1234_MX850_MH125_2017.AsymptoticLimits.mH125.root")
M850_cat1234 = M850_events_cat1234["limit"].arrays(['limit']).limit*100
M1000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1000_MH125/higgsCombinecat1234_MX1000_MH125_2017.AsymptoticLimits.mH125.root")
M1000_cat1234 = M1000_events_cat1234["limit"].arrays(['limit']).limit*100
M1100_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1100_MH125/higgsCombinecat12_MX1100_MH125_2017.AsymptoticLimits.mH125.root")
M1100_cat1234 = M1100_events_cat1234["limit"].arrays(['limit']).limit
M1200_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1200_MH125/higgsCombinecat12_MX1200_MH125_2017.AsymptoticLimits.mH125.root")
M1200_cat1234 = M1200_events_cat1234["limit"].arrays(['limit']).limit
M1300_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1300_MH125/higgsCombinecat12_MX1300_MH125_2017.AsymptoticLimits.mH125.root")
M1300_cat1234 = M1300_events_cat1234["limit"].arrays(['limit']).limit
M1400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1400_MH125/higgsCombinecat12_MX1400_MH125_2017.AsymptoticLimits.mH125.root")
M1400_cat1234 = M1400_events_cat1234["limit"].arrays(['limit']).limit
M1500_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1500_MH125/higgsCombinecat12_MX1500_MH125_2017.AsymptoticLimits.mH125.root")
M1500_cat1234 = M1500_events_cat1234["limit"].arrays(['limit']).limit
M1600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1600_MH125/higgsCombinecat12_MX1600_MH125_2017.AsymptoticLimits.mH125.root")
M1600_cat1234 = M1600_events_cat1234["limit"].arrays(['limit']).limit
M1700_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1700_MH125/higgsCombinecat12_MX1700_MH125_2017.AsymptoticLimits.mH125.root")
M1700_cat1234 = M1700_events_cat1234["limit"].arrays(['limit']).limit
M1800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1800_MH125/higgsCombinecat12_MX1800_MH125_2017.AsymptoticLimits.mH125.root")
M1800_cat1234 = M1800_events_cat1234["limit"].arrays(['limit']).limit
M1900_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX1900_MH125/higgsCombinecat12_MX1900_MH125_2017.AsymptoticLimits.mH125.root")
M1900_cat1234 = M1900_events_cat1234["limit"].arrays(['limit']).limit
M2000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2000_MH125/higgsCombinecat12_MX2000_MH125_2017.AsymptoticLimits.mH125.root")
M2000_cat1234 = M2000_events_cat1234["limit"].arrays(['limit']).limit
M2200_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2200_MH125/higgsCombinecat12_MX2200_MH125_2017.AsymptoticLimits.mH125.root")
M2200_cat1234 = M2200_events_cat1234["limit"].arrays(['limit']).limit
M2400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2400_MH125/higgsCombinecat12_MX2400_MH125_2017.AsymptoticLimits.mH125.root")
M2400_cat1234 = M2400_events_cat1234["limit"].arrays(['limit']).limit
M2600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2600_MH125/higgsCombinecat12_MX2600_MH125_2017.AsymptoticLimits.mH125.root")
M2600_cat1234 = M2600_events_cat1234["limit"].arrays(['limit']).limit
M2800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX2800_MH125/higgsCombinecat12_MX2800_MH125_2017.AsymptoticLimits.mH125.root")
M2800_cat1234 = M2800_events_cat1234["limit"].arrays(['limit']).limit
M3000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2017datacard/datacard_MX3000_MH125/higgsCombinecat12_MX3000_MH125_2017.AsymptoticLimits.mH125.root")
M3000_cat1234 = M3000_events_cat1234["limit"].arrays(['limit']).limit

# %%
hep.style.use(hep.style.CMS)

hep.cms.label("preliminary", data=True, year='2017', lumi=41.5)   
# set figure size
plt.rcParams["figure.figsize"] = (16, 10)
# cat34 = [250,260,270,280,300,320,400,450,500,550,600,650,700,750,800,850,1000]
# plt.plot(cat34, [M250_cat34[2],M260_cat34[2],M270_cat34[2],M280_cat34[2],M300_cat34[2],M320_cat34[2],M400_cat34[2],M450_cat34[2],M500_cat34[2],M550_cat34[2],M600_cat34[2],M650_cat34[2],M700_cat34[2],M750_cat34[2],M800_cat34[2],M850_cat34[2],M1000_cat34[2]],color='purple', linewidth=2,linestyle='--', label='Resolved')#'Asymptotic Limits CLs expected'

# cat12values = [500,550,600,650,700,750,800,850,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
# plt.plot(cat12values, [M500_cat_cat12[2],M550_cat_cat12[2],M600_cat_cat12[2],M650_cat_cat12[2],M700_cat_cat12[2],M750_cat_cat12[2],M800_cat_cat12[2],M850_cat_cat12[2],M1000_cat_cat12[2]+40,M1100_cat_cat12[2],M1200_cat_cat12[2],M1300_cat_cat12[2],M1400_cat_cat12[2],M1500_cat_cat12[2],M1600_cat_cat12[2],M1700_cat_cat12[2],M1800_cat_cat12[2],M1900_cat_cat12[2],M2000_cat_cat12[2],M2200_cat_cat12[2],M2400_cat_cat12[2],M2600_cat_cat12[2],M2800_cat_cat12[2],M3000_cat_cat12[2]],color='red', linewidth=2,linestyle='--', label='Boosted')
allcat_values = [250,260,270,280,300,320,400,450,500,550,600,650,700,750,800,850,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
plt.plot(allcat_values, [M250_cat1234[2],M260_cat1234[2],M270_cat1234[2],M280_cat1234[2],M300_cat1234[2],M320_cat1234[2],M400_cat1234[2],M450_cat1234[2],M500_cat1234[2],M550_cat1234[2],M600_cat1234[2],M650_cat1234[2],M700_cat1234[2],M750_cat1234[2],M800_cat1234[2],M850_cat1234[2],M1000_cat1234[2],M1100_cat1234[2],M1200_cat1234[2],M1300_cat1234[2],M1400_cat1234[2],M1500_cat1234[2],M1600_cat1234[2],M1700_cat1234[2],M1800_cat1234[2],M1900_cat1234[2],M2000_cat1234[2],M2200_cat1234[2],M2400_cat1234[2],M2600_cat1234[2],M2800_cat1234[2],M3000_cat1234[2]],color='black', linewidth=2,linestyle='-', label='Asymptotic Limits CLs expected')
# plt.plot(allcat_values, [M250_wwgg[2],M260_wwgg[2],M270_wwgg[2],M280_wwgg[2],M300_wwgg[2],M320_wwgg[2],M400_wwgg[2],M450_wwgg[2],M500_wwgg[2],M550_wwgg[2],M600_wwgg[2],M650_wwgg[2],M700_wwgg[2],M750_wwgg[2],M800_wwgg[2],M850_wwgg[2],M1000_wwgg[2],M1100_wwgg[2],M1200_wwgg[2],M1300_wwgg[2],M1400_wwgg[2],M1500_wwgg[2],M1600_wwgg[2],M1700_wwgg[2],M1800_wwgg[2],M1900_wwgg[2],M2000_wwgg[2],M2200_wwgg[2],M2400_wwgg[2],M2600_wwgg[2],M2800_wwgg[2],M3000_wwgg[2]],color='blue', linewidth=2,linestyle='--', label='WWgg signal')

# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M250_cat1234[1],M260_cat1234[1],M270_cat1234[1],M280_cat1234[1],M300_cat1234[1],M320_cat1234[1],M400_cat1234[1],M450_cat1234[1],M500_cat1234[1],M550_cat1234[1],M600_cat1234[1],M650_cat1234[1],M700_cat1234[1],M750_cat1234[1],M800_cat1234[1],M850_cat1234[1],M1000_cat1234[1],M1100_cat1234[1],M1200_cat1234[1],M1300_cat1234[1],M1400_cat1234[1],M1500_cat1234[1],M1600_cat1234[1],M1700_cat1234[1],M1800_cat1234[1],M1900_cat1234[1],M2000_cat1234[1],M2200_cat1234[1],M2400_cat1234[1],M2600_cat1234[1],M2800_cat1234[1],M3000_cat1234[1]], [M250_cat1234[3],M260_cat1234[3],M270_cat1234[3],M280_cat1234[3],M300_cat1234[3],M320_cat1234[3],M400_cat1234[3],M450_cat1234[3],M500_cat1234[3],M550_cat1234[3],M600_cat1234[3],M650_cat1234[3],M700_cat1234[3],M750_cat1234[3],M800_cat1234[3],M850_cat1234[3],M1000_cat1234[3],M1100_cat1234[3],M1200_cat1234[3],M1300_cat1234[3],M1400_cat1234[3],M1500_cat1234[3],M1600_cat1234[3],M1700_cat1234[3],M1800_cat1234[3],M1900_cat1234[3],M2000_cat1234[3],M2200_cat1234[3],M2400_cat1234[3],M2600_cat1234[3],M2800_cat1234[3],M3000_cat1234[3]], color='#04cb02', alpha=1, label= r'68% expected')#'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M250_cat1234[0],M260_cat1234[0],M270_cat1234[0],M280_cat1234[0],M300_cat1234[0],M320_cat1234[0],M400_cat1234[0],M450_cat1234[0],M500_cat1234[0],M550_cat1234[0],M600_cat1234[0],M650_cat1234[0],M700_cat1234[0],M750_cat1234[0],M800_cat1234[0],M850_cat1234[0],M1000_cat1234[0],M1100_cat1234[0],M1200_cat1234[0],M1300_cat1234[0],M1400_cat1234[0],M1500_cat1234[0],M1600_cat1234[0],M1700_cat1234[0],M1800_cat1234[0],M1900_cat1234[0],M2000_cat1234[0],M2200_cat1234[0],M2400_cat1234[0],M2600_cat1234[0],M2800_cat1234[0],M3000_cat1234[0]],[M250_cat1234[1],M260_cat1234[1],M270_cat1234[1],M280_cat1234[1],M300_cat1234[1],M320_cat1234[1],M400_cat1234[1],M450_cat1234[1],M500_cat1234[1],M550_cat1234[1],M600_cat1234[1],M650_cat1234[1],M700_cat1234[1],M750_cat1234[1],M800_cat1234[1],M850_cat1234[1],M1000_cat1234[1],M1100_cat1234[1],M1200_cat1234[1],M1300_cat1234[1],M1400_cat1234[1],M1500_cat1234[1],M1600_cat1234[1],M1700_cat1234[1],M1800_cat1234[1],M1900_cat1234[1],M2000_cat1234[1],M2200_cat1234[1],M2400_cat1234[1],M2600_cat1234[1],M2800_cat1234[1],M3000_cat1234[1]], color='gold', alpha=1, label= r'95 %expected')#r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_cat1234[3],M260_cat1234[3],M270_cat1234[3],M280_cat1234[3],M300_cat1234[3],M320_cat1234[3],M400_cat1234[3],M450_cat1234[3],M500_cat1234[3],M550_cat1234[3],M600_cat1234[3],M650_cat1234[3],M700_cat1234[3],M750_cat1234[3],M800_cat1234[3],M850_cat1234[3],M1000_cat1234[3],M1100_cat1234[3],M1200_cat1234[3],M1300_cat1234[3],M1400_cat1234[3],M1500_cat1234[3],M1600_cat1234[3],M1700_cat1234[3],M1800_cat1234[3],M1900_cat1234[3],M2000_cat1234[3],M2200_cat1234[3],M2400_cat1234[3],M2600_cat1234[3],M2800_cat1234[3],M3000_cat1234[3]],  [M250_cat1234[4],M260_cat1234[4],M270_cat1234[4],M280_cat1234[4],M300_cat1234[4],M320_cat1234[4],M400_cat1234[4],M450_cat1234[4],M500_cat1234[4],M550_cat1234[4],M600_cat1234[4],M650_cat1234[4],M700_cat1234[4],M750_cat1234[4],M800_cat1234[4],M850_cat1234[4],M1000_cat1234[4],M1100_cat1234[4],M1200_cat1234[4],M1300_cat1234[4],M1400_cat1234[4],M1500_cat1234[4],M1600_cat1234[4],M1700_cat1234[4],M1800_cat1234[4],M1900_cat1234[4],M2000_cat1234[4],M2200_cat1234[4],M2400_cat1234[4],M2600_cat1234[4],M2800_cat1234[4],M3000_cat1234[4]], color='gold', alpha=1)

# 添加标签和标题
plt.xlabel(r'Radion Mass (GeV)')
# plt.ylabel(r'95% CL limits on $\sigma(ggX)*Br(XHHWWgg)[fb]$')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,3000)
plt.xticks([250, 500, 1000, 1500, 2000, 3000], ['250', '500', '1000', '1500', '2000', '3000'])
# plt.xticks(np.arange(250, 3001, 100))
# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,100000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(0.95, 0.95))

# %% [markdown]
# # 2018

# %%
M500_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX500_MH125/higgsCombinecat12_MX500_MH125_2018.AsymptoticLimits.mH125.root")
M500_cat_cat12 = M500_events_cat12["limit"].arrays(['limit']).limit*100
M550_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX550_MH125/higgsCombinecat12_MX550_MH125_2018.AsymptoticLimits.mH125.root")
M550_cat_cat12 = M550_events_cat12["limit"].arrays(['limit']).limit*100
M600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX600_MH125/higgsCombinecat12_MX600_MH125_2018.AsymptoticLimits.mH125.root")
M600_cat_cat12 = M600_events_cat12["limit"].arrays(['limit']).limit*100
M650_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX650_MH125/higgsCombinecat12_MX650_MH125_2018.AsymptoticLimits.mH125.root")
M650_cat_cat12 = M650_events_cat12["limit"].arrays(['limit']).limit*100
M700_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX700_MH125/higgsCombinecat12_MX700_MH125_2018.AsymptoticLimits.mH125.root")
M700_cat_cat12 = M700_events_cat12["limit"].arrays(['limit']).limit*100
M750_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX750_MH125/higgsCombinecat12_MX750_MH125_2018.AsymptoticLimits.mH125.root")
M750_cat_cat12 = M750_events_cat12["limit"].arrays(['limit']).limit*100
M800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX800_MH125/higgsCombinecat12_MX800_MH125_2018.AsymptoticLimits.mH125.root")
M800_cat_cat12 = M800_events_cat12["limit"].arrays(['limit']).limit*100
M850_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX850_MH125/higgsCombinecat12_MX850_MH125_2018.AsymptoticLimits.mH125.root")
M850_cat_cat12 = M850_events_cat12["limit"].arrays(['limit']).limit*100
M1000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1000_MH125/higgsCombinecat12_MX1000_MH125_2018.AsymptoticLimits.mH125.root")
M1000_cat_cat12 = M1000_events_cat12["limit"].arrays(['limit']).limit
M1100_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1100_MH125/higgsCombinecat12_MX1100_MH125_2018.AsymptoticLimits.mH125.root")
M1100_cat_cat12 = M1100_events_cat12["limit"].arrays(['limit']).limit
M1200_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1200_MH125/higgsCombinecat12_MX1200_MH125_2018.AsymptoticLimits.mH125.root")
M1200_cat_cat12 = M1200_events_cat12["limit"].arrays(['limit']).limit
M1300_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1300_MH125/higgsCombinecat12_MX1300_MH125_2018.AsymptoticLimits.mH125.root")
M1300_cat_cat12 = M1300_events_cat12["limit"].arrays(['limit']).limit
M1400_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1400_MH125/higgsCombinecat12_MX1400_MH125_2018.AsymptoticLimits.mH125.root")
M1400_cat_cat12 = M1400_events_cat12["limit"].arrays(['limit']).limit
M1500_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1500_MH125/higgsCombinecat12_MX1500_MH125_2018.AsymptoticLimits.mH125.root")
M1500_cat_cat12 = M1500_events_cat12["limit"].arrays(['limit']).limit
M1600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1600_MH125/higgsCombinecat12_MX1600_MH125_2018.AsymptoticLimits.mH125.root")
M1600_cat_cat12 = M1600_events_cat12["limit"].arrays(['limit']).limit
M1700_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1700_MH125/higgsCombinecat12_MX1700_MH125_2018.AsymptoticLimits.mH125.root")
M1700_cat_cat12 = M1700_events_cat12["limit"].arrays(['limit']).limit
M1800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1800_MH125/higgsCombinecat12_MX1800_MH125_2018.AsymptoticLimits.mH125.root")
M1800_cat_cat12 = M1800_events_cat12["limit"].arrays(['limit']).limit
M1900_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1900_MH125/higgsCombinecat12_MX1900_MH125_2018.AsymptoticLimits.mH125.root")
M1900_cat_cat12 = M1900_events_cat12["limit"].arrays(['limit']).limit
M2000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2000_MH125/higgsCombinecat12_MX2000_MH125_2018.AsymptoticLimits.mH125.root")
M2000_cat_cat12 = M2000_events_cat12["limit"].arrays(['limit']).limit
M2200_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2200_MH125/higgsCombinecat12_MX2200_MH125_2018.AsymptoticLimits.mH125.root")
M2200_cat_cat12 = M2200_events_cat12["limit"].arrays(['limit']).limit
M2400_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2400_MH125/higgsCombinecat12_MX2400_MH125_2018.AsymptoticLimits.mH125.root")
M2400_cat_cat12 = M2400_events_cat12["limit"].arrays(['limit']).limit
M2600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2600_MH125/higgsCombinecat12_MX2600_MH125_2018.AsymptoticLimits.mH125.root")
M2600_cat_cat12 = M2600_events_cat12["limit"].arrays(['limit']).limit
M2800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2800_MH125/higgsCombinecat12_MX2800_MH125_2018.AsymptoticLimits.mH125.root")
M2800_cat_cat12 = M2800_events_cat12["limit"].arrays(['limit']).limit
M3000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX3000_MH125/higgsCombinecat12_MX3000_MH125_2018.AsymptoticLimits.mH125.root")
M3000_cat_cat12 = M3000_events_cat12["limit"].arrays(['limit']).limit

M500_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX500_MH125/higgsCombineWWggcat12_MX500_MH125_2018.AsymptoticLimits.mH125.root")
M500_wwgg = M500_events_wwgg["limit"].arrays(['limit']).limit*100
M550_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX550_MH125/higgsCombineWWggcat12_MX550_MH125_2018.AsymptoticLimits.mH125.root")
M550_wwgg = M550_events_wwgg["limit"].arrays(['limit']).limit*100
M600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX600_MH125/higgsCombineWWggcat12_MX600_MH125_2018.AsymptoticLimits.mH125.root")
M600_wwgg = M600_events_wwgg["limit"].arrays(['limit']).limit*100
M650_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX650_MH125/higgsCombineWWggcat12_MX650_MH125_2018.AsymptoticLimits.mH125.root")
M650_wwgg = M650_events_wwgg["limit"].arrays(['limit']).limit*100
M700_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX700_MH125/higgsCombineWWggcat12_MX700_MH125_2018.AsymptoticLimits.mH125.root")
M700_wwgg = M700_events_wwgg["limit"].arrays(['limit']).limit*100
M750_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX750_MH125/higgsCombineWWggcat12_MX750_MH125_2018.AsymptoticLimits.mH125.root")
M750_wwgg = M750_events_wwgg["limit"].arrays(['limit']).limit*100
M800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX800_MH125/higgsCombineWWggcat12_MX800_MH125_2018.AsymptoticLimits.mH125.root")
M800_wwgg = M800_events_wwgg["limit"].arrays(['limit']).limit*100
M850_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX850_MH125/higgsCombineWWggcat12_MX850_MH125_2018.AsymptoticLimits.mH125.root")
M850_wwgg = M850_events_wwgg["limit"].arrays(['limit']).limit*100
M1000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1000_MH125/higgsCombineWWggcat12_MX1000_MH125_2018.AsymptoticLimits.mH125.root")
M1000_wwgg = M1000_events_wwgg["limit"].arrays(['limit']).limit
M1100_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1100_MH125/higgsCombineWWggcat12_MX1100_MH125_2018.AsymptoticLimits.mH125.root")
M1100_wwgg = M1100_events_wwgg["limit"].arrays(['limit']).limit
M1200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1200_MH125/higgsCombineWWggcat12_MX1200_MH125_2018.AsymptoticLimits.mH125.root")
M1200_wwgg = M1200_events_wwgg["limit"].arrays(['limit']).limit
M1300_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1300_MH125/higgsCombineWWggcat12_MX1300_MH125_2018.AsymptoticLimits.mH125.root")
M1300_wwgg = M1300_events_wwgg["limit"].arrays(['limit']).limit
M1400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1400_MH125/higgsCombineWWggcat12_MX1400_MH125_2018.AsymptoticLimits.mH125.root")
M1400_wwgg = M1400_events_wwgg["limit"].arrays(['limit']).limit
M1500_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1500_MH125/higgsCombineWWggcat12_MX1500_MH125_2018.AsymptoticLimits.mH125.root")
M1500_wwgg = M1500_events_wwgg["limit"].arrays(['limit']).limit
M1600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1600_MH125/higgsCombineWWggcat12_MX1600_MH125_2018.AsymptoticLimits.mH125.root")
M1600_wwgg = M1600_events_wwgg["limit"].arrays(['limit']).limit
M1700_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1700_MH125/higgsCombineWWggcat12_MX1700_MH125_2018.AsymptoticLimits.mH125.root")
M1700_wwgg = M1700_events_wwgg["limit"].arrays(['limit']).limit
M1800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1800_MH125/higgsCombineWWggcat12_MX1800_MH125_2018.AsymptoticLimits.mH125.root")
M1800_wwgg = M1800_events_wwgg["limit"].arrays(['limit']).limit
M1900_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1900_MH125/higgsCombineWWggcat12_MX1900_MH125_2018.AsymptoticLimits.mH125.root")
M1900_wwgg = M1900_events_wwgg["limit"].arrays(['limit']).limit
M2000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2000_MH125/higgsCombineWWggcat12_MX2000_MH125_2018.AsymptoticLimits.mH125.root")
M2000_wwgg = M2000_events_wwgg["limit"].arrays(['limit']).limit
M2200_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2200_MH125/higgsCombineWWggcat12_MX2200_MH125_2018.AsymptoticLimits.mH125.root")
M2200_wwgg = M2200_events_wwgg["limit"].arrays(['limit']).limit
M2400_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2400_MH125/higgsCombineWWggcat12_MX2400_MH125_2018.AsymptoticLimits.mH125.root")
M2400_wwgg = M2400_events_wwgg["limit"].arrays(['limit']).limit
M2600_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2600_MH125/higgsCombineWWggcat12_MX2600_MH125_2018.AsymptoticLimits.mH125.root")
M2600_wwgg = M2600_events_wwgg["limit"].arrays(['limit']).limit
M2800_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2800_MH125/higgsCombineWWggcat12_MX2800_MH125_2018.AsymptoticLimits.mH125.root")
M2800_wwgg = M2800_events_wwgg["limit"].arrays(['limit']).limit
M3000_events_wwgg = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX3000_MH125/higgsCombineWWggcat12_MX3000_MH125_2018.AsymptoticLimits.mH125.root")
M3000_wwgg = M3000_events_wwgg["limit"].arrays(['limit']).limit

# %%
hep.style.use(hep.style.CMS)

hep.cms.label("preliminary", data=True, year='2018', lumi=59.83)   
# set figure size
plt.rcParams["figure.figsize"] = (16, 10)

allcat_values = [500,550,600,650,700,750,800,850,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
plt.plot(allcat_values, [M500_cat_cat12[2],M550_cat_cat12[2],M600_cat_cat12[2],M650_cat_cat12[2],M700_cat_cat12[2],M750_cat_cat12[2],M800_cat_cat12[2],M850_cat_cat12[2],M1000_cat_cat12[2],M1100_cat_cat12[2],M1200_cat_cat12[2],M1300_cat_cat12[2],M1400_cat_cat12[2],M1500_cat_cat12[2],M1600_cat_cat12[2],M1700_cat_cat12[2],M1800_cat_cat12[2],M1900_cat_cat12[2],M2000_cat_cat12[2],M2200_cat_cat12[2],M2400_cat_cat12[2],M2600_cat_cat12[2],M2800_cat_cat12[2],M3000_cat_cat12[2]],color='black', linewidth=2,linestyle='-', label='Asymptotic Limits CLs expected')
plt.plot(allcat_values, [M500_wwgg[2],M550_wwgg[2],M600_wwgg[2],M650_wwgg[2],M700_wwgg[2],M750_wwgg[2],M800_wwgg[2],M850_wwgg[2],M1000_wwgg[2],M1100_wwgg[2],M1200_wwgg[2],M1300_wwgg[2],M1400_wwgg[2],M1500_wwgg[2],M1600_wwgg[2],M1700_wwgg[2],M1800_wwgg[2],M1900_wwgg[2],M2000_wwgg[2],M2200_wwgg[2],M2400_wwgg[2],M2600_wwgg[2],M2800_wwgg[2],M3000_wwgg[2]],color='blue', linewidth=2,linestyle='--', label='WWgg signal')

# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M500_cat_cat12[1],M550_cat_cat12[1],M600_cat_cat12[1],M650_cat_cat12[1],M700_cat_cat12[1],M750_cat_cat12[1],M800_cat_cat12[1],M850_cat_cat12[1],M1000_cat_cat12[1],M1100_cat_cat12[1],M1200_cat_cat12[1],M1300_cat_cat12[1],M1400_cat_cat12[1],M1500_cat_cat12[1],M1600_cat_cat12[1],M1700_cat_cat12[1],M1800_cat_cat12[1],M1900_cat_cat12[1],M2000_cat_cat12[1],M2200_cat_cat12[1],M2400_cat_cat12[1],M2600_cat_cat12[1],M2800_cat_cat12[1],M3000_cat_cat12[1]], [M500_cat_cat12[3],M550_cat_cat12[3],M600_cat_cat12[3],M650_cat_cat12[3],M700_cat_cat12[3],M750_cat_cat12[3],M800_cat_cat12[3],M850_cat_cat12[3],M1000_cat_cat12[3],M1100_cat_cat12[3],M1200_cat_cat12[3],M1300_cat_cat12[3],M1400_cat_cat12[3],M1500_cat_cat12[3],M1600_cat_cat12[3],M1700_cat_cat12[3],M1800_cat_cat12[3],M1900_cat_cat12[3],M2000_cat_cat12[3],M2200_cat_cat12[3],M2400_cat_cat12[3],M2600_cat_cat12[3],M2800_cat_cat12[3],M3000_cat_cat12[3]], color='#04cb02', alpha=1, label= r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M500_cat_cat12[0],M550_cat_cat12[0],M600_cat_cat12[0],M650_cat_cat12[0],M700_cat_cat12[0],M750_cat_cat12[0],M800_cat_cat12[0],M850_cat_cat12[0],M1000_cat_cat12[0],M1100_cat_cat12[0],M1200_cat_cat12[0],M1300_cat_cat12[0],M1400_cat_cat12[0],M1500_cat_cat12[0],M1600_cat_cat12[0],M1700_cat_cat12[0],M1800_cat_cat12[0],M1900_cat_cat12[0],M2000_cat_cat12[0],M2200_cat_cat12[0],M2400_cat_cat12[0],M2600_cat_cat12[0],M2800_cat_cat12[0],M3000_cat_cat12[0]],[M500_cat_cat12[1],M550_cat_cat12[1],M600_cat_cat12[1],M650_cat_cat12[1],M700_cat_cat12[1],M750_cat_cat12[1],M800_cat_cat12[1],M850_cat_cat12[1],M1000_cat_cat12[1],M1100_cat_cat12[1],M1200_cat_cat12[1],M1300_cat_cat12[1],M1400_cat_cat12[1],M1500_cat_cat12[1],M1600_cat_cat12[1],M1700_cat_cat12[1],M1800_cat_cat12[1],M1900_cat_cat12[1],M2000_cat_cat12[1],M2200_cat_cat12[1],M2400_cat_cat12[1],M2600_cat_cat12[1],M2800_cat_cat12[1],M3000_cat_cat12[1]], color='gold', alpha=1, label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M500_cat_cat12[3],M550_cat_cat12[3],M600_cat_cat12[3],M650_cat_cat12[3],M700_cat_cat12[3],M750_cat_cat12[3],M800_cat_cat12[3],M850_cat_cat12[3],M1000_cat_cat12[3],M1100_cat_cat12[3],M1200_cat_cat12[3],M1300_cat_cat12[3],M1400_cat_cat12[3],M1500_cat_cat12[3],M1600_cat_cat12[3],M1700_cat_cat12[3],M1800_cat_cat12[3],M1900_cat_cat12[3],M2000_cat_cat12[3],M2200_cat_cat12[3],M2400_cat_cat12[3],M2600_cat_cat12[3],M2800_cat_cat12[3],M3000_cat_cat12[3]],  [M500_cat_cat12[4],M550_cat_cat12[4],M600_cat_cat12[4],M650_cat_cat12[4],M700_cat_cat12[4],M750_cat_cat12[4],M800_cat_cat12[4],M850_cat_cat12[4],M1000_cat_cat12[4],M1100_cat_cat12[4],M1200_cat_cat12[4],M1300_cat_cat12[4],M1400_cat_cat12[4],M1500_cat_cat12[4],M1600_cat_cat12[4],M1700_cat_cat12[4],M1800_cat_cat12[4],M1900_cat_cat12[4],M2000_cat_cat12[4],M2200_cat_cat12[4],M2400_cat_cat12[4],M2600_cat_cat12[4],M2800_cat_cat12[4],M3000_cat_cat12[4]], color='gold', alpha=1)

# 添加标签和标题
plt.xlabel(r'Radion Mass (GeV)')
# plt.ylabel(r'95% CL limits on $\sigma(ggX)*Br(XHHWWgg)[fb]$')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(500,3000)
#每1000GeV一个刻度
# plt.xticks(np.arange(200, 3001, 500))
# set x ticks
# plt.xticks(np.arange(1000, 3001, 500))
# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,10000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(0.95, 0.95))

# %%
M250_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX250_MH125/higgsCombinecat34_MX250_MH125_2018.AsymptoticLimits.mH125.root")
M250_cat34 = M250_events_cat34["limit"].arrays(['limit']).limit*100
M260_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX260_MH125/higgsCombinecat34_MX260_MH125_2018.AsymptoticLimits.mH125.root")
M260_cat34 = M260_events_cat34["limit"].arrays(['limit']).limit*100
M270_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX270_MH125/higgsCombinecat34_MX270_MH125_2018.AsymptoticLimits.mH125.root")
M270_cat34 = M270_events_cat34["limit"].arrays(['limit']).limit*100
M280_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX280_MH125/higgsCombinecat34_MX280_MH125_2018.AsymptoticLimits.mH125.root")
M280_cat34 = M280_events_cat34["limit"].arrays(['limit']).limit*100
M300_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX300_MH125/higgsCombinecat34_MX300_MH125_2018.AsymptoticLimits.mH125.root")
M300_cat34 = M300_events_cat34["limit"].arrays(['limit']).limit*100
M320_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX320_MH125/higgsCombinecat34_MX320_MH125_2018.AsymptoticLimits.mH125.root")
M320_cat34 = M320_events_cat34["limit"].arrays(['limit']).limit*100
M350_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX350_MH125/higgsCombinecat34_MX350_MH125_2018.AsymptoticLimits.mH125.root")
M350_cat34 = M350_events_cat34["limit"].arrays(['limit']).limit*100
M400_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX400_MH125/higgsCombinecat34_MX400_MH125_2018.AsymptoticLimits.mH125.root")
M400_cat34 = M400_events_cat34["limit"].arrays(['limit']).limit*100
M450_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX450_MH125/higgsCombinecat34_MX450_MH125_2018.AsymptoticLimits.mH125.root")
M450_cat34 = M450_events_cat34["limit"].arrays(['limit']).limit*100
M500_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX500_MH125/higgsCombinecat34_MX500_MH125_2018.AsymptoticLimits.mH125.root")
M500_cat34 = M500_events_cat34["limit"].arrays(['limit']).limit*100
M550_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX550_MH125/higgsCombinecat34_MX550_MH125_2018.AsymptoticLimits.mH125.root")
M550_cat34 = M550_events_cat34["limit"].arrays(['limit']).limit*100
M600_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX600_MH125/higgsCombinecat34_MX600_MH125_2018.AsymptoticLimits.mH125.root")
M600_cat34 = M600_events_cat34["limit"].arrays(['limit']).limit*100
M650_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX650_MH125/higgsCombinecat34_MX650_MH125_2018.AsymptoticLimits.mH125.root")
M650_cat34 = M650_events_cat34["limit"].arrays(['limit']).limit*100
M700_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX700_MH125/higgsCombinecat34_MX700_MH125_2018.AsymptoticLimits.mH125.root")
M700_cat34 = M700_events_cat34["limit"].arrays(['limit']).limit*100
M750_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX750_MH125/higgsCombinecat34_MX750_MH125_2018.AsymptoticLimits.mH125.root")
M750_cat34 = M750_events_cat34["limit"].arrays(['limit']).limit*100
M800_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX800_MH125/higgsCombinecat34_MX800_MH125_2018.AsymptoticLimits.mH125.root")
M800_cat34 = M800_events_cat34["limit"].arrays(['limit']).limit*100
M850_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX850_MH125/higgsCombinecat34_MX850_MH125_2018.AsymptoticLimits.mH125.root")
M850_cat34 = M850_events_cat34["limit"].arrays(['limit']).limit*100
M1000_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1000_MH125/higgsCombinecat34_MX1000_MH125_2018.AsymptoticLimits.mH125.root")
M1000_cat34 = M1000_events_cat34["limit"].arrays(['limit']).limit*100

# %%
hep.style.use(hep.style.CMS)
hep.cms.label("preliminary", data=True, year='UL2018', lumi=59.83)   
# set figure size
plt.rcParams["figure.figsize"] = (20,20)
allcat_values = [250,260,270,280,300,320,400,450,500,550,600,650,700,750,800,850,1000]
plt.plot(allcat_values, [M250_cat34[2],M260_cat34[2],M270_cat34[2],M280_cat34[2],M300_cat34[2],M320_cat34[2],M400_cat34[2],M450_cat34[2],M500_cat34[2],M550_cat34[2],M600_cat34[2],M650_cat34[2],M700_cat34[2],M750_cat34[2],M800_cat34[2],M850_cat34[2],M1000_cat34[2]],color='black', linewidth=2,linestyle='-', label='WWgg + ZZgg + bbgg Signal')#'Asymptotic Limits CLs expected'

# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M250_cat34[1],M260_cat34[1],M270_cat34[1],M280_cat34[1],M300_cat34[1],M320_cat34[1],M400_cat34[1],M450_cat34[1],M500_cat34[1],M550_cat34[1],M600_cat34[1],M650_cat34[1],M700_cat34[1],M750_cat34[1],M800_cat34[1],M850_cat34[1],M1000_cat34[1]], [M250_cat34[3],M260_cat34[3],M270_cat34[3],M280_cat34[3],M300_cat34[3],M320_cat34[3],M400_cat34[3],M450_cat34[3],M500_cat34[3],M550_cat34[3],M600_cat34[3],M650_cat34[3],M700_cat34[3],M750_cat34[3],M800_cat34[3],M850_cat34[3],M1000_cat34[3]], color='#04cb02', alpha=1, label= r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M250_cat34[0],M260_cat34[0],M270_cat34[0],M280_cat34[0],M300_cat34[0],M320_cat34[0],M400_cat34[0],M450_cat34[0],M500_cat34[0],M550_cat34[0],M600_cat34[0],M650_cat34[0],M700_cat34[0],M750_cat34[0],M800_cat34[0],M850_cat34[0],M1000_cat34[0]],[M250_cat34[1],M260_cat34[1],M270_cat34[1],M280_cat34[1],M300_cat34[1],M320_cat34[1],M400_cat34[1],M450_cat34[1],M500_cat34[1],M550_cat34[1],M600_cat34[1],M650_cat34[1],M700_cat34[1],M750_cat34[1],M800_cat34[1],M850_cat34[1],M1000_cat34[1]], color='gold', alpha=1, label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_cat34[3],M260_cat34[3],M270_cat34[3],M280_cat34[3],M300_cat34[3],M320_cat34[3],M400_cat34[3],M450_cat34[3],M500_cat34[3],M550_cat34[3],M600_cat34[3],M650_cat34[3],M700_cat34[3],M750_cat34[3],M800_cat34[3],M850_cat34[3],M1000_cat34[3]],  [M250_cat34[4],M260_cat34[4],M270_cat34[4],M280_cat34[4],M300_cat34[4],M320_cat34[4],M400_cat34[4],M450_cat34[4],M500_cat34[4],M550_cat34[4],M600_cat34[4],M650_cat34[4],M700_cat34[4],M750_cat34[4],M800_cat34[4],M850_cat34[4],M1000_cat34[4]], color='gold', alpha=1)

plt.xlabel(r'Radion Mass (GeV)')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,1000)

# set log scale
plt.yscale('log')
# set y limit
plt.ylim(100,100000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(1., 0.95))

# %%
M250_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX250_MH125/higgsCombinecat34_MX250_MH125_2018.AsymptoticLimits.mH125.root")
M250_cat1234 = M250_events_cat1234["limit"].arrays(['limit']).limit*100
M260_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX260_MH125/higgsCombinecat34_MX260_MH125_2018.AsymptoticLimits.mH125.root")
M260_cat1234 = M260_events_cat1234["limit"].arrays(['limit']).limit*100
M270_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX270_MH125/higgsCombinecat34_MX270_MH125_2018.AsymptoticLimits.mH125.root")
M270_cat1234 = M270_events_cat1234["limit"].arrays(['limit']).limit*100
M280_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX280_MH125/higgsCombinecat34_MX280_MH125_2018.AsymptoticLimits.mH125.root")
M280_cat1234 = M280_events_cat1234["limit"].arrays(['limit']).limit*100
M300_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX300_MH125/higgsCombinecat34_MX300_MH125_2018.AsymptoticLimits.mH125.root")
M300_cat1234 = M300_events_cat1234["limit"].arrays(['limit']).limit*100
M320_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX320_MH125/higgsCombinecat34_MX320_MH125_2018.AsymptoticLimits.mH125.root")
M320_cat1234 = M320_events_cat1234["limit"].arrays(['limit']).limit*100
M350_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX350_MH125/higgsCombinecat34_MX350_MH125_2018.AsymptoticLimits.mH125.root")
M350_cat1234 = M350_events_cat1234["limit"].arrays(['limit']).limit*100
M400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX400_MH125/higgsCombinecat34_MX400_MH125_2018.AsymptoticLimits.mH125.root")
M400_cat1234 = M400_events_cat1234["limit"].arrays(['limit']).limit*100
M450_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX450_MH125/higgsCombinecat34_MX450_MH125_2018.AsymptoticLimits.mH125.root")
M450_cat1234 = M450_events_cat1234["limit"].arrays(['limit']).limit*100
M500_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX500_MH125/higgsCombinecat1234_MX500_MH125_2018.AsymptoticLimits.mH125.root")
M500_cat1234 = M500_events_cat1234["limit"].arrays(['limit']).limit*100
M550_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX550_MH125/higgsCombinecat1234_MX550_MH125_2018.AsymptoticLimits.mH125.root")
M550_cat1234 = M550_events_cat1234["limit"].arrays(['limit']).limit*100
M600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX600_MH125/higgsCombinecat1234_MX600_MH125_2018.AsymptoticLimits.mH125.root")
M600_cat1234 = M600_events_cat1234["limit"].arrays(['limit']).limit*100
M650_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX650_MH125/higgsCombinecat1234_MX650_MH125_2018.AsymptoticLimits.mH125.root")
M650_cat1234 = M650_events_cat1234["limit"].arrays(['limit']).limit*100
M700_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX700_MH125/higgsCombinecat1234_MX700_MH125_2018.AsymptoticLimits.mH125.root")
M700_cat1234 = M700_events_cat1234["limit"].arrays(['limit']).limit*100
M750_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX750_MH125/higgsCombinecat1234_MX750_MH125_2018.AsymptoticLimits.mH125.root")
M750_cat1234 = M750_events_cat1234["limit"].arrays(['limit']).limit*100
M800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX800_MH125/higgsCombinecat1234_MX800_MH125_2018.AsymptoticLimits.mH125.root")
M800_cat1234 = M800_events_cat1234["limit"].arrays(['limit']).limit*100
M850_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX850_MH125/higgsCombinecat1234_MX850_MH125_2018.AsymptoticLimits.mH125.root")
M850_cat1234 = M850_events_cat1234["limit"].arrays(['limit']).limit*100
# M1000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1000_MH125/higgsCombinecat1234_MX1000_MH125_2018.AsymptoticLimits.mH125.root")
# M1000_cat1234 = M1000_events_cat1234["limit"].arrays(['limit']).limit
M1100_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1100_MH125/higgsCombinecat12_MX1100_MH125_2018.AsymptoticLimits.mH125.root")
M1100_cat1234 = M1100_events_cat1234["limit"].arrays(['limit']).limit
M1200_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1200_MH125/higgsCombinecat12_MX1200_MH125_2018.AsymptoticLimits.mH125.root")
M1200_cat1234 = M1200_events_cat1234["limit"].arrays(['limit']).limit
M1300_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1300_MH125/higgsCombinecat12_MX1300_MH125_2018.AsymptoticLimits.mH125.root")
M1300_cat1234 = M1300_events_cat1234["limit"].arrays(['limit']).limit
M1400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1400_MH125/higgsCombinecat12_MX1400_MH125_2018.AsymptoticLimits.mH125.root")
M1400_cat1234 = M1400_events_cat1234["limit"].arrays(['limit']).limit
M1500_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1500_MH125/higgsCombinecat12_MX1500_MH125_2018.AsymptoticLimits.mH125.root")
M1500_cat1234 = M1500_events_cat1234["limit"].arrays(['limit']).limit
M1600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1600_MH125/higgsCombinecat12_MX1600_MH125_2018.AsymptoticLimits.mH125.root")
M1600_cat1234 = M1600_events_cat1234["limit"].arrays(['limit']).limit
M1700_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1700_MH125/higgsCombinecat12_MX1700_MH125_2018.AsymptoticLimits.mH125.root")
M1700_cat1234 = M1700_events_cat1234["limit"].arrays(['limit']).limit
M1800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1800_MH125/higgsCombinecat12_MX1800_MH125_2018.AsymptoticLimits.mH125.root")
M1800_cat1234 = M1800_events_cat1234["limit"].arrays(['limit']).limit
M1900_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX1900_MH125/higgsCombinecat12_MX1900_MH125_2018.AsymptoticLimits.mH125.root")
M1900_cat1234 = M1900_events_cat1234["limit"].arrays(['limit']).limit
M2000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2000_MH125/higgsCombinecat12_MX2000_MH125_2018.AsymptoticLimits.mH125.root")
M2000_cat1234 = M2000_events_cat1234["limit"].arrays(['limit']).limit
M2200_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2200_MH125/higgsCombinecat12_MX2200_MH125_2018.AsymptoticLimits.mH125.root")
M2200_cat1234 = M2200_events_cat1234["limit"].arrays(['limit']).limit
M2400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2400_MH125/higgsCombinecat12_MX2400_MH125_2018.AsymptoticLimits.mH125.root")
M2400_cat1234 = M2400_events_cat1234["limit"].arrays(['limit']).limit
M2600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2600_MH125/higgsCombinecat12_MX2600_MH125_2018.AsymptoticLimits.mH125.root")
M2600_cat1234 = M2600_events_cat1234["limit"].arrays(['limit']).limit
M2800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX2800_MH125/higgsCombinecat12_MX2800_MH125_2018.AsymptoticLimits.mH125.root")
M2800_cat1234 = M2800_events_cat1234["limit"].arrays(['limit']).limit
M3000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2018datacard/datacard_MX3000_MH125/higgsCombinecat12_MX3000_MH125_2018.AsymptoticLimits.mH125.root")
M3000_cat1234 = M3000_events_cat1234["limit"].arrays(['limit']).limit
hep.style.use(hep.style.CMS)

hep.cms.label("preliminary", data=True, year='2018', lumi=59.83)   
# set figure size
plt.rcParams["figure.figsize"] = (16, 10)
allcat_values = [250,260,270,280,300,320,400,450,500,550,600,650,700,750,800,850,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
# allcat_values = [250,260,270,280,300,320,400,450,500,550,600,650,700,750,800,850,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
plt.plot(allcat_values, [M250_cat1234[2],M260_cat1234[2],M270_cat1234[2],M280_cat1234[2],M300_cat1234[2],M320_cat1234[2],M400_cat1234[2],M450_cat1234[2],M500_cat1234[2],M550_cat1234[2],M600_cat1234[2],M650_cat1234[2],M700_cat1234[2],M750_cat1234[2],M800_cat1234[2],M850_cat1234[2],M1100_cat1234[2],M1200_cat1234[2],M1300_cat1234[2],M1400_cat1234[2],M1500_cat1234[2],M1600_cat1234[2],M1700_cat1234[2],M1800_cat1234[2],M1900_cat1234[2],M2000_cat1234[2],M2200_cat1234[2],M2400_cat1234[2],M2600_cat1234[2],M2800_cat1234[2],M3000_cat1234[2]],color='black', linewidth=2,linestyle='-', label='Asymptotic Limits CLs expected')
# 68% confidence interval
plt.fill_between(allcat_values, [M250_cat1234[1],M260_cat1234[1],M270_cat1234[1],M280_cat1234[1],M300_cat1234[1],M320_cat1234[1],M400_cat1234[1],M450_cat1234[1],M500_cat1234[1],M550_cat1234[1],M600_cat1234[1],M650_cat1234[1],M700_cat1234[1],M750_cat1234[1],M800_cat1234[1],M850_cat1234[1],M1100_cat1234[1],M1200_cat1234[1],M1300_cat1234[1],M1400_cat1234[1],M1500_cat1234[1],M1600_cat1234[1],M1700_cat1234[1],M1800_cat1234[1],M1900_cat1234[1],M2000_cat1234[1],M2200_cat1234[1],M2400_cat1234[1],M2600_cat1234[1],M2800_cat1234[1],M3000_cat1234[1]], [M250_cat1234[3],M260_cat1234[3],M270_cat1234[3],M280_cat1234[3],M300_cat1234[3],M320_cat1234[3],M400_cat1234[3],M450_cat1234[3],M500_cat1234[3],M550_cat1234[3],M600_cat1234[3],M650_cat1234[3],M700_cat1234[3],M750_cat1234[3],M800_cat1234[3],M850_cat1234[3],M1100_cat1234[3],M1200_cat1234[3],M1300_cat1234[3],M1400_cat1234[3],M1500_cat1234[3],M1600_cat1234[3],M1700_cat1234[3],M1800_cat1234[3],M1900_cat1234[3],M2000_cat1234[3],M2200_cat1234[3],M2400_cat1234[3],M2600_cat1234[3],M2800_cat1234[3],M3000_cat1234[3]], color='#04cb02', alpha=1, label= r'±1 std. deviation')
# 95% confidence interval
plt.fill_between(allcat_values, [M250_cat1234[0],M260_cat1234[0],M270_cat1234[0],M280_cat1234[0],M300_cat1234[0],M320_cat1234[0],M400_cat1234[0],M450_cat1234[0],M500_cat1234[0],M550_cat1234[0],M600_cat1234[0],M650_cat1234[0],M700_cat1234[0],M750_cat1234[0],M800_cat1234[0],M850_cat1234[0],M1100_cat1234[0],M1200_cat1234[0],M1300_cat1234[0],M1400_cat1234[0],M1500_cat1234[0],M1600_cat1234[0],M1700_cat1234[0],M1800_cat1234[0],M1900_cat1234[0],M2000_cat1234[0],M2200_cat1234[0],M2400_cat1234[0],M2600_cat1234[0],M2800_cat1234[0],M3000_cat1234[0]],[M250_cat1234[1],M260_cat1234[1],M270_cat1234[1],M280_cat1234[1],M300_cat1234[1],M320_cat1234[1],M400_cat1234[1],M450_cat1234[1],M500_cat1234[1],M550_cat1234[1],M600_cat1234[1],M650_cat1234[1],M700_cat1234[1],M750_cat1234[1],M800_cat1234[1],M850_cat1234[1],M1100_cat1234[1],M1200_cat1234[1],M1300_cat1234[1],M1400_cat1234[1],M1500_cat1234[1],M1600_cat1234[1],M1700_cat1234[1],M1800_cat1234[1],M1900_cat1234[1],M2000_cat1234[1],M2200_cat1234[1],M2400_cat1234[1],M2600_cat1234[1],M2800_cat1234[1],M3000_cat1234[1]], color='gold', alpha=1, label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_cat1234[3],M260_cat1234[3],M270_cat1234[3],M280_cat1234[3],M300_cat1234[3],M320_cat1234[3],M400_cat1234[3],M450_cat1234[3],M500_cat1234[3],M550_cat1234[3],M600_cat1234[3],M650_cat1234[3],M700_cat1234[3],M750_cat1234[3],M800_cat1234[3],M850_cat1234[3],M1100_cat1234[3],M1200_cat1234[3],M1300_cat1234[3],M1400_cat1234[3],M1500_cat1234[3],M1600_cat1234[3],M1700_cat1234[3],M1800_cat1234[3],M1900_cat1234[3],M2000_cat1234[3],M2200_cat1234[3],M2400_cat1234[3],M2600_cat1234[3],M2800_cat1234[3],M3000_cat1234[3]],  [M250_cat1234[4],M260_cat1234[4],M270_cat1234[4],M280_cat1234[4],M300_cat1234[4],M320_cat1234[4],M400_cat1234[4],M450_cat1234[4],M500_cat1234[4],M550_cat1234[4],M600_cat1234[4],M650_cat1234[4],M700_cat1234[4],M750_cat1234[4],M800_cat1234[4],M850_cat1234[4],M1100_cat1234[4],M1200_cat1234[4],M1300_cat1234[4],M1400_cat1234[4],M1500_cat1234[4],M1600_cat1234[4],M1700_cat1234[4],M1800_cat1234[4],M1900_cat1234[4],M2000_cat1234[4],M2200_cat1234[4],M2400_cat1234[4],M2600_cat1234[4],M2800_cat1234[4],M3000_cat1234[4]], color='gold', alpha=1)
plt.xlabel(r'Radion Mass (GeV)')
# plt.ylabel(r'95% CL limits on $\sigma(ggX)*Br(XHHWWgg)[fb]$')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,3000)
plt.xticks([250, 500, 1000, 1500, 2000, 3000], ['250', '500', '1000', '1500', '2000', '3000'])
# plt.xticks(np.arange(250, 3001, 100))
# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,100000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(0.95, 0.95))

# %% [markdown]
# # 2016pre

# %%
M250_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX250_MH125/higgsCombinecat34_MX250_MH125_2016pre.AsymptoticLimits.mH125.root")
M250_cat34 = M250_events_cat34["limit"].arrays(['limit']).limit*100
M260_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX260_MH125/higgsCombinecat34_MX260_MH125_2016pre.AsymptoticLimits.mH125.root")
M260_cat34 = M260_events_cat34["limit"].arrays(['limit']).limit*100
# M270_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX270_MH125/higgsCombinecat34_MX270_MH125_2016pre.AsymptoticLimits.mH125.root")
# M270_cat34 = M270_events_cat34["limit"].arrays(['limit']).limit*100
M280_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX280_MH125/higgsCombinecat34_MX280_MH125_2016pre.AsymptoticLimits.mH125.root")
M280_cat34 = M280_events_cat34["limit"].arrays(['limit']).limit*100
M300_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX300_MH125/higgsCombinecat34_MX300_MH125_2016pre.AsymptoticLimits.mH125.root")
M300_cat34 = M300_events_cat34["limit"].arrays(['limit']).limit*100
M320_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX320_MH125/higgsCombinecat34_MX320_MH125_2016pre.AsymptoticLimits.mH125.root")
M320_cat34 = M320_events_cat34["limit"].arrays(['limit']).limit*100
M350_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX350_MH125/higgsCombinecat34_MX350_MH125_2016pre.AsymptoticLimits.mH125.root")
M350_cat34 = M350_events_cat34["limit"].arrays(['limit']).limit*100
M400_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX400_MH125/higgsCombinecat34_MX400_MH125_2016pre.AsymptoticLimits.mH125.root")
M400_cat34 = M400_events_cat34["limit"].arrays(['limit']).limit*100
M450_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX450_MH125/higgsCombinecat34_MX450_MH125_2016pre.AsymptoticLimits.mH125.root")
M450_cat34 = M450_events_cat34["limit"].arrays(['limit']).limit*100
M500_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX500_MH125/higgsCombinecat34_MX500_MH125_2016pre.AsymptoticLimits.mH125.root")
M500_cat34 = M500_events_cat34["limit"].arrays(['limit']).limit*100
M550_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX550_MH125/higgsCombinecat34_MX550_MH125_2016pre.AsymptoticLimits.mH125.root")
M550_cat34 = M550_events_cat34["limit"].arrays(['limit']).limit*100
M600_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX600_MH125/higgsCombinecat34_MX600_MH125_2016pre.AsymptoticLimits.mH125.root")
M600_cat34 = M600_events_cat34["limit"].arrays(['limit']).limit*100
M650_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX650_MH125/higgsCombinecat34_MX650_MH125_2016pre.AsymptoticLimits.mH125.root")
M650_cat34 = M650_events_cat34["limit"].arrays(['limit']).limit*100
M700_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX700_MH125/higgsCombinecat34_MX700_MH125_2016pre.AsymptoticLimits.mH125.root")
M700_cat34 = M700_events_cat34["limit"].arrays(['limit']).limit*100
M750_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX750_MH125/higgsCombinecat34_MX750_MH125_2016pre.AsymptoticLimits.mH125.root")
M750_cat34 = M750_events_cat34["limit"].arrays(['limit']).limit*100
M800_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX800_MH125/higgsCombinecat34_MX800_MH125_2016pre.AsymptoticLimits.mH125.root")
M800_cat34 = M800_events_cat34["limit"].arrays(['limit']).limit*100
M850_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX850_MH125/higgsCombinecat34_MX850_MH125_2016pre.AsymptoticLimits.mH125.root")
M850_cat34 = M850_events_cat34["limit"].arrays(['limit']).limit*100
M1000_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1000_MH125/higgsCombinecat34_MX1000_MH125_2016pre.AsymptoticLimits.mH125.root")
M1000_cat34 = M1000_events_cat34["limit"].arrays(['limit']).limit*100

# %%
hep.style.use(hep.style.CMS)
hep.cms.label("preliminary", data=True, year='16preVFP', lumi=19.48)   
# set figure size
plt.rcParams["figure.figsize"] = (20,20)
allcat_values = [250,260,280,300,320,400,450,500,550,600,650,700,750,800,850,1000]
plt.plot(allcat_values, [M250_cat34[2],M260_cat34[2],M280_cat34[2],M300_cat34[2],M320_cat34[2],M400_cat34[2],M450_cat34[2],M500_cat34[2],M550_cat34[2],M600_cat34[2],M650_cat34[2],M700_cat34[2],M750_cat34[2],M800_cat34[2],M850_cat34[2],M1000_cat34[2]],color='black', linewidth=2,linestyle='-', label='WWgg + ZZgg + bbgg Signal')#'Asymptotic Limits CLs expected'

# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M250_cat34[1],M260_cat34[1],M280_cat34[1],M300_cat34[1],M320_cat34[1],M400_cat34[1],M450_cat34[1],M500_cat34[1],M550_cat34[1],M600_cat34[1],M650_cat34[1],M700_cat34[1],M750_cat34[1],M800_cat34[1],M850_cat34[1],M1000_cat34[1]], [M250_cat34[3],M260_cat34[3],M280_cat34[3],M300_cat34[3],M320_cat34[3],M400_cat34[3],M450_cat34[3],M500_cat34[3],M550_cat34[3],M600_cat34[3],M650_cat34[3],M700_cat34[3],M750_cat34[3],M800_cat34[3],M850_cat34[3],M1000_cat34[3]], color='#04cb02', alpha=1, label= r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M250_cat34[0],M260_cat34[0],M280_cat34[0],M300_cat34[0],M320_cat34[0],M400_cat34[0],M450_cat34[0],M500_cat34[0],M550_cat34[0],M600_cat34[0],M650_cat34[0],M700_cat34[0],M750_cat34[0],M800_cat34[0],M850_cat34[0],M1000_cat34[0]],[M250_cat34[1],M260_cat34[1],M280_cat34[1],M300_cat34[1],M320_cat34[1],M400_cat34[1],M450_cat34[1],M500_cat34[1],M550_cat34[1],M600_cat34[1],M650_cat34[1],M700_cat34[1],M750_cat34[1],M800_cat34[1],M850_cat34[1],M1000_cat34[1]], color='gold', alpha=1, label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_cat34[3],M260_cat34[3],M280_cat34[3],M300_cat34[3],M320_cat34[3],M400_cat34[3],M450_cat34[3],M500_cat34[3],M550_cat34[3],M600_cat34[3],M650_cat34[3],M700_cat34[3],M750_cat34[3],M800_cat34[3],M850_cat34[3],M1000_cat34[3]],  [M250_cat34[4],M260_cat34[4],M280_cat34[4],M300_cat34[4],M320_cat34[4],M400_cat34[4],M450_cat34[4],M500_cat34[4],M550_cat34[4],M600_cat34[4],M650_cat34[4],M700_cat34[4],M750_cat34[4],M800_cat34[4],M850_cat34[4],M1000_cat34[4]], color='gold', alpha=1)

plt.xlabel(r'Radion Mass (GeV)')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,1000)

# set log scale
plt.yscale('log')
# set y limit
plt.ylim(100,100000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(1., 0.95))

# %%
M500_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX500_MH125/higgsCombinecat12_MX500_MH125_2016pre.AsymptoticLimits.mH125.root")
M500_cat_cat12 = M500_events_cat12["limit"].arrays(['limit']).limit*100
M550_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX550_MH125/higgsCombinecat12_MX550_MH125_2016pre.AsymptoticLimits.mH125.root")
M550_cat_cat12 = M550_events_cat12["limit"].arrays(['limit']).limit*100
M600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX600_MH125/higgsCombinecat12_MX600_MH125_2016pre.AsymptoticLimits.mH125.root")
M600_cat_cat12 = M600_events_cat12["limit"].arrays(['limit']).limit*100
M650_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX650_MH125/higgsCombinecat12_MX650_MH125_2016pre.AsymptoticLimits.mH125.root")
M650_cat_cat12 = M650_events_cat12["limit"].arrays(['limit']).limit*100
M700_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX700_MH125/higgsCombinecat12_MX700_MH125_2016pre.AsymptoticLimits.mH125.root")
M700_cat_cat12 = M700_events_cat12["limit"].arrays(['limit']).limit*100
M750_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX750_MH125/higgsCombinecat12_MX750_MH125_2016pre.AsymptoticLimits.mH125.root")
M750_cat_cat12 = M750_events_cat12["limit"].arrays(['limit']).limit*100
M800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX800_MH125/higgsCombinecat12_MX800_MH125_2016pre.AsymptoticLimits.mH125.root")
M800_cat_cat12 = M800_events_cat12["limit"].arrays(['limit']).limit*100
M850_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX850_MH125/higgsCombinecat12_MX850_MH125_2016pre.AsymptoticLimits.mH125.root")
M850_cat_cat12 = M850_events_cat12["limit"].arrays(['limit']).limit*100
M1000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1000_MH125/higgsCombinecat12_MX1000_MH125_2016pre.AsymptoticLimits.mH125.root")
M1000_cat_cat12 = M1000_events_cat12["limit"].arrays(['limit']).limit*100
M1100_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1100_MH125/higgsCombinecat12_MX1100_MH125_2016pre.AsymptoticLimits.mH125.root")
M1100_cat_cat12 = M1100_events_cat12["limit"].arrays(['limit']).limit
M1200_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1200_MH125/higgsCombinecat12_MX1200_MH125_2016pre.AsymptoticLimits.mH125.root")
M1200_cat_cat12 = M1200_events_cat12["limit"].arrays(['limit']).limit
M1300_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1300_MH125/higgsCombinecat12_MX1300_MH125_2016pre.AsymptoticLimits.mH125.root")
M1300_cat_cat12 = M1300_events_cat12["limit"].arrays(['limit']).limit
M1400_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1400_MH125/higgsCombinecat12_MX1400_MH125_2016pre.AsymptoticLimits.mH125.root")
M1400_cat_cat12 = M1400_events_cat12["limit"].arrays(['limit']).limit
M1500_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1500_MH125/higgsCombinecat12_MX1500_MH125_2016pre.AsymptoticLimits.mH125.root")
M1500_cat_cat12 = M1500_events_cat12["limit"].arrays(['limit']).limit
M1600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1600_MH125/higgsCombinecat12_MX1600_MH125_2016pre.AsymptoticLimits.mH125.root")
M1600_cat_cat12 = M1600_events_cat12["limit"].arrays(['limit']).limit
M1700_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1700_MH125/higgsCombinecat12_MX1700_MH125_2016pre.AsymptoticLimits.mH125.root")
M1700_cat_cat12 = M1700_events_cat12["limit"].arrays(['limit']).limit
M1800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1800_MH125/higgsCombinecat12_MX1800_MH125_2016pre.AsymptoticLimits.mH125.root")
M1800_cat_cat12 = M1800_events_cat12["limit"].arrays(['limit']).limit
M1900_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1900_MH125/higgsCombinecat12_MX1900_MH125_2016pre.AsymptoticLimits.mH125.root")
M1900_cat_cat12 = M1900_events_cat12["limit"].arrays(['limit']).limit
M2000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2000_MH125/higgsCombinecat12_MX2000_MH125_2016pre.AsymptoticLimits.mH125.root")
M2000_cat_cat12 = M2000_events_cat12["limit"].arrays(['limit']).limit
M2200_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2200_MH125/higgsCombinecat12_MX2200_MH125_2016pre.AsymptoticLimits.mH125.root")
M2200_cat_cat12 = M2200_events_cat12["limit"].arrays(['limit']).limit
M2400_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2400_MH125/higgsCombinecat12_MX2400_MH125_2016pre.AsymptoticLimits.mH125.root")
M2400_cat_cat12 = M2400_events_cat12["limit"].arrays(['limit']).limit
M2600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2600_MH125/higgsCombinecat12_MX2600_MH125_2016pre.AsymptoticLimits.mH125.root")
M2600_cat_cat12 = M2600_events_cat12["limit"].arrays(['limit']).limit
M2800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2800_MH125/higgsCombinecat12_MX2800_MH125_2016pre.AsymptoticLimits.mH125.root")
M2800_cat_cat12 = M2800_events_cat12["limit"].arrays(['limit']).limit
M3000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX3000_MH125/higgsCombinecat12_MX3000_MH125_2016pre.AsymptoticLimits.mH125.root")
M3000_cat_cat12 = M3000_events_cat12["limit"].arrays(['limit']).limit
hep.style.use(hep.style.CMS)

hep.cms.label("preliminary", data=True, year='16preVFP', lumi=19.48)   
# set figure size
plt.rcParams["figure.figsize"] = (16, 10)

allcat_values = [500,550,600,650,700,750,800,850,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
plt.plot(allcat_values, [M500_cat_cat12[2],M550_cat_cat12[2],M600_cat_cat12[2],M650_cat_cat12[2],M700_cat_cat12[2],M750_cat_cat12[2],M800_cat_cat12[2],M850_cat_cat12[2],M1000_cat_cat12[2],M1100_cat_cat12[2],M1200_cat_cat12[2],M1300_cat_cat12[2],M1400_cat_cat12[2],M1500_cat_cat12[2],M1600_cat_cat12[2],M1700_cat_cat12[2],M1800_cat_cat12[2],M1900_cat_cat12[2],M2000_cat_cat12[2],M2200_cat_cat12[2],M2400_cat_cat12[2],M2600_cat_cat12[2],M2800_cat_cat12[2],M3000_cat_cat12[2]],color='black', linewidth=2,linestyle='-', label='Asymptotic Limits CLs expected')

# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M500_cat_cat12[1],M550_cat_cat12[1],M600_cat_cat12[1],M650_cat_cat12[1],M700_cat_cat12[1],M750_cat_cat12[1],M800_cat_cat12[1],M850_cat_cat12[1],M1000_cat_cat12[1],M1100_cat_cat12[1],M1200_cat_cat12[1],M1300_cat_cat12[1],M1400_cat_cat12[1],M1500_cat_cat12[1],M1600_cat_cat12[1],M1700_cat_cat12[1],M1800_cat_cat12[1],M1900_cat_cat12[1],M2000_cat_cat12[1],M2200_cat_cat12[1],M2400_cat_cat12[1],M2600_cat_cat12[1],M2800_cat_cat12[1],M3000_cat_cat12[1]], [M500_cat_cat12[3],M550_cat_cat12[3],M600_cat_cat12[3],M650_cat_cat12[3],M700_cat_cat12[3],M750_cat_cat12[3],M800_cat_cat12[3],M850_cat_cat12[3],M1000_cat_cat12[3],M1100_cat_cat12[3],M1200_cat_cat12[3],M1300_cat_cat12[3],M1400_cat_cat12[3],M1500_cat_cat12[3],M1600_cat_cat12[3],M1700_cat_cat12[3],M1800_cat_cat12[3],M1900_cat_cat12[3],M2000_cat_cat12[3],M2200_cat_cat12[3],M2400_cat_cat12[3],M2600_cat_cat12[3],M2800_cat_cat12[3],M3000_cat_cat12[3]], color='#04cb02', alpha=1, label= r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M500_cat_cat12[0],M550_cat_cat12[0],M600_cat_cat12[0],M650_cat_cat12[0],M700_cat_cat12[0],M750_cat_cat12[0],M800_cat_cat12[0],M850_cat_cat12[0],M1000_cat_cat12[0],M1100_cat_cat12[0],M1200_cat_cat12[0],M1300_cat_cat12[0],M1400_cat_cat12[0],M1500_cat_cat12[0],M1600_cat_cat12[0],M1700_cat_cat12[0],M1800_cat_cat12[0],M1900_cat_cat12[0],M2000_cat_cat12[0],M2200_cat_cat12[0],M2400_cat_cat12[0],M2600_cat_cat12[0],M2800_cat_cat12[0],M3000_cat_cat12[0]],[M500_cat_cat12[1],M550_cat_cat12[1],M600_cat_cat12[1],M650_cat_cat12[1],M700_cat_cat12[1],M750_cat_cat12[1],M800_cat_cat12[1],M850_cat_cat12[1],M1000_cat_cat12[1],M1100_cat_cat12[1],M1200_cat_cat12[1],M1300_cat_cat12[1],M1400_cat_cat12[1],M1500_cat_cat12[1],M1600_cat_cat12[1],M1700_cat_cat12[1],M1800_cat_cat12[1],M1900_cat_cat12[1],M2000_cat_cat12[1],M2200_cat_cat12[1],M2400_cat_cat12[1],M2600_cat_cat12[1],M2800_cat_cat12[1],M3000_cat_cat12[1]], color='gold', alpha=1, label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M500_cat_cat12[3],M550_cat_cat12[3],M600_cat_cat12[3],M650_cat_cat12[3],M700_cat_cat12[3],M750_cat_cat12[3],M800_cat_cat12[3],M850_cat_cat12[3],M1000_cat_cat12[3],M1100_cat_cat12[3],M1200_cat_cat12[3],M1300_cat_cat12[3],M1400_cat_cat12[3],M1500_cat_cat12[3],M1600_cat_cat12[3],M1700_cat_cat12[3],M1800_cat_cat12[3],M1900_cat_cat12[3],M2000_cat_cat12[3],M2200_cat_cat12[3],M2400_cat_cat12[3],M2600_cat_cat12[3],M2800_cat_cat12[3],M3000_cat_cat12[3]],  [M500_cat_cat12[4],M550_cat_cat12[4],M600_cat_cat12[4],M650_cat_cat12[4],M700_cat_cat12[4],M750_cat_cat12[4],M800_cat_cat12[4],M850_cat_cat12[4],M1000_cat_cat12[4],M1100_cat_cat12[4],M1200_cat_cat12[4],M1300_cat_cat12[4],M1400_cat_cat12[4],M1500_cat_cat12[4],M1600_cat_cat12[4],M1700_cat_cat12[4],M1800_cat_cat12[4],M1900_cat_cat12[4],M2000_cat_cat12[4],M2200_cat_cat12[4],M2400_cat_cat12[4],M2600_cat_cat12[4],M2800_cat_cat12[4],M3000_cat_cat12[4]], color='gold', alpha=1)

# 添加标签和标题
plt.xlabel(r'Radion Mass (GeV)')
# plt.ylabel(r'95% CL limits on $\sigma(ggX)*Br(XHHWWgg)[fb]$')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(500,3000)
#每1000GeV一个刻度
# plt.xticks(np.arange(200, 3001, 500))
# set x ticks
# plt.xticks(np.arange(1000, 3001, 500))
# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,10000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(0.95, 0.95))

# %%
M250_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX250_MH125/higgsCombinecat34_MX250_MH125_2016pre.AsymptoticLimits.mH125.root")
M250_cat1234 = M250_events_cat1234["limit"].arrays(['limit']).limit*100
M260_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX260_MH125/higgsCombinecat34_MX260_MH125_2016pre.AsymptoticLimits.mH125.root")
M260_cat1234 = M260_events_cat1234["limit"].arrays(['limit']).limit*100
# M270_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX270_MH125/higgsCombinecat34_MX270_MH125_2016pre.AsymptoticLimits.mH125.root")
# M270_cat1234 = M270_events_cat1234["limit"].arrays(['limit']).limit*100
M280_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX280_MH125/higgsCombinecat34_MX280_MH125_2016pre.AsymptoticLimits.mH125.root")
M280_cat1234 = M280_events_cat1234["limit"].arrays(['limit']).limit*100
M300_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX300_MH125/higgsCombinecat34_MX300_MH125_2016pre.AsymptoticLimits.mH125.root")
M300_cat1234 = M300_events_cat1234["limit"].arrays(['limit']).limit*100
M320_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX320_MH125/higgsCombinecat34_MX320_MH125_2016pre.AsymptoticLimits.mH125.root")
M320_cat1234 = M320_events_cat1234["limit"].arrays(['limit']).limit*100
M350_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX350_MH125/higgsCombinecat34_MX350_MH125_2016pre.AsymptoticLimits.mH125.root")
M350_cat1234 = M350_events_cat1234["limit"].arrays(['limit']).limit*100
M400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX400_MH125/higgsCombinecat34_MX400_MH125_2016pre.AsymptoticLimits.mH125.root")
M400_cat1234 = M400_events_cat1234["limit"].arrays(['limit']).limit*100
M450_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX450_MH125/higgsCombinecat34_MX450_MH125_2016pre.AsymptoticLimits.mH125.root")
M450_cat1234 = M450_events_cat1234["limit"].arrays(['limit']).limit*100
M500_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX500_MH125/higgsCombinecat1234_MX500_MH125_2016pre.AsymptoticLimits.mH125.root")
M500_cat1234 = M500_events_cat1234["limit"].arrays(['limit']).limit*100
M550_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX550_MH125/higgsCombinecat1234_MX550_MH125_2016pre.AsymptoticLimits.mH125.root")
M550_cat1234 = M550_events_cat1234["limit"].arrays(['limit']).limit*100
M600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX600_MH125/higgsCombinecat1234_MX600_MH125_2016pre.AsymptoticLimits.mH125.root")
M600_cat1234 = M600_events_cat1234["limit"].arrays(['limit']).limit*100
M650_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX650_MH125/higgsCombinecat1234_MX650_MH125_2016pre.AsymptoticLimits.mH125.root")
M650_cat1234 = M650_events_cat1234["limit"].arrays(['limit']).limit*100
M700_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX700_MH125/higgsCombinecat1234_MX700_MH125_2016pre.AsymptoticLimits.mH125.root")
M700_cat1234 = M700_events_cat1234["limit"].arrays(['limit']).limit*100
M750_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX750_MH125/higgsCombinecat1234_MX750_MH125_2016pre.AsymptoticLimits.mH125.root")
M750_cat1234 = M750_events_cat1234["limit"].arrays(['limit']).limit*100
M800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX800_MH125/higgsCombinecat1234_MX800_MH125_2016pre.AsymptoticLimits.mH125.root")
M800_cat1234 = M800_events_cat1234["limit"].arrays(['limit']).limit*100
M850_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX850_MH125/higgsCombinecat1234_MX850_MH125_2016pre.AsymptoticLimits.mH125.root")
M850_cat1234 = M850_events_cat1234["limit"].arrays(['limit']).limit*100
M1000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1000_MH125/higgsCombinecat1234_MX1000_MH125_2016pre.AsymptoticLimits.mH125.root")
M1000_cat1234 = M1000_events_cat1234["limit"].arrays(['limit']).limit
M1100_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1100_MH125/higgsCombinecat12_MX1100_MH125_2016pre.AsymptoticLimits.mH125.root")
M1100_cat1234 = M1100_events_cat1234["limit"].arrays(['limit']).limit
M1200_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1200_MH125/higgsCombinecat12_MX1200_MH125_2016pre.AsymptoticLimits.mH125.root")
M1200_cat1234 = M1200_events_cat1234["limit"].arrays(['limit']).limit
M1300_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1300_MH125/higgsCombinecat12_MX1300_MH125_2016pre.AsymptoticLimits.mH125.root")
M1300_cat1234 = M1300_events_cat1234["limit"].arrays(['limit']).limit
M1400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1400_MH125/higgsCombinecat12_MX1400_MH125_2016pre.AsymptoticLimits.mH125.root")
M1400_cat1234 = M1400_events_cat1234["limit"].arrays(['limit']).limit
M1500_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1500_MH125/higgsCombinecat12_MX1500_MH125_2016pre.AsymptoticLimits.mH125.root")
M1500_cat1234 = M1500_events_cat1234["limit"].arrays(['limit']).limit
M1600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1600_MH125/higgsCombinecat12_MX1600_MH125_2016pre.AsymptoticLimits.mH125.root")
M1600_cat1234 = M1600_events_cat1234["limit"].arrays(['limit']).limit
M1700_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1700_MH125/higgsCombinecat12_MX1700_MH125_2016pre.AsymptoticLimits.mH125.root")
M1700_cat1234 = M1700_events_cat1234["limit"].arrays(['limit']).limit
M1800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1800_MH125/higgsCombinecat12_MX1800_MH125_2016pre.AsymptoticLimits.mH125.root")
M1800_cat1234 = M1800_events_cat1234["limit"].arrays(['limit']).limit
M1900_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX1900_MH125/higgsCombinecat12_MX1900_MH125_2016pre.AsymptoticLimits.mH125.root")
M1900_cat1234 = M1900_events_cat1234["limit"].arrays(['limit']).limit
M2000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2000_MH125/higgsCombinecat12_MX2000_MH125_2016pre.AsymptoticLimits.mH125.root")
M2000_cat1234 = M2000_events_cat1234["limit"].arrays(['limit']).limit
M2200_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2200_MH125/higgsCombinecat12_MX2200_MH125_2016pre.AsymptoticLimits.mH125.root")
M2200_cat1234 = M2200_events_cat1234["limit"].arrays(['limit']).limit
M2400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2400_MH125/higgsCombinecat12_MX2400_MH125_2016pre.AsymptoticLimits.mH125.root")
M2400_cat1234 = M2400_events_cat1234["limit"].arrays(['limit']).limit
M2600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2600_MH125/higgsCombinecat12_MX2600_MH125_2016pre.AsymptoticLimits.mH125.root")
M2600_cat1234 = M2600_events_cat1234["limit"].arrays(['limit']).limit
M2800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX2800_MH125/higgsCombinecat12_MX2800_MH125_2016pre.AsymptoticLimits.mH125.root")
M2800_cat1234 = M2800_events_cat1234["limit"].arrays(['limit']).limit
M3000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016predatacard/datacard_MX3000_MH125/higgsCombinecat12_MX3000_MH125_2016pre.AsymptoticLimits.mH125.root")
M3000_cat1234 = M3000_events_cat1234["limit"].arrays(['limit']).limit
hep.style.use(hep.style.CMS)

hep.cms.label("preliminary", data=True, year='2016pre', lumi=19.48)   
# set figure size
plt.rcParams["figure.figsize"] = (16, 10)
allcat_values = [250,260,280,300,320,400,450,500,550,600,650,700,750,800,850,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
# allcat_values = [250,260,270,280,300,320,400,450,500,550,600,650,700,750,800,850,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
plt.plot(allcat_values, [M250_cat1234[2],M260_cat1234[2],M280_cat1234[2],M300_cat1234[2],M320_cat1234[2],M400_cat1234[2],M450_cat1234[2],M500_cat1234[2],M550_cat1234[2],M600_cat1234[2],M650_cat1234[2],M700_cat1234[2],M750_cat1234[2],M800_cat1234[2],M850_cat1234[2],M1100_cat1234[2],M1200_cat1234[2],M1300_cat1234[2],M1400_cat1234[2],M1500_cat1234[2],M1600_cat1234[2],M1700_cat1234[2],M1800_cat1234[2],M1900_cat1234[2],M2000_cat1234[2],M2200_cat1234[2],M2400_cat1234[2],M2600_cat1234[2],M2800_cat1234[2],M3000_cat1234[2]],color='black', linewidth=2,linestyle='-', label='Asymptotic Limits CLs expected')
# 68% confidence interval
plt.fill_between(allcat_values, [M250_cat1234[1],M260_cat1234[1],M280_cat1234[1],M300_cat1234[1],M320_cat1234[1],M400_cat1234[1],M450_cat1234[1],M500_cat1234[1],M550_cat1234[1],M600_cat1234[1],M650_cat1234[1],M700_cat1234[1],M750_cat1234[1],M800_cat1234[1],M850_cat1234[1],M1100_cat1234[1],M1200_cat1234[1],M1300_cat1234[1],M1400_cat1234[1],M1500_cat1234[1],M1600_cat1234[1],M1700_cat1234[1],M1800_cat1234[1],M1900_cat1234[1],M2000_cat1234[1],M2200_cat1234[1],M2400_cat1234[1],M2600_cat1234[1],M2800_cat1234[1],M3000_cat1234[1]], [M250_cat1234[3],M260_cat1234[3],M280_cat1234[3],M300_cat1234[3],M320_cat1234[3],M400_cat1234[3],M450_cat1234[3],M500_cat1234[3],M550_cat1234[3],M600_cat1234[3],M650_cat1234[3],M700_cat1234[3],M750_cat1234[3],M800_cat1234[3],M850_cat1234[3],M1100_cat1234[3],M1200_cat1234[3],M1300_cat1234[3],M1400_cat1234[3],M1500_cat1234[3],M1600_cat1234[3],M1700_cat1234[3],M1800_cat1234[3],M1900_cat1234[3],M2000_cat1234[3],M2200_cat1234[3],M2400_cat1234[3],M2600_cat1234[3],M2800_cat1234[3],M3000_cat1234[3]], color='#04cb02', alpha=1, label= r'±1 std. deviation')
# 95% confidence interval
plt.fill_between(allcat_values, [M250_cat1234[0],M260_cat1234[0],M280_cat1234[0],M300_cat1234[0],M320_cat1234[0],M400_cat1234[0],M450_cat1234[0],M500_cat1234[0],M550_cat1234[0],M600_cat1234[0],M650_cat1234[0],M700_cat1234[0],M750_cat1234[0],M800_cat1234[0],M850_cat1234[0],M1100_cat1234[0],M1200_cat1234[0],M1300_cat1234[0],M1400_cat1234[0],M1500_cat1234[0],M1600_cat1234[0],M1700_cat1234[0],M1800_cat1234[0],M1900_cat1234[0],M2000_cat1234[0],M2200_cat1234[0],M2400_cat1234[0],M2600_cat1234[0],M2800_cat1234[0],M3000_cat1234[0]],[M250_cat1234[1],M260_cat1234[1],M280_cat1234[1],M300_cat1234[1],M320_cat1234[1],M400_cat1234[1],M450_cat1234[1],M500_cat1234[1],M550_cat1234[1],M600_cat1234[1],M650_cat1234[1],M700_cat1234[1],M750_cat1234[1],M800_cat1234[1],M850_cat1234[1],M1100_cat1234[1],M1200_cat1234[1],M1300_cat1234[1],M1400_cat1234[1],M1500_cat1234[1],M1600_cat1234[1],M1700_cat1234[1],M1800_cat1234[1],M1900_cat1234[1],M2000_cat1234[1],M2200_cat1234[1],M2400_cat1234[1],M2600_cat1234[1],M2800_cat1234[1],M3000_cat1234[1]], color='gold', alpha=1, label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_cat1234[3],M260_cat1234[3],M280_cat1234[3],M300_cat1234[3],M320_cat1234[3],M400_cat1234[3],M450_cat1234[3],M500_cat1234[3],M550_cat1234[3],M600_cat1234[3],M650_cat1234[3],M700_cat1234[3],M750_cat1234[3],M800_cat1234[3],M850_cat1234[3],M1100_cat1234[3],M1200_cat1234[3],M1300_cat1234[3],M1400_cat1234[3],M1500_cat1234[3],M1600_cat1234[3],M1700_cat1234[3],M1800_cat1234[3],M1900_cat1234[3],M2000_cat1234[3],M2200_cat1234[3],M2400_cat1234[3],M2600_cat1234[3],M2800_cat1234[3],M3000_cat1234[3]],  [M250_cat1234[4],M260_cat1234[4],M280_cat1234[4],M300_cat1234[4],M320_cat1234[4],M400_cat1234[4],M450_cat1234[4],M500_cat1234[4],M550_cat1234[4],M600_cat1234[4],M650_cat1234[4],M700_cat1234[4],M750_cat1234[4],M800_cat1234[4],M850_cat1234[4],M1100_cat1234[4],M1200_cat1234[4],M1300_cat1234[4],M1400_cat1234[4],M1500_cat1234[4],M1600_cat1234[4],M1700_cat1234[4],M1800_cat1234[4],M1900_cat1234[4],M2000_cat1234[4],M2200_cat1234[4],M2400_cat1234[4],M2600_cat1234[4],M2800_cat1234[4],M3000_cat1234[4]], color='gold', alpha=1)
plt.xlabel(r'Radion Mass (GeV)')
# plt.ylabel(r'95% CL limits on $\sigma(ggX)*Br(XHHWWgg)[fb]$')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,3000)
plt.xticks([250, 500, 1000, 1500, 2000, 3000], ['250', '500', '1000', '1500', '2000', '3000'])
# plt.xticks(np.arange(250, 3001, 100))
# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,100000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(0.95, 0.95))

# %% [markdown]
# # 16post

# %%
M250_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX250_MH125/higgsCombinecat34_MX250_MH125_2016post.AsymptoticLimits.mH125.root")
M250_cat34 = M250_events_cat34["limit"].arrays(['limit']).limit*100
M260_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX260_MH125/higgsCombinecat34_MX260_MH125_2016post.AsymptoticLimits.mH125.root")
M260_cat34 = M260_events_cat34["limit"].arrays(['limit']).limit*100
# M270_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX270_MH125/higgsCombinecat34_MX270_MH125_2016post.AsymptoticLimits.mH125.root")
# M270_cat34 = M270_events_cat34["limit"].arrays(['limit']).limit*100
M280_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX280_MH125/higgsCombinecat34_MX280_MH125_2016post.AsymptoticLimits.mH125.root")
M280_cat34 = M280_events_cat34["limit"].arrays(['limit']).limit*100
M300_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX300_MH125/higgsCombinecat34_MX300_MH125_2016post.AsymptoticLimits.mH125.root")
M300_cat34 = M300_events_cat34["limit"].arrays(['limit']).limit*100
M320_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX320_MH125/higgsCombinecat34_MX320_MH125_2016post.AsymptoticLimits.mH125.root")
M320_cat34 = M320_events_cat34["limit"].arrays(['limit']).limit*100
M350_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX350_MH125/higgsCombinecat34_MX350_MH125_2016post.AsymptoticLimits.mH125.root")
M350_cat34 = M350_events_cat34["limit"].arrays(['limit']).limit*100
M400_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX400_MH125/higgsCombinecat34_MX400_MH125_2016post.AsymptoticLimits.mH125.root")
M400_cat34 = M400_events_cat34["limit"].arrays(['limit']).limit*100
M450_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX450_MH125/higgsCombinecat34_MX450_MH125_2016post.AsymptoticLimits.mH125.root")
M450_cat34 = M450_events_cat34["limit"].arrays(['limit']).limit*100
M500_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX500_MH125/higgsCombinecat34_MX500_MH125_2016post.AsymptoticLimits.mH125.root")
M500_cat34 = M500_events_cat34["limit"].arrays(['limit']).limit*100
M550_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX550_MH125/higgsCombinecat34_MX550_MH125_2016post.AsymptoticLimits.mH125.root")
M550_cat34 = M550_events_cat34["limit"].arrays(['limit']).limit*100
M600_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX600_MH125/higgsCombinecat34_MX600_MH125_2016post.AsymptoticLimits.mH125.root")
M600_cat34 = M600_events_cat34["limit"].arrays(['limit']).limit*100
M650_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX650_MH125/higgsCombinecat34_MX650_MH125_2016post.AsymptoticLimits.mH125.root")
M650_cat34 = M650_events_cat34["limit"].arrays(['limit']).limit*100
M700_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX700_MH125/higgsCombinecat34_MX700_MH125_2016post.AsymptoticLimits.mH125.root")
M700_cat34 = M700_events_cat34["limit"].arrays(['limit']).limit*100
M750_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX750_MH125/higgsCombinecat34_MX750_MH125_2016post.AsymptoticLimits.mH125.root")
M750_cat34 = M750_events_cat34["limit"].arrays(['limit']).limit*100
M800_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX800_MH125/higgsCombinecat34_MX800_MH125_2016post.AsymptoticLimits.mH125.root")
M800_cat34 = M800_events_cat34["limit"].arrays(['limit']).limit*100
M850_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX850_MH125/higgsCombinecat34_MX850_MH125_2016post.AsymptoticLimits.mH125.root")
M850_cat34 = M850_events_cat34["limit"].arrays(['limit']).limit*100
M1000_events_cat34 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1000_MH125/higgsCombinecat34_MX1000_MH125_2016post.AsymptoticLimits.mH125.root")
M1000_cat34 = M1000_events_cat34["limit"].arrays(['limit']).limit*100

# %%
hep.style.use(hep.style.CMS)
hep.cms.label("preliminary", data=True, year='16preVFP', lumi=16.76)   
# set figure size
plt.rcParams["figure.figsize"] = (20,20)
allcat_values = [250,260,280,300,320,400,450,500,550,600,650,700,750,800,850,1000]
plt.plot(allcat_values, [M250_cat34[2],M260_cat34[2],M280_cat34[2],M300_cat34[2],M320_cat34[2],M400_cat34[2],M450_cat34[2],M500_cat34[2],M550_cat34[2],M600_cat34[2],M650_cat34[2],M700_cat34[2],M750_cat34[2],M800_cat34[2],M850_cat34[2],M1000_cat34[2]],color='black', linewidth=2,linestyle='-', label='WWgg + ZZgg + bbgg Signal')#'Asymptotic Limits CLs expected'

# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M250_cat34[1],M260_cat34[1],M280_cat34[1],M300_cat34[1],M320_cat34[1],M400_cat34[1],M450_cat34[1],M500_cat34[1],M550_cat34[1],M600_cat34[1],M650_cat34[1],M700_cat34[1],M750_cat34[1],M800_cat34[1],M850_cat34[1],M1000_cat34[1]], [M250_cat34[3],M260_cat34[3],M280_cat34[3],M300_cat34[3],M320_cat34[3],M400_cat34[3],M450_cat34[3],M500_cat34[3],M550_cat34[3],M600_cat34[3],M650_cat34[3],M700_cat34[3],M750_cat34[3],M800_cat34[3],M850_cat34[3],M1000_cat34[3]], color='#04cb02', alpha=1, label= r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M250_cat34[0],M260_cat34[0],M280_cat34[0],M300_cat34[0],M320_cat34[0],M400_cat34[0],M450_cat34[0],M500_cat34[0],M550_cat34[0],M600_cat34[0],M650_cat34[0],M700_cat34[0],M750_cat34[0],M800_cat34[0],M850_cat34[0],M1000_cat34[0]],[M250_cat34[1],M260_cat34[1],M280_cat34[1],M300_cat34[1],M320_cat34[1],M400_cat34[1],M450_cat34[1],M500_cat34[1],M550_cat34[1],M600_cat34[1],M650_cat34[1],M700_cat34[1],M750_cat34[1],M800_cat34[1],M850_cat34[1],M1000_cat34[1]], color='gold', alpha=1, label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_cat34[3],M260_cat34[3],M280_cat34[3],M300_cat34[3],M320_cat34[3],M400_cat34[3],M450_cat34[3],M500_cat34[3],M550_cat34[3],M600_cat34[3],M650_cat34[3],M700_cat34[3],M750_cat34[3],M800_cat34[3],M850_cat34[3],M1000_cat34[3]],  [M250_cat34[4],M260_cat34[4],M280_cat34[4],M300_cat34[4],M320_cat34[4],M400_cat34[4],M450_cat34[4],M500_cat34[4],M550_cat34[4],M600_cat34[4],M650_cat34[4],M700_cat34[4],M750_cat34[4],M800_cat34[4],M850_cat34[4],M1000_cat34[4]], color='gold', alpha=1)

plt.xlabel(r'Radion Mass (GeV)')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,1000)

# set log scale
plt.yscale('log')
# set y limit
plt.ylim(100,100000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(1., 0.95))

# %%
M500_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX500_MH125/higgsCombinecat12_MX500_MH125_2016post.AsymptoticLimits.mH125.root")
M500_cat_cat12 = M500_events_cat12["limit"].arrays(['limit']).limit*100
M550_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX550_MH125/higgsCombinecat12_MX550_MH125_2016post.AsymptoticLimits.mH125.root")
M550_cat_cat12 = M550_events_cat12["limit"].arrays(['limit']).limit*100
M600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX600_MH125/higgsCombinecat12_MX600_MH125_2016post.AsymptoticLimits.mH125.root")
M600_cat_cat12 = M600_events_cat12["limit"].arrays(['limit']).limit*100
M650_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX650_MH125/higgsCombinecat12_MX650_MH125_2016post.AsymptoticLimits.mH125.root")
M650_cat_cat12 = M650_events_cat12["limit"].arrays(['limit']).limit*100
M700_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX700_MH125/higgsCombinecat12_MX700_MH125_2016post.AsymptoticLimits.mH125.root")
M700_cat_cat12 = M700_events_cat12["limit"].arrays(['limit']).limit*100
M750_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX750_MH125/higgsCombinecat12_MX750_MH125_2016post.AsymptoticLimits.mH125.root")
M750_cat_cat12 = M750_events_cat12["limit"].arrays(['limit']).limit*100
M800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX800_MH125/higgsCombinecat12_MX800_MH125_2016post.AsymptoticLimits.mH125.root")
M800_cat_cat12 = M800_events_cat12["limit"].arrays(['limit']).limit*100
M850_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX850_MH125/higgsCombinecat12_MX850_MH125_2016post.AsymptoticLimits.mH125.root")
M850_cat_cat12 = M850_events_cat12["limit"].arrays(['limit']).limit*100
M1000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1000_MH125/higgsCombinecat12_MX1000_MH125_2016post.AsymptoticLimits.mH125.root")
M1000_cat_cat12 = M1000_events_cat12["limit"].arrays(['limit']).limit*100
M1100_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1100_MH125/higgsCombinecat12_MX1100_MH125_2016post.AsymptoticLimits.mH125.root")
M1100_cat_cat12 = M1100_events_cat12["limit"].arrays(['limit']).limit
M1200_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1200_MH125/higgsCombinecat12_MX1200_MH125_2016post.AsymptoticLimits.mH125.root")
M1200_cat_cat12 = M1200_events_cat12["limit"].arrays(['limit']).limit
M1300_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1300_MH125/higgsCombinecat12_MX1300_MH125_2016post.AsymptoticLimits.mH125.root")
M1300_cat_cat12 = M1300_events_cat12["limit"].arrays(['limit']).limit
M1400_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1400_MH125/higgsCombinecat12_MX1400_MH125_2016post.AsymptoticLimits.mH125.root")
M1400_cat_cat12 = M1400_events_cat12["limit"].arrays(['limit']).limit
M1500_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1500_MH125/higgsCombinecat12_MX1500_MH125_2016post.AsymptoticLimits.mH125.root")
M1500_cat_cat12 = M1500_events_cat12["limit"].arrays(['limit']).limit
M1600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1600_MH125/higgsCombinecat12_MX1600_MH125_2016post.AsymptoticLimits.mH125.root")
M1600_cat_cat12 = M1600_events_cat12["limit"].arrays(['limit']).limit
M1700_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1700_MH125/higgsCombinecat12_MX1700_MH125_2016post.AsymptoticLimits.mH125.root")
M1700_cat_cat12 = M1700_events_cat12["limit"].arrays(['limit']).limit
M1800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1800_MH125/higgsCombinecat12_MX1800_MH125_2016post.AsymptoticLimits.mH125.root")
M1800_cat_cat12 = M1800_events_cat12["limit"].arrays(['limit']).limit
M1900_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1900_MH125/higgsCombinecat12_MX1900_MH125_2016post.AsymptoticLimits.mH125.root")
M1900_cat_cat12 = M1900_events_cat12["limit"].arrays(['limit']).limit
M2000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2000_MH125/higgsCombinecat12_MX2000_MH125_2016post.AsymptoticLimits.mH125.root")
M2000_cat_cat12 = M2000_events_cat12["limit"].arrays(['limit']).limit
M2200_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2200_MH125/higgsCombinecat12_MX2200_MH125_2016post.AsymptoticLimits.mH125.root")
M2200_cat_cat12 = M2200_events_cat12["limit"].arrays(['limit']).limit
M2400_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2400_MH125/higgsCombinecat12_MX2400_MH125_2016post.AsymptoticLimits.mH125.root")
M2400_cat_cat12 = M2400_events_cat12["limit"].arrays(['limit']).limit
M2600_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2600_MH125/higgsCombinecat12_MX2600_MH125_2016post.AsymptoticLimits.mH125.root")
M2600_cat_cat12 = M2600_events_cat12["limit"].arrays(['limit']).limit
M2800_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2800_MH125/higgsCombinecat12_MX2800_MH125_2016post.AsymptoticLimits.mH125.root")
M2800_cat_cat12 = M2800_events_cat12["limit"].arrays(['limit']).limit
M3000_events_cat12 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX3000_MH125/higgsCombinecat12_MX3000_MH125_2016post.AsymptoticLimits.mH125.root")
M3000_cat_cat12 = M3000_events_cat12["limit"].arrays(['limit']).limit
hep.style.use(hep.style.CMS)

hep.cms.label("postliminary", data=True, year='16postVFP', lumi=16.46)   
# set figure size
plt.rcParams["figure.figsize"] = (16, 10)

allcat_values = [500,550,600,650,700,750,800,850,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
plt.plot(allcat_values, [M500_cat_cat12[2],M550_cat_cat12[2],M600_cat_cat12[2],M650_cat_cat12[2],M700_cat_cat12[2],M750_cat_cat12[2],M800_cat_cat12[2],M850_cat_cat12[2],M1000_cat_cat12[2],M1100_cat_cat12[2],M1200_cat_cat12[2],M1300_cat_cat12[2],M1400_cat_cat12[2],M1500_cat_cat12[2],M1600_cat_cat12[2],M1700_cat_cat12[2],M1800_cat_cat12[2],M1900_cat_cat12[2],M2000_cat_cat12[2],M2200_cat_cat12[2],M2400_cat_cat12[2],M2600_cat_cat12[2],M2800_cat_cat12[2],M3000_cat_cat12[2]],color='black', linewidth=2,linestyle='-', label='Asymptotic Limits CLs expected')

# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M500_cat_cat12[1],M550_cat_cat12[1],M600_cat_cat12[1],M650_cat_cat12[1],M700_cat_cat12[1],M750_cat_cat12[1],M800_cat_cat12[1],M850_cat_cat12[1],M1000_cat_cat12[1],M1100_cat_cat12[1],M1200_cat_cat12[1],M1300_cat_cat12[1],M1400_cat_cat12[1],M1500_cat_cat12[1],M1600_cat_cat12[1],M1700_cat_cat12[1],M1800_cat_cat12[1],M1900_cat_cat12[1],M2000_cat_cat12[1],M2200_cat_cat12[1],M2400_cat_cat12[1],M2600_cat_cat12[1],M2800_cat_cat12[1],M3000_cat_cat12[1]], [M500_cat_cat12[3],M550_cat_cat12[3],M600_cat_cat12[3],M650_cat_cat12[3],M700_cat_cat12[3],M750_cat_cat12[3],M800_cat_cat12[3],M850_cat_cat12[3],M1000_cat_cat12[3],M1100_cat_cat12[3],M1200_cat_cat12[3],M1300_cat_cat12[3],M1400_cat_cat12[3],M1500_cat_cat12[3],M1600_cat_cat12[3],M1700_cat_cat12[3],M1800_cat_cat12[3],M1900_cat_cat12[3],M2000_cat_cat12[3],M2200_cat_cat12[3],M2400_cat_cat12[3],M2600_cat_cat12[3],M2800_cat_cat12[3],M3000_cat_cat12[3]], color='#04cb02', alpha=1, label= r'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M500_cat_cat12[0],M550_cat_cat12[0],M600_cat_cat12[0],M650_cat_cat12[0],M700_cat_cat12[0],M750_cat_cat12[0],M800_cat_cat12[0],M850_cat_cat12[0],M1000_cat_cat12[0],M1100_cat_cat12[0],M1200_cat_cat12[0],M1300_cat_cat12[0],M1400_cat_cat12[0],M1500_cat_cat12[0],M1600_cat_cat12[0],M1700_cat_cat12[0],M1800_cat_cat12[0],M1900_cat_cat12[0],M2000_cat_cat12[0],M2200_cat_cat12[0],M2400_cat_cat12[0],M2600_cat_cat12[0],M2800_cat_cat12[0],M3000_cat_cat12[0]],[M500_cat_cat12[1],M550_cat_cat12[1],M600_cat_cat12[1],M650_cat_cat12[1],M700_cat_cat12[1],M750_cat_cat12[1],M800_cat_cat12[1],M850_cat_cat12[1],M1000_cat_cat12[1],M1100_cat_cat12[1],M1200_cat_cat12[1],M1300_cat_cat12[1],M1400_cat_cat12[1],M1500_cat_cat12[1],M1600_cat_cat12[1],M1700_cat_cat12[1],M1800_cat_cat12[1],M1900_cat_cat12[1],M2000_cat_cat12[1],M2200_cat_cat12[1],M2400_cat_cat12[1],M2600_cat_cat12[1],M2800_cat_cat12[1],M3000_cat_cat12[1]], color='gold', alpha=1, label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M500_cat_cat12[3],M550_cat_cat12[3],M600_cat_cat12[3],M650_cat_cat12[3],M700_cat_cat12[3],M750_cat_cat12[3],M800_cat_cat12[3],M850_cat_cat12[3],M1000_cat_cat12[3],M1100_cat_cat12[3],M1200_cat_cat12[3],M1300_cat_cat12[3],M1400_cat_cat12[3],M1500_cat_cat12[3],M1600_cat_cat12[3],M1700_cat_cat12[3],M1800_cat_cat12[3],M1900_cat_cat12[3],M2000_cat_cat12[3],M2200_cat_cat12[3],M2400_cat_cat12[3],M2600_cat_cat12[3],M2800_cat_cat12[3],M3000_cat_cat12[3]],  [M500_cat_cat12[4],M550_cat_cat12[4],M600_cat_cat12[4],M650_cat_cat12[4],M700_cat_cat12[4],M750_cat_cat12[4],M800_cat_cat12[4],M850_cat_cat12[4],M1000_cat_cat12[4],M1100_cat_cat12[4],M1200_cat_cat12[4],M1300_cat_cat12[4],M1400_cat_cat12[4],M1500_cat_cat12[4],M1600_cat_cat12[4],M1700_cat_cat12[4],M1800_cat_cat12[4],M1900_cat_cat12[4],M2000_cat_cat12[4],M2200_cat_cat12[4],M2400_cat_cat12[4],M2600_cat_cat12[4],M2800_cat_cat12[4],M3000_cat_cat12[4]], color='gold', alpha=1)

# 添加标签和标题
plt.xlabel(r'Radion Mass (GeV)')
# plt.ylabel(r'95% CL limits on $\sigma(ggX)*Br(XHHWWgg)[fb]$')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(500,3000)
#每1000GeV一个刻度
# plt.xticks(np.arange(200, 3001, 500))
# set x ticks
# plt.xticks(np.arange(1000, 3001, 500))
# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,10000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(0.95, 0.95))

# %%
M250_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX250_MH125/higgsCombinecat34_MX250_MH125_2016post.AsymptoticLimits.mH125.root")
M250_cat1234 = M250_events_cat1234["limit"].arrays(['limit']).limit*100
M260_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX260_MH125/higgsCombinecat34_MX260_MH125_2016post.AsymptoticLimits.mH125.root")
M260_cat1234 = M260_events_cat1234["limit"].arrays(['limit']).limit*100
# M270_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX270_MH125/higgsCombinecat34_MX270_MH125_2016post.AsymptoticLimits.mH125.root")
# M270_cat1234 = M270_events_cat1234["limit"].arrays(['limit']).limit*100
M280_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX280_MH125/higgsCombinecat34_MX280_MH125_2016post.AsymptoticLimits.mH125.root")
M280_cat1234 = M280_events_cat1234["limit"].arrays(['limit']).limit*100
M300_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX300_MH125/higgsCombinecat34_MX300_MH125_2016post.AsymptoticLimits.mH125.root")
M300_cat1234 = M300_events_cat1234["limit"].arrays(['limit']).limit*100
M320_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX320_MH125/higgsCombinecat34_MX320_MH125_2016post.AsymptoticLimits.mH125.root")
M320_cat1234 = M320_events_cat1234["limit"].arrays(['limit']).limit*100
M350_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX350_MH125/higgsCombinecat34_MX350_MH125_2016post.AsymptoticLimits.mH125.root")
M350_cat1234 = M350_events_cat1234["limit"].arrays(['limit']).limit*100
M400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX400_MH125/higgsCombinecat34_MX400_MH125_2016post.AsymptoticLimits.mH125.root")
M400_cat1234 = M400_events_cat1234["limit"].arrays(['limit']).limit*100
M450_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX450_MH125/higgsCombinecat34_MX450_MH125_2016post.AsymptoticLimits.mH125.root")
M450_cat1234 = M450_events_cat1234["limit"].arrays(['limit']).limit*100
M500_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX500_MH125/higgsCombinecat1234_MX500_MH125_2016post.AsymptoticLimits.mH125.root")
M500_cat1234 = M500_events_cat1234["limit"].arrays(['limit']).limit*100
M550_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX550_MH125/higgsCombinecat1234_MX550_MH125_2016post.AsymptoticLimits.mH125.root")
M550_cat1234 = M550_events_cat1234["limit"].arrays(['limit']).limit*100
M600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX600_MH125/higgsCombinecat1234_MX600_MH125_2016post.AsymptoticLimits.mH125.root")
M600_cat1234 = M600_events_cat1234["limit"].arrays(['limit']).limit*100
M650_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX650_MH125/higgsCombinecat1234_MX650_MH125_2016post.AsymptoticLimits.mH125.root")
M650_cat1234 = M650_events_cat1234["limit"].arrays(['limit']).limit*100
M700_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX700_MH125/higgsCombinecat1234_MX700_MH125_2016post.AsymptoticLimits.mH125.root")
M700_cat1234 = M700_events_cat1234["limit"].arrays(['limit']).limit*100
M750_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX750_MH125/higgsCombinecat1234_MX750_MH125_2016post.AsymptoticLimits.mH125.root")
M750_cat1234 = M750_events_cat1234["limit"].arrays(['limit']).limit*100
M800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX800_MH125/higgsCombinecat1234_MX800_MH125_2016post.AsymptoticLimits.mH125.root")
M800_cat1234 = M800_events_cat1234["limit"].arrays(['limit']).limit*100
M850_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX850_MH125/higgsCombinecat1234_MX850_MH125_2016post.AsymptoticLimits.mH125.root")
M850_cat1234 = M850_events_cat1234["limit"].arrays(['limit']).limit*100
M1000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1000_MH125/higgsCombinecat1234_MX1000_MH125_2016post.AsymptoticLimits.mH125.root")
M1000_cat1234 = M1000_events_cat1234["limit"].arrays(['limit']).limit
M1100_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1100_MH125/higgsCombinecat12_MX1100_MH125_2016post.AsymptoticLimits.mH125.root")
M1100_cat1234 = M1100_events_cat1234["limit"].arrays(['limit']).limit
M1200_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1200_MH125/higgsCombinecat12_MX1200_MH125_2016post.AsymptoticLimits.mH125.root")
M1200_cat1234 = M1200_events_cat1234["limit"].arrays(['limit']).limit
M1300_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1300_MH125/higgsCombinecat12_MX1300_MH125_2016post.AsymptoticLimits.mH125.root")
M1300_cat1234 = M1300_events_cat1234["limit"].arrays(['limit']).limit
M1400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1400_MH125/higgsCombinecat12_MX1400_MH125_2016post.AsymptoticLimits.mH125.root")
M1400_cat1234 = M1400_events_cat1234["limit"].arrays(['limit']).limit
M1500_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1500_MH125/higgsCombinecat12_MX1500_MH125_2016post.AsymptoticLimits.mH125.root")
M1500_cat1234 = M1500_events_cat1234["limit"].arrays(['limit']).limit
M1600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1600_MH125/higgsCombinecat12_MX1600_MH125_2016post.AsymptoticLimits.mH125.root")
M1600_cat1234 = M1600_events_cat1234["limit"].arrays(['limit']).limit
M1700_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1700_MH125/higgsCombinecat12_MX1700_MH125_2016post.AsymptoticLimits.mH125.root")
M1700_cat1234 = M1700_events_cat1234["limit"].arrays(['limit']).limit
M1800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1800_MH125/higgsCombinecat12_MX1800_MH125_2016post.AsymptoticLimits.mH125.root")
M1800_cat1234 = M1800_events_cat1234["limit"].arrays(['limit']).limit
M1900_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX1900_MH125/higgsCombinecat12_MX1900_MH125_2016post.AsymptoticLimits.mH125.root")
M1900_cat1234 = M1900_events_cat1234["limit"].arrays(['limit']).limit
M2000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2000_MH125/higgsCombinecat12_MX2000_MH125_2016post.AsymptoticLimits.mH125.root")
M2000_cat1234 = M2000_events_cat1234["limit"].arrays(['limit']).limit
M2200_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2200_MH125/higgsCombinecat12_MX2200_MH125_2016post.AsymptoticLimits.mH125.root")
M2200_cat1234 = M2200_events_cat1234["limit"].arrays(['limit']).limit
M2400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2400_MH125/higgsCombinecat12_MX2400_MH125_2016post.AsymptoticLimits.mH125.root")
M2400_cat1234 = M2400_events_cat1234["limit"].arrays(['limit']).limit
M2600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2600_MH125/higgsCombinecat12_MX2600_MH125_2016post.AsymptoticLimits.mH125.root")
M2600_cat1234 = M2600_events_cat1234["limit"].arrays(['limit']).limit
M2800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX2800_MH125/higgsCombinecat12_MX2800_MH125_2016post.AsymptoticLimits.mH125.root")
M2800_cat1234 = M2800_events_cat1234["limit"].arrays(['limit']).limit
M3000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/2016postdatacard/datacard_MX3000_MH125/higgsCombinecat12_MX3000_MH125_2016post.AsymptoticLimits.mH125.root")
M3000_cat1234 = M3000_events_cat1234["limit"].arrays(['limit']).limit
hep.style.use(hep.style.CMS)

hep.cms.label("postliminary", data=True, year='2016post', lumi=16.46)   
# set figure size
plt.rcParams["figure.figsize"] = (16, 10)
allcat_values = [250,260,280,300,320,400,450,500,550,600,650,700,750,800,850,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
# allcat_values = [250,260,270,280,300,320,400,450,500,550,600,650,700,750,800,850,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
plt.plot(allcat_values, [M250_cat1234[2],M260_cat1234[2],M280_cat1234[2],M300_cat1234[2],M320_cat1234[2],M400_cat1234[2],M450_cat1234[2],M500_cat1234[2],M550_cat1234[2],M600_cat1234[2],M650_cat1234[2],M700_cat1234[2],M750_cat1234[2],M800_cat1234[2],M850_cat1234[2],M1100_cat1234[2],M1200_cat1234[2],M1300_cat1234[2],M1400_cat1234[2],M1500_cat1234[2],M1600_cat1234[2],M1700_cat1234[2],M1800_cat1234[2],M1900_cat1234[2],M2000_cat1234[2],M2200_cat1234[2],M2400_cat1234[2],M2600_cat1234[2],M2800_cat1234[2],M3000_cat1234[2]],color='black', linewidth=2,linestyle='-', label='Asymptotic Limits CLs expected')
# 68% confidence interval
plt.fill_between(allcat_values, [M250_cat1234[1],M260_cat1234[1],M280_cat1234[1],M300_cat1234[1],M320_cat1234[1],M400_cat1234[1],M450_cat1234[1],M500_cat1234[1],M550_cat1234[1],M600_cat1234[1],M650_cat1234[1],M700_cat1234[1],M750_cat1234[1],M800_cat1234[1],M850_cat1234[1],M1100_cat1234[1],M1200_cat1234[1],M1300_cat1234[1],M1400_cat1234[1],M1500_cat1234[1],M1600_cat1234[1],M1700_cat1234[1],M1800_cat1234[1],M1900_cat1234[1],M2000_cat1234[1],M2200_cat1234[1],M2400_cat1234[1],M2600_cat1234[1],M2800_cat1234[1],M3000_cat1234[1]], [M250_cat1234[3],M260_cat1234[3],M280_cat1234[3],M300_cat1234[3],M320_cat1234[3],M400_cat1234[3],M450_cat1234[3],M500_cat1234[3],M550_cat1234[3],M600_cat1234[3],M650_cat1234[3],M700_cat1234[3],M750_cat1234[3],M800_cat1234[3],M850_cat1234[3],M1100_cat1234[3],M1200_cat1234[3],M1300_cat1234[3],M1400_cat1234[3],M1500_cat1234[3],M1600_cat1234[3],M1700_cat1234[3],M1800_cat1234[3],M1900_cat1234[3],M2000_cat1234[3],M2200_cat1234[3],M2400_cat1234[3],M2600_cat1234[3],M2800_cat1234[3],M3000_cat1234[3]], color='#04cb02', alpha=1, label= r'±1 std. deviation')
# 95% confidence interval
plt.fill_between(allcat_values, [M250_cat1234[0],M260_cat1234[0],M280_cat1234[0],M300_cat1234[0],M320_cat1234[0],M400_cat1234[0],M450_cat1234[0],M500_cat1234[0],M550_cat1234[0],M600_cat1234[0],M650_cat1234[0],M700_cat1234[0],M750_cat1234[0],M800_cat1234[0],M850_cat1234[0],M1100_cat1234[0],M1200_cat1234[0],M1300_cat1234[0],M1400_cat1234[0],M1500_cat1234[0],M1600_cat1234[0],M1700_cat1234[0],M1800_cat1234[0],M1900_cat1234[0],M2000_cat1234[0],M2200_cat1234[0],M2400_cat1234[0],M2600_cat1234[0],M2800_cat1234[0],M3000_cat1234[0]],[M250_cat1234[1],M260_cat1234[1],M280_cat1234[1],M300_cat1234[1],M320_cat1234[1],M400_cat1234[1],M450_cat1234[1],M500_cat1234[1],M550_cat1234[1],M600_cat1234[1],M650_cat1234[1],M700_cat1234[1],M750_cat1234[1],M800_cat1234[1],M850_cat1234[1],M1100_cat1234[1],M1200_cat1234[1],M1300_cat1234[1],M1400_cat1234[1],M1500_cat1234[1],M1600_cat1234[1],M1700_cat1234[1],M1800_cat1234[1],M1900_cat1234[1],M2000_cat1234[1],M2200_cat1234[1],M2400_cat1234[1],M2600_cat1234[1],M2800_cat1234[1],M3000_cat1234[1]], color='gold', alpha=1, label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_cat1234[3],M260_cat1234[3],M280_cat1234[3],M300_cat1234[3],M320_cat1234[3],M400_cat1234[3],M450_cat1234[3],M500_cat1234[3],M550_cat1234[3],M600_cat1234[3],M650_cat1234[3],M700_cat1234[3],M750_cat1234[3],M800_cat1234[3],M850_cat1234[3],M1100_cat1234[3],M1200_cat1234[3],M1300_cat1234[3],M1400_cat1234[3],M1500_cat1234[3],M1600_cat1234[3],M1700_cat1234[3],M1800_cat1234[3],M1900_cat1234[3],M2000_cat1234[3],M2200_cat1234[3],M2400_cat1234[3],M2600_cat1234[3],M2800_cat1234[3],M3000_cat1234[3]],  [M250_cat1234[4],M260_cat1234[4],M280_cat1234[4],M300_cat1234[4],M320_cat1234[4],M400_cat1234[4],M450_cat1234[4],M500_cat1234[4],M550_cat1234[4],M600_cat1234[4],M650_cat1234[4],M700_cat1234[4],M750_cat1234[4],M800_cat1234[4],M850_cat1234[4],M1100_cat1234[4],M1200_cat1234[4],M1300_cat1234[4],M1400_cat1234[4],M1500_cat1234[4],M1600_cat1234[4],M1700_cat1234[4],M1800_cat1234[4],M1900_cat1234[4],M2000_cat1234[4],M2200_cat1234[4],M2400_cat1234[4],M2600_cat1234[4],M2800_cat1234[4],M3000_cat1234[4]], color='gold', alpha=1)
plt.xlabel(r'Radion Mass (GeV)')
# plt.ylabel(r'95% CL limits on $\sigma(ggX)*Br(XHHWWgg)[fb]$')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,3000)
plt.xticks([250, 500, 1000, 1500, 2000, 3000], ['250', '500', '1000', '1500', '2000', '3000'])
# plt.xticks(np.arange(250, 3001, 100))
# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,100000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(0.95, 0.95))

# %%
M250_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX250_MH125_run2.AsymptoticLimits.mH125.root")
M250_cat1234 = M250_events_cat1234["limit"].arrays(['limit']).limit*100
M260_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX260_MH125_run2.AsymptoticLimits.mH125.root")
M260_cat1234 = M260_events_cat1234["limit"].arrays(['limit']).limit*100
M280_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX280_MH125_run2.AsymptoticLimits.mH125.root")
M280_cat1234 = M280_events_cat1234["limit"].arrays(['limit']).limit*100
M300_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX300_MH125_run2.AsymptoticLimits.mH125.root")
M300_cat1234 = M300_events_cat1234["limit"].arrays(['limit']).limit*100
M320_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX320_MH125_run2.AsymptoticLimits.mH125.root")
M320_cat1234 = M320_events_cat1234["limit"].arrays(['limit']).limit*100
M350_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX350_MH125_run2.AsymptoticLimits.mH125.root")
M350_cat1234 = M350_events_cat1234["limit"].arrays(['limit']).limit*100
M400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX400_MH125_run2.AsymptoticLimits.mH125.root")
M400_cat1234 = M400_events_cat1234["limit"].arrays(['limit']).limit*100
M450_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX450_MH125_run2.AsymptoticLimits.mH125.root")
M450_cat1234 = M450_events_cat1234["limit"].arrays(['limit']).limit*100
M500_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX500_MH125_run2.AsymptoticLimits.mH125.root")
M500_cat1234 = M500_events_cat1234["limit"].arrays(['limit']).limit*100
M550_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX550_MH125_run2.AsymptoticLimits.mH125.root")
M550_cat1234 = M550_events_cat1234["limit"].arrays(['limit']).limit*100
M600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX600_MH125_run2.AsymptoticLimits.mH125.root")
M600_cat1234 = M600_events_cat1234["limit"].arrays(['limit']).limit*100
M650_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX650_MH125_run2.AsymptoticLimits.mH125.root")
M650_cat1234 = M650_events_cat1234["limit"].arrays(['limit']).limit*100
M700_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX700_MH125_run2.AsymptoticLimits.mH125.root")
M700_cat1234 = M700_events_cat1234["limit"].arrays(['limit']).limit*100
M750_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX750_MH125_run2.AsymptoticLimits.mH125.root")
M750_cat1234 = M750_events_cat1234["limit"].arrays(['limit']).limit*100
M800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX800_MH125_run2.AsymptoticLimits.mH125.root")
M800_cat1234 = M800_events_cat1234["limit"].arrays(['limit']).limit*100
M850_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX850_MH125_run2.AsymptoticLimits.mH125.root")
M850_cat1234 = M850_events_cat1234["limit"].arrays(['limit']).limit*100
M1100_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1100_MH125_run2.AsymptoticLimits.mH125.root")
M1100_cat1234 = M1100_events_cat1234["limit"].arrays(['limit']).limit
M1200_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1200_MH125_run2.AsymptoticLimits.mH125.root")
M1200_cat1234 = M1200_events_cat1234["limit"].arrays(['limit']).limit
M1300_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1300_MH125_run2.AsymptoticLimits.mH125.root")
M1300_cat1234 = M1300_events_cat1234["limit"].arrays(['limit']).limit
M1400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1400_MH125_run2.AsymptoticLimits.mH125.root")
M1400_cat1234 = M1400_events_cat1234["limit"].arrays(['limit']).limit
M1500_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1500_MH125_run2.AsymptoticLimits.mH125.root")
M1500_cat1234 = M1500_events_cat1234["limit"].arrays(['limit']).limit
M1600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1600_MH125_run2.AsymptoticLimits.mH125.root")
M1600_cat1234 = M1600_events_cat1234["limit"].arrays(['limit']).limit
M1700_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1700_MH125_run2.AsymptoticLimits.mH125.root")
M1700_cat1234 = M1700_events_cat1234["limit"].arrays(['limit']).limit
M1800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1800_MH125_run2.AsymptoticLimits.mH125.root")
M1800_cat1234 = M1800_events_cat1234["limit"].arrays(['limit']).limit
M1900_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1900_MH125_run2.AsymptoticLimits.mH125.root")
M1900_cat1234 = M1900_events_cat1234["limit"].arrays(['limit']).limit
M2000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX2000_MH125_run2.AsymptoticLimits.mH125.root")
M2000_cat1234 = M2000_events_cat1234["limit"].arrays(['limit']).limit
M2200_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX2200_MH125_run2.AsymptoticLimits.mH125.root")
M2200_cat1234 = M2200_events_cat1234["limit"].arrays(['limit']).limit
M2400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX2400_MH125_run2.AsymptoticLimits.mH125.root")
M2400_cat1234 = M2400_events_cat1234["limit"].arrays(['limit']).limit
M2600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX2600_MH125_run2.AsymptoticLimits.mH125.root")
M2600_cat1234 = M2600_events_cat1234["limit"].arrays(['limit']).limit
M2800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX2800_MH125_run2.AsymptoticLimits.mH125.root")
M2800_cat1234 = M2800_events_cat1234["limit"].arrays(['limit']).limit
M3000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX3000_MH125_run2.AsymptoticLimits.mH125.root")
M3000_cat1234 = M3000_events_cat1234["limit"].arrays(['limit']).limit
#plot run2
allcat_values = [250,260,280,300,320,400,450,500,550,600,650,700,750,800,850,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
plt.plot(allcat_values, [M250_cat1234[2],M260_cat1234[2],M280_cat1234[2],M300_cat1234[2],M320_cat1234[2],M400_cat1234[2],M450_cat1234[2],M500_cat1234[2],M550_cat1234[2],M600_cat1234[2],M650_cat1234[2],M700_cat1234[2],M750_cat1234[2],M800_cat1234[2],M850_cat1234[2],M1100_cat1234[2],M1200_cat1234[2],M1300_cat1234[2],M1400_cat1234[2],M1500_cat1234[2],M1600_cat1234[2],M1700_cat1234[2],M1800_cat1234[2],M1900_cat1234[2],M2000_cat1234[2],M2200_cat1234[2],M2400_cat1234[2],M2600_cat1234[2],M2800_cat1234[2],M3000_cat1234[2]],color='black', linewidth=2,linestyle='-', label='Asymptotic Limits CLs expected')
# 68% confidence interval
plt.fill_between(allcat_values, [M250_cat1234[1],M260_cat1234[1],M280_cat1234[1],M300_cat1234[1],M320_cat1234[1],M400_cat1234[1],M450_cat1234[1],M500_cat1234[1],M550_cat1234[1],M600_cat1234[1],M650_cat1234[1],M700_cat1234[1],M750_cat1234[1],M800_cat1234[1],M850_cat1234[1],M1100_cat1234[1],M1200_cat1234[1],M1300_cat1234[1],M1400_cat1234[1],M1500_cat1234[1],M1600_cat1234[1],M1700_cat1234[1],M1800_cat1234[1],M1900_cat1234[1],M2000_cat1234[1],M2200_cat1234[1],M2400_cat1234[1],M2600_cat1234[1],M2800_cat1234[1],M3000_cat1234[1]], [M250_cat1234[3],M260_cat1234[3],M280_cat1234[3],M300_cat1234[3],M320_cat1234[3],M400_cat1234[3],M450_cat1234[3],M500_cat1234[3],M550_cat1234[3],M600_cat1234[3],M650_cat1234[3],M700_cat1234[3],M750_cat1234[3],M800_cat1234[3],M850_cat1234[3],M1100_cat1234[3],M1200_cat1234[3],M1300_cat1234[3],M1400_cat1234[3],M1500_cat1234[3],M1600_cat1234[3],M1700_cat1234[3],M1800_cat1234[3],M1900_cat1234[3],M2000_cat1234[3],M2200_cat1234[3],M2400_cat1234[3],M2600_cat1234[3],M2800_cat1234[3],M3000_cat1234[3]], color='#04cb02', alpha=1, label= r'±1 std. deviation')
# 95% confidence interval
plt.fill_between(allcat_values, [M250_cat1234[0],M260_cat1234[0],M280_cat1234[0],M300_cat1234[0],M320_cat1234[0],M400_cat1234[0],M450_cat1234[0],M500_cat1234[0],M550_cat1234[0],M600_cat1234[0],M650_cat1234[0],M700_cat1234[0],M750_cat1234[0],M800_cat1234[0],M850_cat1234[0],M1100_cat1234[0],M1200_cat1234[0],M1300_cat1234[0],M1400_cat1234[0],M1500_cat1234[0],M1600_cat1234[0],M1700_cat1234[0],M1800_cat1234[0],M1900_cat1234[0],M2000_cat1234[0],M2200_cat1234[0],M2400_cat1234[0],M2600_cat1234[0],M2800_cat1234[0],M3000_cat1234[0]],[M250_cat1234[1],M260_cat1234[1],M280_cat1234[1],M300_cat1234[1],M320_cat1234[1],M400_cat1234[1],M450_cat1234[1],M500_cat1234[1],M550_cat1234[1],M600_cat1234[1],M650_cat1234[1],M700_cat1234[1],M750_cat1234[1],M800_cat1234[1],M850_cat1234[1],M1100_cat1234[1],M1200_cat1234[1],M1300_cat1234[1],M1400_cat1234[1],M1500_cat1234[1],M1600_cat1234[1],M1700_cat1234[1],M1800_cat1234[1],M1900_cat1234[1],M2000_cat1234[1],M2200_cat1234[1],M2400_cat1234[1],M2600_cat1234[1],M2800_cat1234[1],M3000_cat1234[1]], color='gold', alpha=1, label= r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_cat1234[3],M260_cat1234[3],M280_cat1234[3],M300_cat1234[3],M320_cat1234[3],M400_cat1234[3],M450_cat1234[3],M500_cat1234[3],M550_cat1234[3],M600_cat1234[3],M650_cat1234[3],M700_cat1234[3],M750_cat1234[3],M800_cat1234[3],M850_cat1234[3],M1100_cat1234[3],M1200_cat1234[3],M1300_cat1234[3],M1400_cat1234[3],M1500_cat1234[3],M1600_cat1234[3],M1700_cat1234[3],M1800_cat1234[3],M1900_cat1234[3],M2000_cat1234[3],M2200_cat1234[3],M2400_cat1234[3],M2600_cat1234[3],M2800_cat1234[3],M3000_cat1234[3]],  [M250_cat1234[4],M260_cat1234[4],M280_cat1234[4],M300_cat1234[4],M320_cat1234[4],M400_cat1234[4],M450_cat1234[4],M500_cat1234[4],M550_cat1234[4],M600_cat1234[4],M650_cat1234[4],M700_cat1234[4],M750_cat1234[4],M800_cat1234[4],M850_cat1234[4],M1100_cat1234[4],M1200_cat1234[4],M1300_cat1234[4],M1400_cat1234[4],M1500_cat1234[4],M1600_cat1234[4],M1700_cat1234[4],M1800_cat1234[4],M1900_cat1234[4],M2000_cat1234[4],M2200_cat1234[4],M2400_cat1234[4],M2600_cat123
plt.xlabel(r'Radion Mass (GeV)')
# plt.ylabel(r'95% CL limits on $\sigma(ggX)*Br(XHHWWgg)[fb]$')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,3000)
plt.xticks([250, 500, 1000, 1500, 2000, 3000], ['250', '500', '1000', '1500', '2000', '3000'])
# plt.xticks(np.arange(250, 3001, 100))
# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,100000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(0.95, 0.95))
plt.show()

# %%
M250_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX250_MH125_run2.AsymptoticLimits.mH125.root")
M250_cat1234 = M250_events_cat1234["limit"].arrays(['limit']).limit*100
M260_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX260_MH125_run2.AsymptoticLimits.mH125.root")
M260_cat1234 = M260_events_cat1234["limit"].arrays(['limit']).limit*100
# M270_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX270_MH125_run2.AsymptoticLimits.mH125.root")
# M270_cat1234 = M270_events_cat1234["limit"].arrays(['limit']).limit*100
M280_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX280_MH125_run2.AsymptoticLimits.mH125.root")
M280_cat1234 = M280_events_cat1234["limit"].arrays(['limit']).limit*100
M300_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX300_MH125_run2.AsymptoticLimits.mH125.root")
M300_cat1234 = M300_events_cat1234["limit"].arrays(['limit']).limit*100
M320_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX320_MH125_run2.AsymptoticLimits.mH125.root")
M320_cat1234 = M320_events_cat1234["limit"].arrays(['limit']).limit*100
M350_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX350_MH125_run2.AsymptoticLimits.mH125.root")
M350_cat1234 = M350_events_cat1234["limit"].arrays(['limit']).limit*100
M400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX400_MH125_run2.AsymptoticLimits.mH125.root")
M400_cat1234 = M400_events_cat1234["limit"].arrays(['limit']).limit*100
M450_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat34_MX450_MH125_run2.AsymptoticLimits.mH125.root")
M450_cat1234 = M450_events_cat1234["limit"].arrays(['limit']).limit*100
M500_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX500_MH125_run2.AsymptoticLimits.mH125.root")
M500_cat1234 = M500_events_cat1234["limit"].arrays(['limit']).limit*100
M550_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX550_MH125_run2.AsymptoticLimits.mH125.root")
M550_cat1234 = M550_events_cat1234["limit"].arrays(['limit']).limit*100
M600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX600_MH125_run2.AsymptoticLimits.mH125.root")
M600_cat1234 = M600_events_cat1234["limit"].arrays(['limit']).limit*100
M650_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX650_MH125_run2.AsymptoticLimits.mH125.root")
M650_cat1234 = M650_events_cat1234["limit"].arrays(['limit']).limit*100
M700_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX700_MH125_run2.AsymptoticLimits.mH125.root")
M700_cat1234 = M700_events_cat1234["limit"].arrays(['limit']).limit*100
M750_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX750_MH125_run2.AsymptoticLimits.mH125.root")
M750_cat1234 = M750_events_cat1234["limit"].arrays(['limit']).limit*100
M800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX800_MH125_run2.AsymptoticLimits.mH125.root")
M800_cat1234 = M800_events_cat1234["limit"].arrays(['limit']).limit*100
M850_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX850_MH125_run2.AsymptoticLimits.mH125.root")
M850_cat1234 = M850_events_cat1234["limit"].arrays(['limit']).limit*100
# M1000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat1234_MX1000_MH125_run2.AsymptoticLimits.mH125.root")
# M1000_cat1234 = M1000_events_cat1234["limit"].arrays(['limit']).limit*100
M1100_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1100_MH125_run2.AsymptoticLimits.mH125.root")
M1100_cat1234 = M1100_events_cat1234["limit"].arrays(['limit']).limit
M1200_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1200_MH125_run2.AsymptoticLimits.mH125.root")
M1200_cat1234 = M1200_events_cat1234["limit"].arrays(['limit']).limit
M1300_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1300_MH125_run2.AsymptoticLimits.mH125.root")
M1300_cat1234 = M1300_events_cat1234["limit"].arrays(['limit']).limit
M1400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1400_MH125_run2.AsymptoticLimits.mH125.root")
M1400_cat1234 = M1400_events_cat1234["limit"].arrays(['limit']).limit
M1500_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1500_MH125_run2.AsymptoticLimits.mH125.root")
M1500_cat1234 = M1500_events_cat1234["limit"].arrays(['limit']).limit
M1600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1600_MH125_run2.AsymptoticLimits.mH125.root")
M1600_cat1234 = M1600_events_cat1234["limit"].arrays(['limit']).limit
M1700_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1700_MH125_run2.AsymptoticLimits.mH125.root")
M1700_cat1234 = M1700_events_cat1234["limit"].arrays(['limit']).limit
M1800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1800_MH125_run2.AsymptoticLimits.mH125.root")
M1800_cat1234 = M1800_events_cat1234["limit"].arrays(['limit']).limit
M1900_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX1900_MH125_run2.AsymptoticLimits.mH125.root")
M1900_cat1234 = M1900_events_cat1234["limit"].arrays(['limit']).limit
M2000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX2000_MH125_run2.AsymptoticLimits.mH125.root")
M2000_cat1234 = M2000_events_cat1234["limit"].arrays(['limit']).limit
M2200_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX2200_MH125_run2.AsymptoticLimits.mH125.root")
M2200_cat1234 = M2200_events_cat1234["limit"].arrays(['limit']).limit
M2400_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX2400_MH125_run2.AsymptoticLimits.mH125.root")
M2400_cat1234 = M2400_events_cat1234["limit"].arrays(['limit']).limit
M2600_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX2600_MH125_run2.AsymptoticLimits.mH125.root")
M2600_cat1234 = M2600_events_cat1234["limit"].arrays(['limit']).limit
M2800_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX2800_MH125_run2.AsymptoticLimits.mH125.root")
M2800_cat1234 = M2800_events_cat1234["limit"].arrays(['limit']).limit
M3000_events_cat1234 = uproot.open("/afs/cern.ch/user/s/shsong/CMSSW_10_6_20/src/flashggFinalFit/Datacard/run2datacard/higgsCombinecat12_MX3000_MH125_run2.AsymptoticLimits.mH125.root")
M3000_cat1234 = M3000_events_cat1234["limit"].arrays(['limit']).limit

# %%
hep.style.use(hep.style.CMS)

hep.cms.label("preliminary", data=True, lumi=138)   
# set figure size
plt.rcParams["figure.figsize"] = (16, 10)
allcat_values = [250,260,280,300,320,350,400,450,500,550,600,650,700,750,850,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2200,2400,2600,2800,3000]
plt.plot(allcat_values, [M250_cat1234[2],M260_cat1234[2],M280_cat1234[2],M300_cat1234[2],M320_cat1234[2],M350_cat1234[2],M400_cat1234[2],M450_cat1234[2],M500_cat1234[2],M550_cat1234[2],M600_cat1234[2],M650_cat1234[2],M700_cat1234[2],M750_cat1234[2],M850_cat1234[2],M1100_cat1234[2],M1200_cat1234[2],M1300_cat1234[2],M1400_cat1234[2],M1500_cat1234[2],M1600_cat1234[2],M1700_cat1234[2],M1800_cat1234[2],M1900_cat1234[2],M2000_cat1234[2],M2200_cat1234[2],M2400_cat1234[2],M2600_cat1234[2],M2800_cat1234[2],M3000_cat1234[2]],color='black', linewidth=2,linestyle='--', label='Asymptotic Limits CLs expected')
# plt.plot(allcat_values, [M250_wwgg[2],M260_wwgg[2],M270_wwgg[2],M280_wwgg[2],M300_wwgg[2],M320_wwgg[2],M400_wwgg[2],M450_wwgg[2],M500_wwgg[2],M550_wwgg[2],M600_wwgg[2],M650_wwgg[2],M700_wwgg[2],M750_wwgg[2],M800_wwgg[2],M850_wwgg[2],M1000_wwgg[2],M1100_wwgg[2],M1200_wwgg[2],M1300_wwgg[2],M1400_wwgg[2],M1500_wwgg[2],M1600_wwgg[2],M1700_wwgg[2],M1800_wwgg[2],M1900_wwgg[2],M2000_wwgg[2],M2200_wwgg[2],M2400_wwgg[2],M2600_wwgg[2],M2800_wwgg[2],M3000_wwgg[2]],color='blue', linewidth=2,linestyle='--', label='WWgg signal')

# 创建连接线之间的中间面积区域并设置为绿色
# 68% confidence interval
plt.fill_between(allcat_values, [M250_cat1234[1],M260_cat1234[1],M280_cat1234[1],M300_cat1234[1],M320_cat1234[1],M350_cat1234[1],M400_cat1234[1],M450_cat1234[1],M500_cat1234[1],M550_cat1234[1],M600_cat1234[1],M650_cat1234[1],M700_cat1234[1],M750_cat1234[1],M850_cat1234[1],M1100_cat1234[1],M1200_cat1234[1],M1300_cat1234[1],M1400_cat1234[1],M1500_cat1234[1],M1600_cat1234[1],M1700_cat1234[1],M1800_cat1234[1],M1900_cat1234[1],M2000_cat1234[1],M2200_cat1234[1],M2400_cat1234[1],M2600_cat1234[1],M2800_cat1234[1],M3000_cat1234[1]], [M250_cat1234[3],M260_cat1234[3],M280_cat1234[3],M300_cat1234[3],M320_cat1234[3],M350_cat1234[3],M400_cat1234[3],M450_cat1234[3],M500_cat1234[3],M550_cat1234[3],M600_cat1234[3],M650_cat1234[3],M700_cat1234[3],M750_cat1234[3],M850_cat1234[3],M1100_cat1234[3],M1200_cat1234[3],M1300_cat1234[3],M1400_cat1234[3],M1500_cat1234[3],M1600_cat1234[3],M1700_cat1234[3],M1800_cat1234[3],M1900_cat1234[3],M2000_cat1234[3],M2200_cat1234[3],M2400_cat1234[3],M2600_cat1234[3],M2800_cat1234[3],M3000_cat1234[3]], color='#04cb02', alpha=1, label= r'68% expected')#'±1 std. deviation')

# 95% confidence interval
plt.fill_between(allcat_values, [M250_cat1234[0],M260_cat1234[0],M280_cat1234[0],M300_cat1234[0],M320_cat1234[0],M350_cat1234[0],M400_cat1234[0],M450_cat1234[0],M500_cat1234[0],M550_cat1234[0],M600_cat1234[0],M650_cat1234[0],M700_cat1234[0],M750_cat1234[0],M850_cat1234[0],M1100_cat1234[0],M1200_cat1234[0],M1300_cat1234[0],M1400_cat1234[0],M1500_cat1234[0],M1600_cat1234[0],M1700_cat1234[0],M1800_cat1234[0],M1900_cat1234[0],M2000_cat1234[0],M2200_cat1234[0],M2400_cat1234[0],M2600_cat1234[0],M2800_cat1234[0],M3000_cat1234[0]],[M250_cat1234[1],M260_cat1234[1],M280_cat1234[1],M300_cat1234[1],M320_cat1234[1],M350_cat1234[1],M400_cat1234[1],M450_cat1234[1],M500_cat1234[1],M550_cat1234[1],M600_cat1234[1],M650_cat1234[1],M700_cat1234[1],M750_cat1234[1],M850_cat1234[1],M1100_cat1234[1],M1200_cat1234[1],M1300_cat1234[1],M1400_cat1234[1],M1500_cat1234[1],M1600_cat1234[1],M1700_cat1234[1],M1800_cat1234[1],M1900_cat1234[1],M2000_cat1234[1],M2200_cat1234[1],M2400_cat1234[1],M2600_cat1234[1],M2800_cat1234[1],M3000_cat1234[1]], color='gold', alpha=1, label= r'95 %expected')#r'±2 std. deviation')
plt.fill_between(allcat_values,  [M250_cat1234[3],M260_cat1234[3],M280_cat1234[3],M300_cat1234[3],M320_cat1234[3],M350_cat1234[3],M400_cat1234[3],M450_cat1234[3],M500_cat1234[3],M550_cat1234[3],M600_cat1234[3],M650_cat1234[3],M700_cat1234[3],M750_cat1234[3],M850_cat1234[3],M1100_cat1234[3],M1200_cat1234[3],M1300_cat1234[3],M1400_cat1234[3],M1500_cat1234[3],M1600_cat1234[3],M1700_cat1234[3],M1800_cat1234[3],M1900_cat1234[3],M2000_cat1234[3],M2200_cat1234[3],M2400_cat1234[3],M2600_cat1234[3],M2800_cat1234[3],M3000_cat1234[3]],  [M250_cat1234[4],M260_cat1234[4],M280_cat1234[4],M300_cat1234[4],M320_cat1234[4],M350_cat1234[4],M400_cat1234[4],M450_cat1234[4],M500_cat1234[4],M550_cat1234[4],M600_cat1234[4],M650_cat1234[4],M700_cat1234[4],M750_cat1234[4],M850_cat1234[4],M1100_cat1234[4],M1200_cat1234[4],M1300_cat1234[4],M1400_cat1234[4],M1500_cat1234[4],M1600_cat1234[4],M1700_cat1234[4],M1800_cat1234[4],M1900_cat1234[4],M2000_cat1234[4],M2200_cat1234[4],M2400_cat1234[4],M2600_cat1234[4],M2800_cat1234[4],M3000_cat1234[4]], color='gold', alpha=1)

# 添加标签和标题
plt.xlabel(r'Radion Mass (GeV)')
# plt.ylabel(r'95% CL limits on $\sigma(ggX)*Br(XHHWWgg)[fb]$')
plt.ylabel(r'95% CL limits on $\sigma(gg\to X)\times Br(X\to HH)[fb]$')
# set x axis range
plt.xlim(250,3000)
plt.xticks([250, 500, 1000, 1500, 2000, 3000], ['250', '500', '1000', '1500', '2000', '3000'])
# plt.xticks(np.arange(250, 3001, 100))
# set log scale
plt.yscale('log')
# set y limit
plt.ylim(10,10000)
# put legend outside of the plot box in right
# plt.legend(loc='upper right', bbox_to_anchor=(1.8, 1.0))
plt.legend(loc='upper right', bbox_to_anchor=(0.95, 0.95))
plt.savefig("/eos/user/s/shsong/AN-23-071/Images/Limit/Run2_HH_limit.pdf",bbox_inches='tight')
